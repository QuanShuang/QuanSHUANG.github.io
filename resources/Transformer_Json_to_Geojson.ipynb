# %%
from sys import argv
from os.path import exists
import simplejson as json 
import pandas as pd
import pprint

# %%
# !pip install simplejson
# Out:
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/e3/24/c35fb1c1c315fc0fffe61ea00d3f88e85469004713dab488dee4f35b0aff/simplejson-3.16.0.tar.gz (81kB)
# Building wheels for collected packages: simplejson
#   Running setup.py bdist_wheel for simplejson: started
#   Running setup.py bdist_wheel for simplejson: finished with status 'done'
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\5d\1a\1e\0350bb3df3e74215cd91325344cc86c2c691f5306eb4d22c77
# Successfully built simplejson
# Installing collected packages: simplejson
# Successfully installed simplejson-3.16.0

# %%
script, in_file, out_file = argv
data = json.load(open("listing.json"))
# data = json.load(open(in_file))

data2 = json.load(open("rent.json"))

# %%
data2
# Out:
# {'status': True, 'data': {'message': '', 'nearby': [], 'house': {'id_listing': 'x9w8o3mRraJYGKjm', 'ml_num': 'C4444946', 'hash_id': 'jpA7wq4UZqPd9YWx', 'seo_suffix': '120-Rosedale-Valley-Rd-402-Toronto-M4W1P8-C4444946', 'photo_url': 'https://rendertron.fangintel.com/Live/photos/FULL/1/946/C4444946.jpg?074ab25d', 'house_type_name': 'Co-Op Apt', 'address': 'Unit 402 - 120 Rosedale Valley Rd', 'community_name': 'Rosedale-Moore Park', 'municipality_name': 'Toronto', 'bedroom': 2, 'bedroom_plus': None, 'bedroom_string': 2, 'washroom': 2, 'parking': {'total': 1, 'garage_type': 'Other', 'garage': None, 'parking_type': 'Surface', 'parking': 1, 'text': '0 garage, Surface 1 parking'}, 'house_area': {'area': '1200-1399', 'area_note': None, 'unit': 'feet²', 'estimate': 1299}, 'land': None, 'price': '929,000', 'estimate_price': None, 'estimate_rent': None, 'list_days': 65, 'map': {'lat': 43.67467, 'lon': -79.38603}, 'text': {'list_date_short': 'List 2019-05-09', 'list_date_long': 'List 2019-05-09, 65 days ago', 'dom_short': 'Listed in May,2019', 'dom_long': 'Listed 65 days ago', 'rooms_short': '2 bd 2 ba 1 gr', 'rooms_long': '2 Bedroom, 2 Bathroom, 1 Garage'}, 'list_status': {'public': 1, 'live': 1, 'sold': 0, 's_r': 'Sale', 'text': 'For sale', 'status': 'A', 'feature': None, 'precon': None, 'premium': 1, 'archive': 0}, 'schedule_message': 'I want to book an appointment to view: [C4444946], Unit 402 - 120 Rosedale Valley Rd, Toronto'}, 'chart': []}, 'error': {'code': 0, 'message': ''}, 'debug': {'0': 'API V2', '1': '/api/listing/nearby/rent', 'lang': 'en_US', 'lang_test': 'Language Test English', '$_REQUEST': {'_url': '/api/listing/nearby/rent', 'baseUri': '/bkv2/', 'staticUri': '/bkv2/', 'lang': 'en_US', 'id_listing': 'x9w8o3mRraJYGKjm'}, 'environment': 'production'}}

# %%
data2["data"]["house"]
# Out:
# {'id_listing': 'x9w8o3mRraJYGKjm', 'ml_num': 'C4444946', 'hash_id': 'jpA7wq4UZqPd9YWx', 'seo_suffix': '120-Rosedale-Valley-Rd-402-Toronto-M4W1P8-C4444946', 'photo_url': 'https://rendertron.fangintel.com/Live/photos/FULL/1/946/C4444946.jpg?074ab25d', 'house_type_name': 'Co-Op Apt', 'address': 'Unit 402 - 120 Rosedale Valley Rd', 'community_name': 'Rosedale-Moore Park', 'municipality_name': 'Toronto', 'bedroom': 2, 'bedroom_plus': None, 'bedroom_string': 2, 'washroom': 2, 'parking': {'total': 1, 'garage_type': 'Other', 'garage': None, 'parking_type': 'Surface', 'parking': 1, 'text': '0 garage, Surface 1 parking'}, 'house_area': {'area': '1200-1399', 'area_note': None, 'unit': 'feet²', 'estimate': 1299}, 'land': None, 'price': '929,000', 'estimate_price': None, 'estimate_rent': None, 'list_days': 65, 'map': {'lat': 43.67467, 'lon': -79.38603}, 'text': {'list_date_short': 'List 2019-05-09', 'list_date_long': 'List 2019-05-09, 65 days ago', 'dom_short': 'Listed in May,2019', 'dom_long': 'Listed 65 days ago', 'rooms_short': '2 bd 2 ba 1 gr', 'rooms_long': '2 Bedroom, 2 Bathroom, 1 Garage'}, 'list_status': {'public': 1, 'live': 1, 'sold': 0, 's_r': 'Sale', 'text': 'For sale', 'status': 'A', 'feature': None, 'precon': None, 'premium': 1, 'archive': 0}, 'schedule_message': 'I want to book an appointment to view: [C4444946], Unit 402 - 120 Rosedale Valley Rd, Toronto'}

# %%
data
# Out:
# {'status': True,
#  'data': {'message': '',
#   'list': [{'id_listing': 'xmZRW7ng8r13EBO9',
#     'lat': 43.44757,
#     'lng': -79.68754,
#     'price': '0.73M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dWm67wRQr',
#     'lat': 43.4577,
#     'lng': -79.69413,
#     'price': '2.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMOdkYkWVP',
#     'lat': 43.53884,
#     'lng': -79.67404,
#     'price': '0.64M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGoQPjyW1ZD',
#     'lat': 43.430661,
#     'lng': -79.74829,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGoQkJyW1ZD',
#     'lat': 43.47901,
#     'lng': -79.73638,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraRGK354lW',
#     'lat': 43.44629,
#     'lng': -79.76425,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dW1z7wRQr',
#     'lat': 43.43847,
#     'lng': -79.68056,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9O8Z7GxMb',
#     'lat': 43.51203,
#     'lng': -79.65332,
#     'price': '0.76M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REKDLyqlAp',
#     'lat': 43.46292,
#     'lng': -79.66456,
#     'price': '2.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6Lqd78Jg0',
#     'lat': 43.5458,
#     'lng': -79.73195,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3Vqn9O7DBNr',
#     'lat': 43.51929,
#     'lng': -79.67545,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZkwX3QOzg',
#     'lat': 43.45277,
#     'lng': -79.73692,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZMz97J9Bo',
#     'lat': 43.46015,
#     'lng': -79.67024,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6jBV78Jg0',
#     'lat': 43.55473,
#     'lng': -79.67685,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meMeV3GKjm',
#     'lat': 43.44389,
#     'lng': -79.72874,
#     'price': '0.73M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovMvL3n961',
#     'lat': 43.43578,
#     'lng': -79.73501,
#     'price': '0.45M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176Kj4n3ZajD',
#     'lat': 43.54436,
#     'lng': -79.67833,
#     'price': '0.65M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraMnb354lW',
#     'lat': 43.47337,
#     'lng': -79.73888,
#     'price': '0.66M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZMwA7J9Bo',
#     'lat': 43.55141,
#     'lng': -79.68138,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDKA9yKabB',
#     'lat': 43.55307,
#     'lng': -79.64953,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8jWo78m9K',
#     'lat': 43.54412,
#     'lng': -79.74292,
#     'price': '0.7M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30Ojgl7OklN',
#     'lat': 43.47442,
#     'lng': -79.73339,
#     'price': '0.89M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4Mww3j2q8',
#     'lat': 43.43315,
#     'lng': -79.68355,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzMeRyKRjD',
#     'lat': 43.49161,
#     'lng': -79.69518,
#     'price': '2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6jGO78Jg0',
#     'lat': 43.555,
#     'lng': -79.75489,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176Kj2d3ZajD',
#     'lat': 43.53911,
#     'lng': -79.72034,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGM1R7w1Qr',
#     'lat': 43.4311,
#     'lng': -79.68973,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVjaDYrPo8',
#     'lat': 43.44835,
#     'lng': -79.70931,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xjB4Yo9DA',
#     'lat': 43.482696,
#     'lng': -79.689924,
#     'price': '0.65M',
#     'house_type': None,
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngM9R3EBO9',
#     'lat': 43.493234,
#     'lng': -79.718618,
#     'price': '0.83M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBjqqyKemj',
#     'lat': 43.47431,
#     'lng': -79.7458,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176Kjkw3ZajD',
#     'lat': 43.4887,
#     'lng': -79.71885,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLjmX75eZE',
#     'lat': 43.53848,
#     'lng': -79.68749,
#     'price': '0.38M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PjmwyrR18',
#     'lat': 43.43772,
#     'lng': -79.76533,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGMnd7w1Qr',
#     'lat': 43.43496,
#     'lng': -79.69433,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176Kjwv3ZajD',
#     'lat': 43.43768,
#     'lng': -79.69279,
#     'price': '0.98M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLjQV75eZE',
#     'lat': 43.54913,
#     'lng': -79.71988,
#     'price': '0.64M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5Abe7d4V6',
#     'lat': 43.475273,
#     'lng': -79.721494,
#     'price': '0.65M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwj6w3XBeq',
#     'lat': 43.44647,
#     'lng': -79.74247,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7RELeDyqlAp',
#     'lat': 43.44998,
#     'lng': -79.73448,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9kQA7GxMb',
#     'lat': 43.5299,
#     'lng': -79.68737,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0Bw2yZ1MW',
#     'lat': 43.47619,
#     'lng': -79.74342,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMd6J3d0ZE',
#     'lat': 43.45418,
#     'lng': -79.69693,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovMbp3n961',
#     'lat': 43.47954,
#     'lng': -79.72717,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PjQ9yrR18',
#     'lat': 43.54539,
#     'lng': -79.67988,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2PGD7VPW4',
#     'lat': 43.47954,
#     'lng': -79.72717,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZnnk3QOzg',
#     'lat': 43.5325,
#     'lng': -79.68702,
#     'price': '0.6M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwjj83XBeq',
#     'lat': 43.47522,
#     'lng': -79.72111,
#     'price': '0.88M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNML6ybmwe',
#     'lat': 43.5406,
#     'lng': -79.6655,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3Vqj2O7DBNr',
#     'lat': 43.45449,
#     'lng': -79.67101,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLjwv75eZE',
#     'lat': 43.42534,
#     'lng': -79.77021,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMbEVYkWVP',
#     'lat': 43.4284,
#     'lng': -79.76018,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEg6JR7x2P0',
#     'lat': 43.41786,
#     'lng': -79.70502,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNQPxYJmG2',
#     'lat': 43.44367,
#     'lng': -79.75743,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9kPK7GxMb',
#     'lat': 43.53524,
#     'lng': -79.70499,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraMqn354lW',
#     'lat': 43.44365,
#     'lng': -79.67994,
#     'price': '0.73M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2Pwo7VPW4',
#     'lat': 43.4573,
#     'lng': -79.70704,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZnqd3QOzg',
#     'lat': 43.44715,
#     'lng': -79.66917,
#     'price': '1.3M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meMJz3GKjm',
#     'lat': 43.55205,
#     'lng': -79.71304,
#     'price': '0.4M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEg6AK7x2P0',
#     'lat': 43.53132,
#     'lng': -79.71476,
#     'price': '0.78M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMdaV3d0ZE',
#     'lat': 43.54979,
#     'lng': -79.68605,
#     'price': '0.7M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6j9w78Jg0',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.51M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32Wj64YDar0',
#     'lat': 43.497897,
#     'lng': -79.720353,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDMRpY5mGN',
#     'lat': 43.492111,
#     'lng': -79.719011,
#     'price': '0.84M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZEvr7J9Bo',
#     'lat': 43.53848,
#     'lng': -79.68749,
#     'price': '0.38M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kglj3qdeK',
#     'lat': 43.49715,
#     'lng': -79.70794,
#     'price': '0.66M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwbw83XBeq',
#     'lat': 43.42249,
#     'lng': -79.77,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meOe23GKjm',
#     'lat': 43.47348,
#     'lng': -79.69679,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WaW8YDar0',
#     'lat': 43.41795,
#     'lng': -79.70642,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGoWoJyW1ZD',
#     'lat': 43.4458,
#     'lng': -79.75995,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoAqeYLGlV',
#     'lat': 43.43593,
#     'lng': -79.76438,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4VEE3j2q8',
#     'lat': 43.47118,
#     'lng': -79.72711,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNqDoYJmG2',
#     'lat': 43.55205,
#     'lng': -79.71304,
#     'price': '0.42M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVb1EYrPo8',
#     'lat': 43.48034,
#     'lng': -79.71998,
#     'price': '1.9K',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REbd1yqlAp',
#     'lat': 43.44757,
#     'lng': -79.68754,
#     'price': '0.68M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZEDM7J9Bo',
#     'lat': 43.49265,
#     'lng': -79.719957,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7Nzwmr7eRPJ',
#     'lat': 43.44392,
#     'lng': -79.75083,
#     'price': '0.68M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5kqG7d4V6',
#     'lat': 43.485639,
#     'lng': -79.729208,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoAmVYLGlV',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.5M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2Kzo7VPW4',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xML0WYkWVP',
#     'lat': 43.48132,
#     'lng': -79.71568,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dZGV7wRQr',
#     'lat': 43.55405,
#     'lng': -79.71117,
#     'price': '0.55M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DeVb5YMnxB',
#     'lat': 43.47068,
#     'lng': -79.74772,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYrak1o354lW',
#     'lat': 43.52599,
#     'lng': -79.69806,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kN6Joybmwe',
#     'lat': 43.51168,
#     'lng': -79.65255,
#     'price': '0.73M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZ8Ob3QOzg',
#     'lat': 43.44745,
#     'lng': -79.68164,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBbwbyKemj',
#     'lat': 43.54974,
#     'lng': -79.74051,
#     'price': '0.72M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovWk23n961',
#     'lat': 43.55198,
#     'lng': -79.72868,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DeVwrYMnxB',
#     'lat': 43.55068,
#     'lng': -79.68358,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNqwjYJmG2',
#     'lat': 43.43588,
#     'lng': -79.7509,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xggjYo9DA',
#     'lat': 43.50153,
#     'lng': -79.6941,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVb9MYrPo8',
#     'lat': 43.53003,
#     'lng': -79.69083,
#     'price': '0.81M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DeVr6YMnxB',
#     'lat': 43.55575,
#     'lng': -79.65271,
#     'price': '0.96M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kN6n1ybmwe',
#     'lat': 43.42846,
#     'lng': -79.75223,
#     'price': '0.8M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wznkeyKRjD',
#     'lat': 43.43682,
#     'lng': -79.7175,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwbLx3XBeq',
#     'lat': 43.43942,
#     'lng': -79.7525,
#     'price': '0.77M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DeV9JYMnxB',
#     'lat': 43.41793,
#     'lng': -79.69687,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30ODzD7OklN',
#     'lat': 43.45198,
#     'lng': -79.73227,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4P2DByrR18',
#     'lat': 43.54187,
#     'lng': -79.67832,
#     'price': '0.72M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmLap3XeLP',
#     'lat': 43.54801,
#     'lng': -79.69839,
#     'price': '0.63M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30ODnn7OklN',
#     'lat': 43.54554,
#     'lng': -79.68537,
#     'price': '0.45M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9JnK7GxMb',
#     'lat': 43.481825,
#     'lng': -79.691881,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6bal78Jg0',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0XvEyZ1MW',
#     'lat': 43.42971,
#     'lng': -79.69011,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xML2WYkWVP',
#     'lat': 43.43396,
#     'lng': -79.76886,
#     'price': '0.77M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoAO8YLGlV',
#     'lat': 43.55224,
#     'lng': -79.72846,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6bkO78Jg0',
#     'lat': 43.49407,
#     'lng': -79.68647,
#     'price': '1.1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REb8RyqlAp',
#     'lat': 43.46452,
#     'lng': -79.73681,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0q5LyvgxV',
#     'lat': 43.42704,
#     'lng': -79.73067,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDdj2yKabB',
#     'lat': 43.49163,
#     'lng': -79.70146,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYrak0o354lW',
#     'lat': 43.47697,
#     'lng': -79.737,
#     'price': '0.9M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dZNn7wRQr',
#     'lat': 43.44208,
#     'lng': -79.75039,
#     'price': '0.99M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgO5n7x2P0',
#     'lat': 43.47743,
#     'lng': -79.72272,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DenNjYMnxB',
#     'lat': 43.47991,
#     'lng': -79.73216,
#     'price': '0.89M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1J19YjEvL',
#     'lat': 43.53666,
#     'lng': -79.64892,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meZnd3GKjm',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.5M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'kbEDRYadx0v31VaB',
#     'lat': 43.47781,
#     'lng': -79.72256,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVgdEYrPo8',
#     'lat': 43.53144,
#     'lng': -79.68398,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLPmk75eZE',
#     'lat': 43.48116,
#     'lng': -79.6928,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3Vq2D67DBNr',
#     'lat': 43.473874,
#     'lng': -79.747807,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5gpz7d4V6',
#     'lat': 43.476763,
#     'lng': -79.733969,
#     'price': '1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KXQd3ZajD',
#     'lat': 43.46057,
#     'lng': -79.69947,
#     'price': '0.63M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovZlD3n961',
#     'lat': 43.54802,
#     'lng': -79.72629,
#     'price': '0.63M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OwRG7OklN',
#     'lat': 43.53724,
#     'lng': -79.67148,
#     'price': '0.66M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DennrYMnxB',
#     'lat': 43.484285,
#     'lng': -79.731891,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5gxZ7d4V6',
#     'lat': 43.53269,
#     'lng': -79.69406,
#     'price': '0.97M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2gXx7VPW4',
#     'lat': 43.47644,
#     'lng': -79.69043,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMgOg3d0ZE',
#     'lat': 43.47108,
#     'lng': -79.74354,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNdLjYJmG2',
#     'lat': 43.44146,
#     'lng': -79.68993,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGojVvyW1ZD',
#     'lat': 43.55159,
#     'lng': -79.72373,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8k4O78m9K',
#     'lat': 43.55205,
#     'lng': -79.71304,
#     'price': '0.51M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OwoZ7OklN',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoZ61YLGlV',
#     'lat': 43.54399,
#     'lng': -79.666778,
#     'price': '0.95M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDg4ZyKabB',
#     'lat': 43.43008,
#     'lng': -79.7455,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZb2L7J9Bo',
#     'lat': 43.550025,
#     'lng': -79.713641,
#     'price': '0.31M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xn4jYo9DA',
#     'lat': 43.52844,
#     'lng': -79.64844,
#     'price': '0.37M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmgEX3XeLP',
#     'lat': 43.53884,
#     'lng': -79.67404,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0JZ2yZ1MW',
#     'lat': 43.47631,
#     'lng': -79.70007,
#     'price': '0.95M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmgrO3XeLP',
#     'lat': 43.44499,
#     'lng': -79.76224,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVgnGYrPo8',
#     'lat': 43.52196,
#     'lng': -79.6676,
#     'price': '0.79M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REa1LyqlAp',
#     'lat': 43.48543,
#     'lng': -79.72869,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7Pmgn13XeLP',
#     'lat': 43.48007,
#     'lng': -79.72758,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngZod3EBO9',
#     'lat': 43.45035,
#     'lng': -79.68037,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0JvlyZ1MW',
#     'lat': 43.53211,
#     'lng': -79.71463,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDgJmyKabB',
#     'lat': 43.43521,
#     'lng': -79.69405,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmJGD3XeLP',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG4PR7w1Qr',
#     'lat': 43.48161,
#     'lng': -79.71617,
#     'price': '0.57M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6XBO78Jg0',
#     'lat': 43.41683,
#     'lng': -79.70815,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovpvD3n961',
#     'lat': 43.47361,
#     'lng': -79.749054,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'kbEDRYadKE131VaB',
#     'lat': 43.4486,
#     'lng': -79.68555,
#     'price': '0.29M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqQ8z7DBNr',
#     'lat': 43.54087,
#     'lng': -79.70089,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNEAjYJmG2',
#     'lat': 43.47849,
#     'lng': -79.72787,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNlqOybmwe',
#     'lat': 43.47849,
#     'lng': -79.72787,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PqgpyrR18',
#     'lat': 43.44482,
#     'lng': -79.71522,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4lDp3j2q8',
#     'lat': 43.49379,
#     'lng': -79.70081,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqQmQ7DBNr',
#     'lat': 43.48067,
#     'lng': -79.69919,
#     'price': '0.94M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DeQJkYMnxB',
#     'lat': 43.49656,
#     'lng': -79.70486,
#     'price': '1M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WQg4YDar0',
#     'lat': 43.4346,
#     'lng': -79.76821,
#     'price': '0.78M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGo6nvyW1ZD',
#     'lat': 43.42382,
#     'lng': -79.69743,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDgEpY5mGN',
#     'lat': 43.47617,
#     'lng': -79.71933,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8ndO78m9K',
#     'lat': 43.45186,
#     'lng': -79.75697,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVBQKYrPo8',
#     'lat': 43.47743,
#     'lng': -79.70883,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xRWxYo9DA',
#     'lat': 43.497789,
#     'lng': -79.691533,
#     'price': '0.72M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5xvm7d4V6',
#     'lat': 43.5284,
#     'lng': -79.649782,
#     'price': '0.4M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG48K7w1Qr',
#     'lat': 43.44757,
#     'lng': -79.68754,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0nwnyZ1MW',
#     'lat': 43.47344,
#     'lng': -79.68367,
#     'price': '0.79M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLwEk75eZE',
#     'lat': 43.41939,
#     'lng': -79.70392,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7nglvd3EBO9',
#     'lat': 43.54233,
#     'lng': -79.72391,
#     'price': '0.72M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgXEG7x2P0',
#     'lat': 43.45576,
#     'lng': -79.74178,
#     'price': '0.87M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KVgn3ZajD',
#     'lat': 43.466979,
#     'lng': -79.712291,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0an4yvgxV',
#     'lat': 43.55273,
#     'lng': -79.72926,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDPg9yKabB',
#     'lat': 43.47568,
#     'lng': -79.71155,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KVVj3ZajD',
#     'lat': 43.47937,
#     'lng': -79.70861,
#     'price': '0.84M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG44B7w1Qr',
#     'lat': 43.41947,
#     'lng': -79.77306,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG4jR7w1Qr',
#     'lat': 43.54825,
#     'lng': -79.72323,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REwlRyqlAp',
#     'lat': 43.42473,
#     'lng': -79.77249,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMEV6YkWVP',
#     'lat': 43.53862,
#     'lng': -79.72112,
#     'price': '0.85M',
#     'house_type': 'L',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVB0oYrPo8',
#     'lat': 43.47937,
#     'lng': -79.70861,
#     'price': '0.84M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzjkOyKRjD',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.48M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNE2jYJmG2',
#     'lat': 43.52415,
#     'lng': -79.67247,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqQ4Q7DBNr',
#     'lat': 43.48669,
#     'lng': -79.69769,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PqlbyrR18',
#     'lat': 43.46766,
#     'lng': -79.71738,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510Qqypo2r1YLGlV',
#     'lat': 43.55077,
#     'lng': -79.74293,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqQXZ7DBNr',
#     'lat': 43.48161,
#     'lng': -79.71617,
#     'price': '0.55M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0nx5yZ1MW',
#     'lat': 43.52443,
#     'lng': -79.69685,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGo60JyW1ZD',
#     'lat': 43.49888,
#     'lng': -79.74097,
#     'price': '2.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dxNz7wRQr',
#     'lat': 43.44546,
#     'lng': -79.74612,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9AKZ7GxMb',
#     'lat': 43.44113,
#     'lng': -79.75393,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVBpEYrPo8',
#     'lat': 43.53724,
#     'lng': -79.67148,
#     'price': '0.65M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5Q897d4V6',
#     'lat': 43.55125,
#     'lng': -79.7048,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WvO5YDar0',
#     'lat': 43.43888,
#     'lng': -79.73755,
#     'price': '0.4M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OmOn7OklN',
#     'lat': 43.48797,
#     'lng': -79.70615,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l414O3j2q8',
#     'lat': 43.42661,
#     'lng': -79.70663,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG26e7w1Qr',
#     'lat': 43.47852,
#     'lng': -79.70942,
#     'price': '2.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgJRG7x2P0',
#     'lat': 43.42932,
#     'lng': -79.76357,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2Xn27VPW4',
#     'lat': 43.48571,
#     'lng': -79.72311,
#     'price': '0.41M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6dvK78Jg0',
#     'lat': 43.553396,
#     'lng': -79.71122,
#     'price': '0.64M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZB8r4yKemj',
#     'lat': 43.43416,
#     'lng': -79.74439,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g18PnYjEvL',
#     'lat': 43.47735,
#     'lng': -79.73377,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510Qqypopl8YLGlV',
#     'lat': 43.47744,
#     'lng': -79.73696,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xDwEYo9DA',
#     'lat': 43.44637,
#     'lng': -79.72402,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMBD6YkWVP',
#     'lat': 43.46228,
#     'lng': -79.73164,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bw8gg3XBeq',
#     'lat': 43.497789,
#     'lng': -79.691533,
#     'price': '0.83M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510Qqypop96YLGlV',
#     'lat': 43.47004,
#     'lng': -79.69273,
#     'price': '0.34M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MD6qPyKabB',
#     'lat': 43.52838,
#     'lng': -79.70708,
#     'price': '0.97M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5Yov1z23n961',
#     'lat': 43.55472,
#     'lng': -79.74913,
#     'price': '0.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYra4zB354lW',
#     'lat': 43.52113,
#     'lng': -79.69103,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMBmQYkWVP',
#     'lat': 43.49356,
#     'lng': -79.6587,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZB8zKyKemj',
#     'lat': 43.55206,
#     'lng': -79.75076,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzgN6yKRjD',
#     'lat': 43.45828,
#     'lng': -79.70877,
#     'price': '0.68M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6dP678Jg0',
#     'lat': 43.430661,
#     'lng': -79.74829,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVwGGYrPo8',
#     'lat': 43.43278,
#     'lng': -79.72808,
#     'price': '0.45M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG2EK7w1Qr',
#     'lat': 43.43888,
#     'lng': -79.73755,
#     'price': '0.41M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MD6dVyKabB',
#     'lat': 43.53775,
#     'lng': -79.6611,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVwgEYrPo8',
#     'lat': 43.55125,
#     'lng': -79.75332,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dRxA7wRQr',
#     'lat': 43.51967,
#     'lng': -79.67258,
#     'price': '0.72M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PvxmyrR18',
#     'lat': 43.53853,
#     'lng': -79.69441,
#     'price': '0.78M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNPW5YJmG2',
#     'lat': 43.44589,
#     'lng': -79.74966,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVwDvYrPo8',
#     'lat': 43.52675,
#     'lng': -79.67448,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMBqQYkWVP',
#     'lat': 43.43721,
#     'lng': -79.71536,
#     'price': '0.78M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0Ax2yZ1MW',
#     'lat': 43.43539,
#     'lng': -79.77266,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqG2057w1Qr',
#     'lat': 43.54732,
#     'lng': -79.71075,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZWpp3QOzg',
#     'lat': 43.47175,
#     'lng': -79.73614,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3me15k3GKjm',
#     'lat': 43.43133,
#     'lng': -79.69946,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZ1nL7J9Bo',
#     'lat': 43.53798,
#     'lng': -79.72157,
#     'price': '0.73M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kmEw3qdeK',
#     'lat': 43.4947,
#     'lng': -79.70707,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wrgOyDrK8',
#     'lat': 43.48055,
#     'lng': -79.726448,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDq1oY5mGN',
#     'lat': 43.47306,
#     'lng': -79.68219,
#     'price': '0.37M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMV9kYkWVP',
#     'lat': 43.48494,
#     'lng': -79.72462,
#     'price': '0.62M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0g0ayvgxV',
#     'lat': 43.43008,
#     'lng': -79.7455,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5DVm7d4V6',
#     'lat': 43.44757,
#     'lng': -79.68754,
#     'price': '0.41M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2LO67VPW4',
#     'lat': 43.43539,
#     'lng': -79.77266,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZLKk3QOzg',
#     'lat': 43.54458,
#     'lng': -79.67011,
#     'price': '1.2M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176Kr4a3ZajD',
#     'lat': 43.42702,
#     'lng': -79.76095,
#     'price': '0.98M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W64vd78Jg0',
#     'lat': 43.43436,
#     'lng': -79.74469,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WrlOYDar0',
#     'lat': 43.43183,
#     'lng': -79.6936,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMLZ03d0ZE',
#     'lat': 43.534543,
#     'lng': -79.680012,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kzMd3qdeK',
#     'lat': 43.47431,
#     'lng': -79.65883,
#     'price': '3.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraEAZ354lW',
#     'lat': 43.44733,
#     'lng': -79.752,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KrMW3ZajD',
#     'lat': 43.47636,
#     'lng': -79.64906,
#     'price': '2.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XV9aqYrPo8',
#     'lat': 43.47918,
#     'lng': -79.6994,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMLVQ3d0ZE',
#     'lat': 43.48266,
#     'lng': -79.73545,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7RElzRyqlAp',
#     'lat': 43.52452,
#     'lng': -79.67909,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PrJmyrR18',
#     'lat': 43.42356,
#     'lng': -79.70522,
#     'price': '2.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzLoo7eRPJ',
#     'lat': 43.44836,
#     'lng': -79.6796,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZLo13QOzg',
#     'lat': 43.47025,
#     'lng': -79.74106,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDLXPyKabB',
#     'lat': 43.43539,
#     'lng': -79.77266,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kzq43qdeK',
#     'lat': 43.55284,
#     'lng': -79.64888,
#     'price': '0.47M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e89Aq78m9K',
#     'lat': 43.50607,
#     'lng': -79.65307,
#     'price': '0.84M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0oLLyZ1MW',
# ...
#     'lat': 43.47081,
#     'lng': -79.66198,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngpNR3EBO9',
#     'lat': 43.48676,
#     'lng': -79.7243,
#     'price': '0.9M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLld175eZE',
#     'lat': 43.4603,
#     'lng': -79.70731,
#     'price': '0.83M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KL4K3ZajD',
#     'lat': 43.48526,
#     'lng': -79.64909,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REqJdyqlAp',
#     'lat': 43.491941,
#     'lng': -79.716997,
#     'price': '0.87M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqxLz7DBNr',
#     'lat': 43.43814,
#     'lng': -79.76462,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngpqg3EBO9',
#     'lat': 43.48091,
#     'lng': -79.69244,
#     'price': '0.87M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzaD6yKRjD',
#     'lat': 43.47515,
#     'lng': -79.71299,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVPmKYrPo8',
#     'lat': 43.44547,
#     'lng': -79.7615,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32W8gXYDar0',
#     'lat': 43.48498,
#     'lng': -79.65039,
#     'price': '2.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J59l17d4V6',
#     'lat': 43.51332,
#     'lng': -79.65185,
#     'price': '0.84M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l48mE3j2q8',
#     'lat': 43.43279,
#     'lng': -79.76387,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wL2zyDrK8',
#     'lat': 43.496472,
#     'lng': -79.72002,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9bve7GxMb',
#     'lat': 43.53239,
#     'lng': -79.69575,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqxvO7DBNr',
#     'lat': 43.42846,
#     'lng': -79.75223,
#     'price': '0.48M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVPkdYrPo8',
#     'lat': 43.43991,
#     'lng': -79.73543,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLlvg75eZE',
#     'lat': 43.54453,
#     'lng': -79.70097,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3me8Lo3GKjm',
#     'lat': 43.54392,
#     'lng': -79.70551,
#     'price': '0.98M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e81ng78m9K',
#     'lat': 43.44502,
#     'lng': -79.7255,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzEko7eRPJ',
#     'lat': 43.43473,
#     'lng': -79.76316,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kLmq3qdeK',
#     'lat': 43.49226,
#     'lng': -79.71345,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzEVV7eRPJ',
#     'lat': 43.54358,
#     'lng': -79.72326,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1wgRYjEvL',
#     'lat': 43.52558,
#     'lng': -79.69991,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZX0a3QOzg',
#     'lat': 43.46298,
#     'lng': -79.71233,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A02EmyZ1MW',
#     'lat': 43.4883,
#     'lng': -79.68772,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6Wxn78Jg0',
#     'lat': 43.46714,
#     'lng': -79.71504,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqxOz7DBNr',
#     'lat': 43.555,
#     'lng': -79.73777,
#     'price': '0.88M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVPAMYrPo8',
#     'lat': 43.48242,
#     'lng': -79.73658,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEg90d7x2P0',
#     'lat': 43.43167,
#     'lng': -79.70187,
#     'price': '0.79M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVPOGYrPo8',
#     'lat': 43.47088,
#     'lng': -79.72723,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1wQ5YjEvL',
#     'lat': 43.41994,
#     'lng': -79.70785,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REq8LyqlAp',
#     'lat': 43.42067,
#     'lng': -79.70495,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5Yov2j63n961',
#     'lat': 43.46072,
#     'lng': -79.70466,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1wBPYjEvL',
#     'lat': 43.48794,
#     'lng': -79.69539,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e81eM78m9K',
#     'lat': 43.55331,
#     'lng': -79.69064,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PBZgyrR18',
#     'lat': 43.486584,
#     'lng': -79.729164,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYra8Bz354lW',
#     'lat': 43.46833,
#     'lng': -79.69174,
#     'price': '0.82M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wLKdyDrK8',
#     'lat': 43.43793,
#     'lng': -79.76222,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5r5G7d4V6',
#     'lat': 43.4377,
#     'lng': -79.74831,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K20227VPW4',
#     'lat': 43.55121,
#     'lng': -79.73889,
#     'price': '0.88M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMPklYkWVP',
#     'lat': 43.47463,
#     'lng': -79.73306,
#     'price': '0.97M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K20ZX7VPW4',
#     'lat': 43.48414,
#     'lng': -79.68987,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoXB6YLGlV',
#     'lat': 43.41708,
#     'lng': -79.70948,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEg1mn7x2P0',
#     'lat': 43.53808,
#     'lng': -79.69256,
#     'price': '0.83M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBNmbyKemj',
#     'lat': 43.46541,
#     'lng': -79.69396,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wodqyDrK8',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6w5w78Jg0',
#     'lat': 43.53118,
#     'lng': -79.6652,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMjB13d0ZE',
#     'lat': 43.4757,
#     'lng': -79.72892,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGq817w1Qr',
#     'lat': 43.494439,
#     'lng': -79.715466,
#     'price': '0.97M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEg1vd7x2P0',
#     'lat': 43.484254,
#     'lng': -79.733566,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwdqQ3XBeq',
#     'lat': 43.41963,
#     'lng': -79.68885,
#     'price': '3.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wonOyDrK8',
#     'lat': 43.43097,
#     'lng': -79.76122,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dPVz7wRQr',
#     'lat': 43.4787,
#     'lng': -79.72819,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5rjm7d4V6',
#     'lat': 43.43673,
#     'lng': -79.67994,
#     'price': '0.77M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYra6kZ354lW',
#     'lat': 43.48099,
#     'lng': -79.73445,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6wbV78Jg0',
#     'lat': 43.47165,
#     'lng': -79.74203,
#     'price': '1.1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDagmyKabB',
#     'lat': 43.4645,
#     'lng': -79.72156,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l40Zg3j2q8',
#     'lat': 43.44935,
#     'lng': -79.72905,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMjKb3d0ZE',
#     'lat': 43.49219,
#     'lng': -79.69044,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dP2V7wRQr',
#     'lat': 43.47367,
#     'lng': -79.73996,
#     'price': '0.9M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngRdM3EBO9',
#     'lat': 43.47294,
#     'lng': -79.71017,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6wNn78Jg0',
#     'lat': 43.41818,
#     'lng': -79.70768,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5raZ7d4V6',
#     'lat': 43.46843,
#     'lng': -79.7482,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PlLNyrR18',
#     'lat': 43.478633,
#     'lng': -79.708193,
#     'price': '0.87M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wDedyDrK8',
#     'lat': 43.43945,
#     'lng': -79.73875,
#     'price': '0.38M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DeWRVYMnxB',
#     'lat': 43.52812,
#     'lng': -79.65617,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dDM07wRQr',
#     'lat': 43.45136,
#     'lng': -79.66137,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176Km2n3ZajD',
#     'lat': 43.52807,
#     'lng': -79.65618,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meGVo3GKjm',
#     'lat': 43.4757,
#     'lng': -79.68322,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzODRyKRjD',
#     'lat': 43.49757,
#     'lng': -79.69968,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZ9md3QOzg',
#     'lat': 43.428,
#     'lng': -79.76286,
#     'price': '0.72M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0GD4yvgxV',
#     'lat': 43.43195,
#     'lng': -79.69743,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}],
#   'list_feature': [],
#   'days_filter': [{'id': 1, 'name': 'Last 1 days', 'abbr': '1d'},
#    {'id': 7, 'name': 'Last 7 days', 'abbr': '7d'},
#    {'id': 30, 'name': 'Last 30 days', 'abbr': '30d'},
#    {'id': 90, 'name': 'Last 90 days', 'abbr': '90d'},
#    {'id': 0, 'name': 'Listing date - All', 'abbr': 'All'},
#    {'id': -30, 'name': 'More than 30 days', 'abbr': 'dom30'},
#    {'id': -60, 'name': 'More than 60 days', 'abbr': 'dom60'},
#    {'id': -90, 'name': 'More than 90 days', 'abbr': 'dom90'}],
#   'housetype_filter': [{'id': 'all', 'name': 'All property types'},
#    {'id': 'all', 'name': 'All property types'},
#    {'id': 'D.', 'name': '\u200bDetached', 'default': True},
#    {'id': 'S.', 'name': '\u200bSemi-Detached'},
#    {'id': 'A.', 'name': '\u200bFreehold Townhouse'},
#    {'id': 'T.', 'name': '\u200bCondo Townhouse'},
#    {'id': 'C.', 'name': '\u200bCondo Apt'},
#    {'id': 'L.', 'name': '\u200bLink'},
#    {'id': 'J.', 'name': '\u200bMultiplex'},
#    {'id': 'V.', 'name': '\u200bVacant Land'}],
#   'filter_active': {'house_type': 'all',
#    'house_type_name': 'all',
#    'lat1': 43.55576395747266,
#    'lat2': 43.41676950876012,
#    'lon1': -79.64538574218751,
#    'lon2': -79.77413177490236,
#    'days': 0,
#    'price_min': 0,
#    'price_max': 0,
#    'bedroom_range': [0],
#    'bathroom_min': 0,
#    'garage_min': 0,
#    'basement': [],
#    'square_ft_min': 0,
#    'square_ft_max': 4000}},
#  'error': {'code': 0, 'message': ''},
#  'debug': {'0': 'API V2',
#   '1': '/api/search/mapsearch/listing',
#   'lang': 'en_US',
#   'lang_test': 'Language Test English',
#   '$_REQUEST': {'_url': '/api/search/mapsearch/listing',
#    'baseUri': '/bkv2/',
#    'staticUri': '/bkv2/',
#    'lang': 'en_US',
#    'house_type': 'all',
#    'days': 0,
#    'bedroom_range': [0],
#    'price_min': 0,
#    'price_max': 0,
#    'bathroom_min': 0,
#    'garage_min': 0,
#    'basement': [],
#    'square_ft_min': 0,
#    'square_ft_max': 4000,
#    'lat1': 43.55576395747266,
#    'lon1': -79.64538574218751,
#    'lat2': 43.41676950876012,
#    'lon2': -79.77413177490236},
#   'environment': 'production',
#   'bounds': {'lat1': 43.41676950876012,
#    'lat2': 43.55576395747266,
#    'lon1': -79.77413177490236,
#    'lon2': -79.64538574218751},
#   'rowCount': 500}}

# %%
data.keys()
# Out:
# dict_keys(['status', 'data', 'error', 'debug'])

# %%
clean = data["data"]

# %%
clean.keys()
# Out:
# dict_keys(['message', 'list', 'list_feature', 'days_filter', 'housetype_filter', 'filter_active'])

# %%
clean["housetype_filter"]
# Out:
# [{'id': 'all', 'name': 'All property types'},
#  {'id': 'all', 'name': 'All property types'},
#  {'id': 'D.', 'name': '\u200bDetached', 'default': True},
#  {'id': 'S.', 'name': '\u200bSemi-Detached'},
#  {'id': 'A.', 'name': '\u200bFreehold Townhouse'},
#  {'id': 'T.', 'name': '\u200bCondo Townhouse'},
#  {'id': 'C.', 'name': '\u200bCondo Apt'},
#  {'id': 'L.', 'name': '\u200bLink'},
#  {'id': 'J.', 'name': '\u200bMultiplex'},
#  {'id': 'V.', 'name': '\u200bVacant Land'}]

# %%
clean["filter_active"]
# Out:
# {'house_type': 'all',
#  'house_type_name': 'all',
#  'lat1': 43.55576395747266,
#  'lat2': 43.41676950876012,
#  'lon1': -79.64538574218751,
#  'lon2': -79.77413177490236,
#  'days': 0,
#  'price_min': 0,
#  'price_max': 0,
#  'bedroom_range': [0],
#  'bathroom_min': 0,
#  'garage_min': 0,
#  'basement': [],
#  'square_ft_min': 0,
#  'square_ft_max': 4000}

# %%
usable = clean["list"]

# %%
geojson = {
    "type": "FeatureCollection",
    "features": [
    {
        "type": "Feature",
        "geometry" : {
            "type": "Point",
            "coordinates": [d["lng"], d["lat"]],
            },
        "properties" : d,
     } for d in usable]
}

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68754, 43.44757]},
#    'properties': {'id_listing': 'xmZRW7ng8r13EBO9',
#     'lat': 43.44757,
#     'lng': -79.68754,
#     'price': '0.73M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69413, 43.4577]},
#    'properties': {'id_listing': 'VaD6p78dWm67wRQr',
#     'lat': 43.4577,
#     'lng': -79.69413,
#     'price': '2.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67404, 43.53884]},
#    'properties': {'id_listing': 'MB5bO3xMOdkYkWVP',
#     'lat': 43.53884,
#     'lng': -79.67404,
#     'price': '0.64M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74829, 43.430661]},
#    'properties': {'id_listing': '6VLaGyGoQPjyW1ZD',
#     'lat': 43.430661,
#     'lng': -79.74829,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73638, 43.47901]},
#    'properties': {'id_listing': '6VLaGyGoQkJyW1ZD',
#     'lat': 43.47901,
#     'lng': -79.73638,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76425, 43.44629]},
#    'properties': {'id_listing': 'jJKdOYraRGK354lW',
#     'lat': 43.44629,
#     'lng': -79.76425,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68056, 43.43847]},
#    'properties': {'id_listing': 'VaD6p78dW1z7wRQr',
#     'lat': 43.43847,
#     'lng': -79.68056,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65332, 43.51203]},
#    'properties': {'id_listing': 'VgAaOyL9O8Z7GxMb',
#     'lat': 43.51203,
#     'lng': -79.65332,
#     'price': '0.76M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66456, 43.46292]},
#    'properties': {'id_listing': 'b1DBW7REKDLyqlAp',
#     'lat': 43.46292,
#     'lng': -79.66456,
#     'price': '2.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73195, 43.5458]},
#    'properties': {'id_listing': 'BDO1w3W6Lqd78Jg0',
#     'lat': 43.5458,
#     'lng': -79.73195,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67545, 43.51929]},
#    'properties': {'id_listing': '5xLkv3Vqn9O7DBNr',
#     'lat': 43.51929,
#     'lng': -79.67545,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73692, 43.45277]},
#    'properties': {'id_listing': 'JjAXw7QZkwX3QOzg',
#     'lat': 43.45277,
#     'lng': -79.73692,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67024, 43.46015]},
#    'properties': {'id_listing': 'gaQmD7zZMz97J9Bo',
#     'lat': 43.46015,
#     'lng': -79.67024,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67685, 43.55473]},
#    'properties': {'id_listing': 'BDO1w3W6jBV78Jg0',
#     'lat': 43.55473,
#     'lng': -79.67685,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72874, 43.44389]},
#    'properties': {'id_listing': 'x9w8o3meMeV3GKjm',
#     'lat': 43.44389,
#     'lng': -79.72874,
#     'price': '0.73M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73501, 43.43578]},
#    'properties': {'id_listing': '0Zaw5YovMvL3n961',
#     'lat': 43.43578,
#     'lng': -79.73501,
#     'price': '0.45M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67833, 43.54436]},
#    'properties': {'id_listing': 'obqB176Kj4n3ZajD',
#     'lat': 43.54436,
#     'lng': -79.67833,
#     'price': '0.65M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73888, 43.47337]},
#    'properties': {'id_listing': 'jJKdOYraMnb354lW',
#     'lat': 43.47337,
#     'lng': -79.73888,
#     'price': '0.66M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68138, 43.55141]},
#    'properties': {'id_listing': 'gaQmD7zZMwA7J9Bo',
#     'lat': 43.55141,
#     'lng': -79.68138,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64953, 43.55307]},
#    'properties': {'id_listing': '0ZxwR7MDKA9yKabB',
#     'lat': 43.55307,
#     'lng': -79.64953,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74292, 43.54412]},
#    'properties': {'id_listing': 'RdXze3e8jWo78m9K',
#     'lat': 43.54412,
#     'lng': -79.74292,
#     'price': '0.7M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73339, 43.47442]},
#    'properties': {'id_listing': 'ZEXrx30Ojgl7OklN',
#     'lat': 43.47442,
#     'lng': -79.73339,
#     'price': '0.89M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68355, 43.43315]},
#    'properties': {'id_listing': 'L5VXv3l4Mww3j2q8',
#     'lat': 43.43315,
#     'lng': -79.68355,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69518, 43.49161]},
#    'properties': {'id_listing': 'r56k97wzMeRyKRjD',
#     'lat': 43.49161,
#     'lng': -79.69518,
#     'price': '2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75489, 43.555]},
#    'properties': {'id_listing': 'BDO1w3W6jGO78Jg0',
#     'lat': 43.555,
#     'lng': -79.75489,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72034, 43.53911]},
#    'properties': {'id_listing': 'obqB176Kj2d3ZajD',
#     'lat': 43.53911,
#     'lng': -79.72034,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68973, 43.4311]},
#    'properties': {'id_listing': 'BGMnKYqGM1R7w1Qr',
#     'lat': 43.4311,
#     'lng': -79.68973,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70931, 43.44835]},
#    'properties': {'id_listing': 'BXeEn7XVjaDYrPo8',
#     'lat': 43.44835,
#     'lng': -79.70931,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.689924, 43.482696]},
#    'properties': {'id_listing': 'knbq6y1xjB4Yo9DA',
#     'lat': 43.482696,
#     'lng': -79.689924,
#     'price': '0.65M',
#     'house_type': None,
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.718618, 43.493234]},
#    'properties': {'id_listing': 'xmZRW7ngM9R3EBO9',
#     'lat': 43.493234,
#     'lng': -79.718618,
#     'price': '0.83M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7458, 43.47431]},
#    'properties': {'id_listing': '0MWBVyZBjqqyKemj',
#     'lat': 43.47431,
#     'lng': -79.7458,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71885, 43.4887]},
#    'properties': {'id_listing': 'obqB176Kjkw3ZajD',
#     'lat': 43.4887,
#     'lng': -79.71885,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68749, 43.53848]},
#    'properties': {'id_listing': 'a6zqW7dLjmX75eZE',
#     'lat': 43.53848,
#     'lng': -79.68749,
#     'price': '0.38M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76533, 43.43772]},
#    'properties': {'id_listing': 'dXawjy4PjmwyrR18',
#     'lat': 43.43772,
#     'lng': -79.76533,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69433, 43.43496]},
#    'properties': {'id_listing': 'BGMnKYqGMnd7w1Qr',
#     'lat': 43.43496,
#     'lng': -79.69433,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69279, 43.43768]},
#    'properties': {'id_listing': 'obqB176Kjwv3ZajD',
#     'lat': 43.43768,
#     'lng': -79.69279,
#     'price': '0.98M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71988, 43.54913]},
#    'properties': {'id_listing': 'a6zqW7dLjQV75eZE',
#     'lat': 43.54913,
#     'lng': -79.71988,
#     'price': '0.64M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.721494, 43.475273]},
#    'properties': {'id_listing': 'ZNkKJ3J5Abe7d4V6',
#     'lat': 43.475273,
#     'lng': -79.721494,
#     'price': '0.65M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74247, 43.44647]},
#    'properties': {'id_listing': '0J6Em7bwj6w3XBeq',
#     'lat': 43.44647,
#     'lng': -79.74247,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73448, 43.44998]},
#    'properties': {'id_listing': 'b1DBW7RELeDyqlAp',
#     'lat': 43.44998,
#     'lng': -79.73448,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68737, 43.5299]},
#    'properties': {'id_listing': 'VgAaOyL9kQA7GxMb',
#     'lat': 43.5299,
#     'lng': -79.68737,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74342, 43.47619]},
#    'properties': {'id_listing': 'damgL7A0Bw2yZ1MW',
#     'lat': 43.47619,
#     'lng': -79.74342,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69693, 43.45418]},
#    'properties': {'id_listing': 'weQp5yOMd6J3d0ZE',
#     'lat': 43.45418,
#     'lng': -79.69693,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72717, 43.47954]},
#    'properties': {'id_listing': '0Zaw5YovMbp3n961',
#     'lat': 43.47954,
#     'lng': -79.72717,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67988, 43.54539]},
#    'properties': {'id_listing': 'dXawjy4PjQ9yrR18',
#     'lat': 43.54539,
#     'lng': -79.67988,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72717, 43.47954]},
#    'properties': {'id_listing': 'gJRv53K2PGD7VPW4',
#     'lat': 43.47954,
#     'lng': -79.72717,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68702, 43.5325]},
#    'properties': {'id_listing': 'JjAXw7QZnnk3QOzg',
#     'lat': 43.5325,
#     'lng': -79.68702,
#     'price': '0.6M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72111, 43.47522]},
#    'properties': {'id_listing': '0J6Em7bwjj83XBeq',
#     'lat': 43.47522,
#     'lng': -79.72111,
#     'price': '0.88M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6655, 43.5406]},
#    'properties': {'id_listing': 'DnM697kNML6ybmwe',
#     'lat': 43.5406,
#     'lng': -79.6655,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67101, 43.45449]},
#    'properties': {'id_listing': '5xLkv3Vqj2O7DBNr',
#     'lat': 43.45449,
#     'lng': -79.67101,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77021, 43.42534]},
#    'properties': {'id_listing': 'a6zqW7dLjwv75eZE',
#     'lat': 43.42534,
#     'lng': -79.77021,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76018, 43.4284]},
#    'properties': {'id_listing': 'MB5bO3xMbEVYkWVP',
#     'lat': 43.4284,
#     'lng': -79.76018,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70502, 43.41786]},
#    'properties': {'id_listing': 'EeVbOYEg6JR7x2P0',
#     'lat': 43.41786,
#     'lng': -79.70502,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75743, 43.44367]},
#    'properties': {'id_listing': 'oK8OgYBNQPxYJmG2',
#     'lat': 43.44367,
#     'lng': -79.75743,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70499, 43.53524]},
#    'properties': {'id_listing': 'VgAaOyL9kPK7GxMb',
#     'lat': 43.53524,
#     'lng': -79.70499,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67994, 43.44365]},
#    'properties': {'id_listing': 'jJKdOYraMqn354lW',
#     'lat': 43.44365,
#     'lng': -79.67994,
#     'price': '0.73M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70704, 43.4573]},
#    'properties': {'id_listing': 'gJRv53K2Pwo7VPW4',
#     'lat': 43.4573,
#     'lng': -79.70704,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66917, 43.44715]},
#    'properties': {'id_listing': 'JjAXw7QZnqd3QOzg',
#     'lat': 43.44715,
#     'lng': -79.66917,
#     'price': '1.3M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71304, 43.55205]},
#    'properties': {'id_listing': 'x9w8o3meMJz3GKjm',
#     'lat': 43.55205,
#     'lng': -79.71304,
#     'price': '0.4M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71476, 43.53132]},
#    'properties': {'id_listing': 'EeVbOYEg6AK7x2P0',
#     'lat': 43.53132,
#     'lng': -79.71476,
#     'price': '0.78M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68605, 43.54979]},
#    'properties': {'id_listing': 'weQp5yOMdaV3d0ZE',
#     'lat': 43.54979,
#     'lng': -79.68605,
#     'price': '0.7M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77046, 43.43332]},
#    'properties': {'id_listing': 'BDO1w3W6j9w78Jg0',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.51M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.720353, 43.497897]},
#    'properties': {'id_listing': '2Z5BX32Wj64YDar0',
#     'lat': 43.497897,
#     'lng': -79.720353,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.719011, 43.492111]},
#    'properties': {'id_listing': 'zVwod7vDMRpY5mGN',
#     'lat': 43.492111,
#     'lng': -79.719011,
#     'price': '0.84M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68749, 43.53848]},
#    'properties': {'id_listing': 'gaQmD7zZEvr7J9Bo',
#     'lat': 43.53848,
#     'lng': -79.68749,
#     'price': '0.38M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70794, 43.49715]},
#    'properties': {'id_listing': 'mLzQ1y5kglj3qdeK',
#     'lat': 43.49715,
#     'lng': -79.70794,
#     'price': '0.66M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77, 43.42249]},
#    'properties': {'id_listing': '0J6Em7bwbw83XBeq',
#     'lat': 43.42249,
#     'lng': -79.77,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69679, 43.47348]},
#    'properties': {'id_listing': 'x9w8o3meOe23GKjm',
#     'lat': 43.47348,
#     'lng': -79.69679,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70642, 43.41795]},
#    'properties': {'id_listing': '2Z5BX32WaW8YDar0',
#     'lat': 43.41795,
#     'lng': -79.70642,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75995, 43.4458]},
#    'properties': {'id_listing': '6VLaGyGoWoJyW1ZD',
#     'lat': 43.4458,
#     'lng': -79.75995,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76438, 43.43593]},
#    'properties': {'id_listing': '510QqypoAqeYLGlV',
#     'lat': 43.43593,
#     'lng': -79.76438,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72711, 43.47118]},
#    'properties': {'id_listing': 'L5VXv3l4VEE3j2q8',
#     'lat': 43.47118,
#     'lng': -79.72711,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71304, 43.55205]},
#    'properties': {'id_listing': 'oK8OgYBNqDoYJmG2',
#     'lat': 43.55205,
#     'lng': -79.71304,
#     'price': '0.42M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71998, 43.48034]},
#    'properties': {'id_listing': 'BXeEn7XVb1EYrPo8',
#     'lat': 43.48034,
#     'lng': -79.71998,
#     'price': '1.9K',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68754, 43.44757]},
#    'properties': {'id_listing': 'b1DBW7REbd1yqlAp',
#     'lat': 43.44757,
#     'lng': -79.68754,
#     'price': '0.68M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.719957, 43.49265]},
#    'properties': {'id_listing': 'gaQmD7zZEDM7J9Bo',
#     'lat': 43.49265,
#     'lng': -79.719957,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75083, 43.44392]},
#    'properties': {'id_listing': 'L4KAX7Nzwmr7eRPJ',
#     'lat': 43.44392,
#     'lng': -79.75083,
#     'price': '0.68M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.729208, 43.485639]},
#    'properties': {'id_listing': 'ZNkKJ3J5kqG7d4V6',
#     'lat': 43.485639,
#     'lng': -79.729208,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'id_listing': '510QqypoAmVYLGlV',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.5M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'id_listing': 'gJRv53K2Kzo7VPW4',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71568, 43.48132]},
#    'properties': {'id_listing': 'MB5bO3xML0WYkWVP',
#     'lat': 43.48132,
#     'lng': -79.71568,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71117, 43.55405]},
#    'properties': {'id_listing': 'VaD6p78dZGV7wRQr',
#     'lat': 43.55405,
#     'lng': -79.71117,
#     'price': '0.55M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74772, 43.47068]},
#    'properties': {'id_listing': 'NAKv53DeVb5YMnxB',
#     'lat': 43.47068,
#     'lng': -79.74772,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69806, 43.52599]},
#    'properties': {'id_listing': 'jJKdOYrak1o354lW',
#     'lat': 43.52599,
#     'lng': -79.69806,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65255, 43.51168]},
#    'properties': {'id_listing': 'DnM697kN6Joybmwe',
#     'lat': 43.51168,
#     'lng': -79.65255,
#     'price': '0.73M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68164, 43.44745]},
#    'properties': {'id_listing': 'JjAXw7QZ8Ob3QOzg',
#     'lat': 43.44745,
#     'lng': -79.68164,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74051, 43.54974]},
#    'properties': {'id_listing': '0MWBVyZBbwbyKemj',
#     'lat': 43.54974,
#     'lng': -79.74051,
#     'price': '0.72M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72868, 43.55198]},
#    'properties': {'id_listing': '0Zaw5YovWk23n961',
#     'lat': 43.55198,
#     'lng': -79.72868,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68358, 43.55068]},
#    'properties': {'id_listing': 'NAKv53DeVwrYMnxB',
#     'lat': 43.55068,
#     'lng': -79.68358,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7509, 43.43588]},
#    'properties': {'id_listing': 'oK8OgYBNqwjYJmG2',
#     'lat': 43.43588,
#     'lng': -79.7509,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6941, 43.50153]},
#    'properties': {'id_listing': 'knbq6y1xggjYo9DA',
#     'lat': 43.50153,
#     'lng': -79.6941,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69083, 43.53003]},
#    'properties': {'id_listing': 'BXeEn7XVb9MYrPo8',
#     'lat': 43.53003,
#     'lng': -79.69083,
#     'price': '0.81M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65271, 43.55575]},
#    'properties': {'id_listing': 'NAKv53DeVr6YMnxB',
#     'lat': 43.55575,
#     'lng': -79.65271,
#     'price': '0.96M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75223, 43.42846]},
#    'properties': {'id_listing': 'DnM697kN6n1ybmwe',
#     'lat': 43.42846,
#     'lng': -79.75223,
#     'price': '0.8M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7175, 43.43682]},
#    'properties': {'id_listing': 'r56k97wznkeyKRjD',
#     'lat': 43.43682,
#     'lng': -79.7175,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7525, 43.43942]},
#    'properties': {'id_listing': '0J6Em7bwbLx3XBeq',
#     'lat': 43.43942,
#     'lng': -79.7525,
#     'price': '0.77M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69687, 43.41793]},
#    'properties': {'id_listing': 'NAKv53DeV9JYMnxB',
#     'lat': 43.41793,
#     'lng': -79.69687,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73227, 43.45198]},
#    'properties': {'id_listing': 'ZEXrx30ODzD7OklN',
#     'lat': 43.45198,
#     'lng': -79.73227,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67832, 43.54187]},
#    'properties': {'id_listing': 'dXawjy4P2DByrR18',
#     'lat': 43.54187,
#     'lng': -79.67832,
#     'price': '0.72M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69839, 43.54801]},
#    'properties': {'id_listing': 'owJKR7PmLap3XeLP',
#     'lat': 43.54801,
#     'lng': -79.69839,
#     'price': '0.63M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68537, 43.54554]},
#    'properties': {'id_listing': 'ZEXrx30ODnn7OklN',
#     'lat': 43.54554,
#     'lng': -79.68537,
#     'price': '0.45M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.691881, 43.481825]},
#    'properties': {'id_listing': 'VgAaOyL9JnK7GxMb',
#     'lat': 43.481825,
#     'lng': -79.691881,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77046, 43.43332]},
#    'properties': {'id_listing': 'BDO1w3W6bal78Jg0',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69011, 43.42971]},
#    'properties': {'id_listing': 'damgL7A0XvEyZ1MW',
#     'lat': 43.42971,
#     'lng': -79.69011,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76886, 43.43396]},
#    'properties': {'id_listing': 'MB5bO3xML2WYkWVP',
#     'lat': 43.43396,
#     'lng': -79.76886,
#     'price': '0.77M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72846, 43.55224]},
#    'properties': {'id_listing': '510QqypoAO8YLGlV',
#     'lat': 43.55224,
#     'lng': -79.72846,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68647, 43.49407]},
#    'properties': {'id_listing': 'BDO1w3W6bkO78Jg0',
#     'lat': 43.49407,
#     'lng': -79.68647,
#     'price': '1.1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73681, 43.46452]},
#    'properties': {'id_listing': 'b1DBW7REb8RyqlAp',
#     'lat': 43.46452,
#     'lng': -79.73681,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73067, 43.42704]},
#    'properties': {'id_listing': 'N0A9X3j0q5LyvgxV',
#     'lat': 43.42704,
#     'lng': -79.73067,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70146, 43.49163]},
#    'properties': {'id_listing': '0ZxwR7MDdj2yKabB',
#     'lat': 43.49163,
#     'lng': -79.70146,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.737, 43.47697]},
#    'properties': {'id_listing': 'jJKdOYrak0o354lW',
#     'lat': 43.47697,
#     'lng': -79.737,
#     'price': '0.9M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75039, 43.44208]},
#    'properties': {'id_listing': 'VaD6p78dZNn7wRQr',
#     'lat': 43.44208,
#     'lng': -79.75039,
#     'price': '0.99M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72272, 43.47743]},
#    'properties': {'id_listing': 'EeVbOYEgO5n7x2P0',
#     'lat': 43.47743,
#     'lng': -79.72272,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73216, 43.47991]},
#    'properties': {'id_listing': 'NAKv53DenNjYMnxB',
#     'lat': 43.47991,
#     'lng': -79.73216,
#     'price': '0.89M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64892, 43.53666]},
#    'properties': {'id_listing': 'PXRla7g1J19YjEvL',
#     'lat': 43.53666,
#     'lng': -79.64892,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'id_listing': 'x9w8o3meZnd3GKjm',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.5M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72256, 43.47781]},
#    'properties': {'id_listing': 'kbEDRYadx0v31VaB',
#     'lat': 43.47781,
#     'lng': -79.72256,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68398, 43.53144]},
#    'properties': {'id_listing': 'BXeEn7XVgdEYrPo8',
#     'lat': 43.53144,
#     'lng': -79.68398,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6928, 43.48116]},
#    'properties': {'id_listing': 'a6zqW7dLPmk75eZE',
#     'lat': 43.48116,
#     'lng': -79.6928,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.747807, 43.473874]},
#    'properties': {'id_listing': '5xLkv3Vq2D67DBNr',
#     'lat': 43.473874,
#     'lng': -79.747807,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.733969, 43.476763]},
#    'properties': {'id_listing': 'ZNkKJ3J5gpz7d4V6',
#     'lat': 43.476763,
#     'lng': -79.733969,
#     'price': '1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69947, 43.46057]},
#    'properties': {'id_listing': 'obqB176KXQd3ZajD',
#     'lat': 43.46057,
#     'lng': -79.69947,
#     'price': '0.63M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72629, 43.54802]},
#    'properties': {'id_listing': '0Zaw5YovZlD3n961',
#     'lat': 43.54802,
#     'lng': -79.72629,
#     'price': '0.63M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67148, 43.53724]},
#    'properties': {'id_listing': 'ZEXrx30OwRG7OklN',
#     'lat': 43.53724,
#     'lng': -79.67148,
#     'price': '0.66M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.731891, 43.484285]},
#    'properties': {'id_listing': 'NAKv53DennrYMnxB',
#     'lat': 43.484285,
#     'lng': -79.731891,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69406, 43.53269]},
#    'properties': {'id_listing': 'ZNkKJ3J5gxZ7d4V6',
#     'lat': 43.53269,
#     'lng': -79.69406,
#     'price': '0.97M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69043, 43.47644]},
#    'properties': {'id_listing': 'gJRv53K2gXx7VPW4',
#     'lat': 43.47644,
#     'lng': -79.69043,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74354, 43.47108]},
#    'properties': {'id_listing': 'weQp5yOMgOg3d0ZE',
#     'lat': 43.47108,
#     'lng': -79.74354,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68993, 43.44146]},
#    'properties': {'id_listing': 'oK8OgYBNdLjYJmG2',
#     'lat': 43.44146,
#     'lng': -79.68993,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72373, 43.55159]},
#    'properties': {'id_listing': '6VLaGyGojVvyW1ZD',
#     'lat': 43.55159,
#     'lng': -79.72373,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71304, 43.55205]},
#    'properties': {'id_listing': 'RdXze3e8k4O78m9K',
#     'lat': 43.55205,
#     'lng': -79.71304,
#     'price': '0.51M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77046, 43.43332]},
#    'properties': {'id_listing': 'ZEXrx30OwoZ7OklN',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.49M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.666778, 43.54399]},
#    'properties': {'id_listing': '510QqypoZ61YLGlV',
#     'lat': 43.54399,
#     'lng': -79.666778,
#     'price': '0.95M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7455, 43.43008]},
#    'properties': {'id_listing': '0ZxwR7MDg4ZyKabB',
#     'lat': 43.43008,
#     'lng': -79.7455,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.713641, 43.550025]},
#    'properties': {'id_listing': 'gaQmD7zZb2L7J9Bo',
#     'lat': 43.550025,
#     'lng': -79.713641,
#     'price': '0.31M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64844, 43.52844]},
#    'properties': {'id_listing': 'knbq6y1xn4jYo9DA',
#     'lat': 43.52844,
#     'lng': -79.64844,
#     'price': '0.37M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67404, 43.53884]},
#    'properties': {'id_listing': 'owJKR7PmgEX3XeLP',
#     'lat': 43.53884,
#     'lng': -79.67404,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70007, 43.47631]},
#    'properties': {'id_listing': 'damgL7A0JZ2yZ1MW',
#     'lat': 43.47631,
#     'lng': -79.70007,
#     'price': '0.95M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76224, 43.44499]},
#    'properties': {'id_listing': 'owJKR7PmgrO3XeLP',
#     'lat': 43.44499,
#     'lng': -79.76224,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6676, 43.52196]},
#    'properties': {'id_listing': 'BXeEn7XVgnGYrPo8',
#     'lat': 43.52196,
#     'lng': -79.6676,
#     'price': '0.79M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72869, 43.48543]},
#    'properties': {'id_listing': 'b1DBW7REa1LyqlAp',
#     'lat': 43.48543,
#     'lng': -79.72869,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72758, 43.48007]},
#    'properties': {'id_listing': 'owJKR7Pmgn13XeLP',
#     'lat': 43.48007,
#     'lng': -79.72758,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68037, 43.45035]},
#    'properties': {'id_listing': 'xmZRW7ngZod3EBO9',
#     'lat': 43.45035,
#     'lng': -79.68037,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71463, 43.53211]},
#    'properties': {'id_listing': 'damgL7A0JvlyZ1MW',
#     'lat': 43.53211,
#     'lng': -79.71463,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69405, 43.43521]},
#    'properties': {'id_listing': '0ZxwR7MDgJmyKabB',
#     'lat': 43.43521,
#     'lng': -79.69405,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'id_listing': 'owJKR7PmJGD3XeLP',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71617, 43.48161]},
#    'properties': {'id_listing': 'BGMnKYqG4PR7w1Qr',
#     'lat': 43.48161,
#     'lng': -79.71617,
#     'price': '0.57M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70815, 43.41683]},
#    'properties': {'id_listing': 'BDO1w3W6XBO78Jg0',
#     'lat': 43.41683,
#     'lng': -79.70815,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.749054, 43.47361]},
#    'properties': {'id_listing': '0Zaw5YovpvD3n961',
#     'lat': 43.47361,
#     'lng': -79.749054,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68555, 43.4486]},
#    'properties': {'id_listing': 'kbEDRYadKE131VaB',
#     'lat': 43.4486,
#     'lng': -79.68555,
#     'price': '0.29M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70089, 43.54087]},
#    'properties': {'id_listing': '5xLkv3VqQ8z7DBNr',
#     'lat': 43.54087,
#     'lng': -79.70089,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72787, 43.47849]},
#    'properties': {'id_listing': 'oK8OgYBNEAjYJmG2',
#     'lat': 43.47849,
#     'lng': -79.72787,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72787, 43.47849]},
#    'properties': {'id_listing': 'DnM697kNlqOybmwe',
#     'lat': 43.47849,
#     'lng': -79.72787,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71522, 43.44482]},
#    'properties': {'id_listing': 'dXawjy4PqgpyrR18',
#     'lat': 43.44482,
#     'lng': -79.71522,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70081, 43.49379]},
#    'properties': {'id_listing': 'L5VXv3l4lDp3j2q8',
#     'lat': 43.49379,
#     'lng': -79.70081,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69919, 43.48067]},
#    'properties': {'id_listing': '5xLkv3VqQmQ7DBNr',
#     'lat': 43.48067,
#     'lng': -79.69919,
#     'price': '0.94M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70486, 43.49656]},
#    'properties': {'id_listing': 'NAKv53DeQJkYMnxB',
#     'lat': 43.49656,
#     'lng': -79.70486,
#     'price': '1M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76821, 43.4346]},
#    'properties': {'id_listing': '2Z5BX32WQg4YDar0',
#     'lat': 43.4346,
#     'lng': -79.76821,
#     'price': '0.78M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69743, 43.42382]},
#    'properties': {'id_listing': '6VLaGyGo6nvyW1ZD',
#     'lat': 43.42382,
#     'lng': -79.69743,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
# ...
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76316, 43.43473]},
#    'properties': {'id_listing': 'L4KAX7NzEko7eRPJ',
#     'lat': 43.43473,
#     'lng': -79.76316,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71345, 43.49226]},
#    'properties': {'id_listing': 'mLzQ1y5kLmq3qdeK',
#     'lat': 43.49226,
#     'lng': -79.71345,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72326, 43.54358]},
#    'properties': {'id_listing': 'L4KAX7NzEVV7eRPJ',
#     'lat': 43.54358,
#     'lng': -79.72326,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69991, 43.52558]},
#    'properties': {'id_listing': 'PXRla7g1wgRYjEvL',
#     'lat': 43.52558,
#     'lng': -79.69991,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71233, 43.46298]},
#    'properties': {'id_listing': 'JjAXw7QZX0a3QOzg',
#     'lat': 43.46298,
#     'lng': -79.71233,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68772, 43.4883]},
#    'properties': {'id_listing': 'damgL7A02EmyZ1MW',
#     'lat': 43.4883,
#     'lng': -79.68772,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71504, 43.46714]},
#    'properties': {'id_listing': 'BDO1w3W6Wxn78Jg0',
#     'lat': 43.46714,
#     'lng': -79.71504,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73777, 43.555]},
#    'properties': {'id_listing': '5xLkv3VqxOz7DBNr',
#     'lat': 43.555,
#     'lng': -79.73777,
#     'price': '0.88M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73658, 43.48242]},
#    'properties': {'id_listing': 'BXeEn7XVPAMYrPo8',
#     'lat': 43.48242,
#     'lng': -79.73658,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70187, 43.43167]},
#    'properties': {'id_listing': 'EeVbOYEg90d7x2P0',
#     'lat': 43.43167,
#     'lng': -79.70187,
#     'price': '0.79M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72723, 43.47088]},
#    'properties': {'id_listing': 'BXeEn7XVPOGYrPo8',
#     'lat': 43.47088,
#     'lng': -79.72723,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70785, 43.41994]},
#    'properties': {'id_listing': 'PXRla7g1wQ5YjEvL',
#     'lat': 43.41994,
#     'lng': -79.70785,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70495, 43.42067]},
#    'properties': {'id_listing': 'b1DBW7REq8LyqlAp',
#     'lat': 43.42067,
#     'lng': -79.70495,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70466, 43.46072]},
#    'properties': {'id_listing': '0Zaw5Yov2j63n961',
#     'lat': 43.46072,
#     'lng': -79.70466,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69539, 43.48794]},
#    'properties': {'id_listing': 'PXRla7g1wBPYjEvL',
#     'lat': 43.48794,
#     'lng': -79.69539,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69064, 43.55331]},
#    'properties': {'id_listing': 'RdXze3e81eM78m9K',
#     'lat': 43.55331,
#     'lng': -79.69064,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.729164, 43.486584]},
#    'properties': {'id_listing': 'dXawjy4PBZgyrR18',
#     'lat': 43.486584,
#     'lng': -79.729164,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69174, 43.46833]},
#    'properties': {'id_listing': 'jJKdOYra8Bz354lW',
#     'lat': 43.46833,
#     'lng': -79.69174,
#     'price': '0.82M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76222, 43.43793]},
#    'properties': {'id_listing': '02Zpj39wLKdyDrK8',
#     'lat': 43.43793,
#     'lng': -79.76222,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74831, 43.4377]},
#    'properties': {'id_listing': 'ZNkKJ3J5r5G7d4V6',
#     'lat': 43.4377,
#     'lng': -79.74831,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73889, 43.55121]},
#    'properties': {'id_listing': 'gJRv53K20227VPW4',
#     'lat': 43.55121,
#     'lng': -79.73889,
#     'price': '0.88M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73306, 43.47463]},
#    'properties': {'id_listing': 'MB5bO3xMPklYkWVP',
#     'lat': 43.47463,
#     'lng': -79.73306,
#     'price': '0.97M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68987, 43.48414]},
#    'properties': {'id_listing': 'gJRv53K20ZX7VPW4',
#     'lat': 43.48414,
#     'lng': -79.68987,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70948, 43.41708]},
#    'properties': {'id_listing': '510QqypoXB6YLGlV',
#     'lat': 43.41708,
#     'lng': -79.70948,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69256, 43.53808]},
#    'properties': {'id_listing': 'EeVbOYEg1mn7x2P0',
#     'lat': 43.53808,
#     'lng': -79.69256,
#     'price': '0.83M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69396, 43.46541]},
#    'properties': {'id_listing': '0MWBVyZBNmbyKemj',
#     'lat': 43.46541,
#     'lng': -79.69396,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77046, 43.43332]},
#    'properties': {'id_listing': '02Zpj39wodqyDrK8',
#     'lat': 43.43332,
#     'lng': -79.77046,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6652, 43.53118]},
#    'properties': {'id_listing': 'BDO1w3W6w5w78Jg0',
#     'lat': 43.53118,
#     'lng': -79.6652,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72892, 43.4757]},
#    'properties': {'id_listing': 'weQp5yOMjB13d0ZE',
#     'lat': 43.4757,
#     'lng': -79.72892,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.715466, 43.494439]},
#    'properties': {'id_listing': 'BGMnKYqGq817w1Qr',
#     'lat': 43.494439,
#     'lng': -79.715466,
#     'price': '0.97M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.733566, 43.484254]},
#    'properties': {'id_listing': 'EeVbOYEg1vd7x2P0',
#     'lat': 43.484254,
#     'lng': -79.733566,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68885, 43.41963]},
#    'properties': {'id_listing': '0J6Em7bwdqQ3XBeq',
#     'lat': 43.41963,
#     'lng': -79.68885,
#     'price': '3.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76122, 43.43097]},
#    'properties': {'id_listing': '02Zpj39wonOyDrK8',
#     'lat': 43.43097,
#     'lng': -79.76122,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72819, 43.4787]},
#    'properties': {'id_listing': 'VaD6p78dPVz7wRQr',
#     'lat': 43.4787,
#     'lng': -79.72819,
#     'price': '0.52M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67994, 43.43673]},
#    'properties': {'id_listing': 'ZNkKJ3J5rjm7d4V6',
#     'lat': 43.43673,
#     'lng': -79.67994,
#     'price': '0.77M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73445, 43.48099]},
#    'properties': {'id_listing': 'jJKdOYra6kZ354lW',
#     'lat': 43.48099,
#     'lng': -79.73445,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74203, 43.47165]},
#    'properties': {'id_listing': 'BDO1w3W6wbV78Jg0',
#     'lat': 43.47165,
#     'lng': -79.74203,
#     'price': '1.1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72156, 43.4645]},
#    'properties': {'id_listing': '0ZxwR7MDagmyKabB',
#     'lat': 43.4645,
#     'lng': -79.72156,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72905, 43.44935]},
#    'properties': {'id_listing': 'L5VXv3l40Zg3j2q8',
#     'lat': 43.44935,
#     'lng': -79.72905,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69044, 43.49219]},
#    'properties': {'id_listing': 'weQp5yOMjKb3d0ZE',
#     'lat': 43.49219,
#     'lng': -79.69044,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73996, 43.47367]},
#    'properties': {'id_listing': 'VaD6p78dP2V7wRQr',
#     'lat': 43.47367,
#     'lng': -79.73996,
#     'price': '0.9M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71017, 43.47294]},
#    'properties': {'id_listing': 'xmZRW7ngRdM3EBO9',
#     'lat': 43.47294,
#     'lng': -79.71017,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70768, 43.41818]},
#    'properties': {'id_listing': 'BDO1w3W6wNn78Jg0',
#     'lat': 43.41818,
#     'lng': -79.70768,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7482, 43.46843]},
#    'properties': {'id_listing': 'ZNkKJ3J5raZ7d4V6',
#     'lat': 43.46843,
#     'lng': -79.7482,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.708193, 43.478633]},
#    'properties': {'id_listing': 'dXawjy4PlLNyrR18',
#     'lat': 43.478633,
#     'lng': -79.708193,
#     'price': '0.87M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73875, 43.43945]},
#    'properties': {'id_listing': '02Zpj39wDedyDrK8',
#     'lat': 43.43945,
#     'lng': -79.73875,
#     'price': '0.38M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65617, 43.52812]},
#    'properties': {'id_listing': 'NAKv53DeWRVYMnxB',
#     'lat': 43.52812,
#     'lng': -79.65617,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66137, 43.45136]},
#    'properties': {'id_listing': 'VaD6p78dDM07wRQr',
#     'lat': 43.45136,
#     'lng': -79.66137,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65618, 43.52807]},
#    'properties': {'id_listing': 'obqB176Km2n3ZajD',
#     'lat': 43.52807,
#     'lng': -79.65618,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68322, 43.4757]},
#    'properties': {'id_listing': 'x9w8o3meGVo3GKjm',
#     'lat': 43.4757,
#     'lng': -79.68322,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69968, 43.49757]},
#    'properties': {'id_listing': 'r56k97wzODRyKRjD',
#     'lat': 43.49757,
#     'lng': -79.69968,
#     'price': '1.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76286, 43.428]},
#    'properties': {'id_listing': 'JjAXw7QZ9md3QOzg',
#     'lat': 43.428,
#     'lng': -79.76286,
#     'price': '0.72M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69743, 43.43195]},
#    'properties': {'id_listing': 'N0A9X3j0GD4yvgxV',
#     'lat': 43.43195,
#     'lng': -79.69743,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'}}]}

# %%
output = open(out_file, 'w')
json.dump(geojson, output)

# %%
geojson
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.68754, 43.44757]}, 'properties': {'id_listing': 'xmZRW7ng8r13EBO9', 'lat': 43.44757, 'lng': -79.68754, 'price': '0.73M', 'house_type': 'C', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.69413, 43.4577]}, 'properties': {'id_listing': 'VaD6p78dWm67wRQr', 'lat': 43.4577, 'lng': -79.69413, 'price': '2.5M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.67404, 43.53884]}, 'properties': {'id_listing': 'MB5bO3xMOdkYkWVP', 'lat': 43.53884, 'lng': -79.67404, 'price': '0.64M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.74829, 43.430661]}, 'properties': {'id_listing': '6VLaGyGoQPjyW1ZD', 'lat': 43.430661, 'lng': -79.74829, 'price': '0.7M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.73638, 43.47901]}, 'properties': {'id_listing': '6VLaGyGoQkJyW1ZD', 'lat': 43.47901, 'lng': -79.73638, 'price': '1.2M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.76425, 43.44629]}, 'properties': {'id_listing': 'jJKdOYraRGK354lW', 'lat': 43.44629, 'lng': -79.76425, 'price': '0.8M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.68056, 43.43847]}, 'properties': {'id_listing': 'VaD6p78dW1z7wRQr', 'lat': 43.43847, 'lng': -79.68056, 'price': '1.2M', 'house_type': 'D', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.65332, 43.51203]}, 'properties': {'id_listing': 'VgAaOyL9O8Z7GxMb', 'lat': 43.51203, 'lng': -79.65332, 'price': '0.76M', 'house_type': 'S', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.66456, 43.46292]}, 'properties': {'id_listing': 'b1DBW7REKDLyqlAp', 'lat': 43.46292, 'lng': -79.66456, 'price': '2.8M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.73195, 43.5458]}, 'properties': {'id_listing': 'BDO1w3W6Lqd78Jg0', 'lat': 43.5458, 'lng': -79.73195, 'price': '1.5M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.67545, 43.51929]}, 'properties': {'id_listing': '5xLkv3Vqn9O7DBNr', 'lat': 43.51929, 'lng': -79.67545, 'price': '0.93M', 'house_type': 'D', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.73692, 43.45277]}, 'properties': {'id_listing': 'JjAXw7QZkwX3QOzg', 'lat': 43.45277, 'lng': -79.73692, 'price': '0.85M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.67024, 43.46015]}, 'properties': {'id_listing': 'gaQmD7zZMz97J9Bo', 'lat': 43.46015, 'lng': -79.67024, 'price': '1.3M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.67685, 43.55473]}, 'properties': {'id_listing': 'BDO1w3W6jBV78Jg0', 'lat': 43.55473, 'lng': -79.67685, 'price': '2.7M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}}, {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-79.72874, 43.44389]}, 'properties': {'id_listing': 'x9w8o3meMeV3GKjm', 'lat': 43.44389, 'lng': -79.72874, 'price': '0.73M', 'house_type': 'C', 'flg_idx': 0, 'flg_disp_addr': 1,  ...
