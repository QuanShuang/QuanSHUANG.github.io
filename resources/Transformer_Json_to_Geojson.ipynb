# %%
from sys import argv
from os.path import exists
import simplejson as json 
import pandas as pd
import pprint

# %%
# !pip install simplejson
# Out:
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/e3/24/c35fb1c1c315fc0fffe61ea00d3f88e85469004713dab488dee4f35b0aff/simplejson-3.16.0.tar.gz (81kB)
# Building wheels for collected packages: simplejson
#   Running setup.py bdist_wheel for simplejson: started
#   Running setup.py bdist_wheel for simplejson: finished with status 'done'
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\5d\1a\1e\0350bb3df3e74215cd91325344cc86c2c691f5306eb4d22c77
# Successfully built simplejson
# Installing collected packages: simplejson
# Successfully installed simplejson-3.16.0

# %%
script, in_file, out_file = argv
data = json.load(open("listing1.json"))
# data = json.load(open(in_file))

# data2 = json.load(open("rent.json"))

# %%
data
# Out:
# {'status': True,
#  'data': {'message': '',
#   'list': [{'id_listing': 'N0A9X3j0OlDyvgxV',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.42M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwBkg3XBeq',
#     'lat': 43.377062,
#     'lng': -79.809363,
#     'price': '0.39M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wxXnyDrK8',
#     'lat': 43.47599,
#     'lng': -79.68764,
#     'price': '0.68M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqkKR7DBNr',
#     'lat': 43.24459,
#     'lng': -79.79985,
#     'price': '0.35M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwBNg3XBeq',
#     'lat': 43.53379,
#     'lng': -79.85404,
#     'price': '0.8M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBwnqyKemj',
#     'lat': 43.36588,
#     'lng': -79.75671,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6KJq78Jg0',
#     'lat': 43.27235,
#     'lng': -79.97164,
#     'price': '1.3M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOM6zv3d0ZE',
#     'lat': 43.47998,
#     'lng': -79.71286,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqkzR7DBNr',
#     'lat': 43.47976,
#     'lng': -79.72747,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVJzvYrPo8',
#     'lat': 43.36526,
#     'lng': -79.73485,
#     'price': '0.7M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0OmdyvgxV',
#     'lat': 43.47998,
#     'lng': -79.71286,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBwzbyKemj',
#     'lat': 43.482696,
#     'lng': -79.689924,
#     'price': '0.66M',
#     'house_type': None,
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOM65g3d0ZE',
#     'lat': 43.2739,
#     'lng': -79.99203,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3Vqk5Q7DBNr',
#     'lat': 43.28862,
#     'lng': -80.13745,
#     'price': '0.87M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNnGjYJmG2',
#     'lat': 43.1821,
#     'lng': -79.77823,
#     'price': '0.66M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0OxwyvgxV',
#     'lat': 43.37113,
#     'lng': -79.82134,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wxGqyDrK8',
#     'lat': 43.5103,
#     'lng': -79.83702,
#     'price': '0.76M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGopGKyW1ZD',
#     'lat': 43.3905,
#     'lng': -79.78066,
#     'price': '0.62M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xEWBYo9DA',
#     'lat': 43.49255,
#     'lng': -79.86242,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNxKOybmwe',
#     'lat': 43.5263,
#     'lng': -79.70822,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6K2j78Jg0',
#     'lat': 43.408,
#     'lng': -79.79202,
#     'price': '0.63M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xM14LYkWVP',
#     'lat': 43.41322,
#     'lng': -79.69987,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNn4jYJmG2',
#     'lat': 43.48328,
#     'lng': -79.72774,
#     'price': '0.88M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vD8NDY5mGN',
#     'lat': 43.46221,
#     'lng': -79.69245,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4WWV3j2q8',
#     'lat': 43.47849,
#     'lng': -79.72787,
#     'price': '0.51M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dOO67wRQr',
#     'lat': 43.31159,
#     'lng': -79.85467,
#     'price': '0.93M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6KKw78Jg0',
#     'lat': 43.39677,
#     'lng': -79.80351,
#     'price': '0.97M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGJJ57w1Qr',
#     'lat': 43.39316,
#     'lng': -79.78841,
#     'price': '0.34M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBwG5yKemj',
#     'lat': 43.22153,
#     'lng': -79.89911,
#     'price': '0.45M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDXGeyKabB',
#     'lat': 43.20268,
#     'lng': -79.77122,
#     'price': '0.72M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZrBr7J9Bo',
#     'lat': 43.23302,
#     'lng': -79.90379,
#     'price': '0.54M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53De8LwYMnxB',
#     'lat': 43.53769,
#     'lng': -79.66444,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kqXj3qdeK',
#     'lat': 43.37034,
#     'lng': -79.73186,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'kbEDRYadr9b31VaB',
#     'lat': 43.44219,
#     'lng': -79.72199,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5Ej17d4V6',
#     'lat': 43.34319,
#     'lng': -79.76725,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmVPG3XeLP',
#     'lat': 43.40169,
#     'lng': -79.71704,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1qkgYjEvL',
#     'lat': 43.24976,
#     'lng': -79.93874,
#     'price': '0.72M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoK1aYLGlV',
#     'lat': 43.223106,
#     'lng': -79.723435,
#     'price': '0.65M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzlVGyKRjD',
#     'lat': 43.42835,
#     'lng': -79.74678,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLRWK75eZE',
#     'lat': 43.55005,
#     'lng': -79.73034,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmVwG3XeLP',
#     'lat': 43.12604,
#     'lng': -79.79708,
#     'price': '0.96M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xM1bkYkWVP',
#     'lat': 43.32108,
#     'lng': -79.82243,
#     'price': '0.75M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqkjZ7DBNr',
#     'lat': 43.47912,
#     'lng': -79.6787,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgl6d7x2P0',
#     'lat': 43.23201,
#     'lng': -79.96404,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0wB5yZ1MW',
#     'lat': 43.07191,
#     'lng': -79.9318,
#     'price': '0.5M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGJMK7w1Qr',
#     'lat': 43.43834,
#     'lng': -79.69301,
#     'price': '1.5M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dOZz7wRQr',
#     'lat': 43.49104,
#     'lng': -79.86374,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9QJZ7GxMb',
#     'lat': 43.3842,
#     'lng': -79.7144,
#     'price': '2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVJgGYrPo8',
#     'lat': 43.206551,
#     'lng': -79.87049,
#     'price': '0.43M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEglLO7x2P0',
#     'lat': 43.327507,
#     'lng': -79.899968,
#     'price': '0.61M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBwRkyKemj',
#     'lat': 43.50472,
#     'lng': -79.88244,
#     'price': '0.54M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WRQOYDar0',
#     'lat': 43.43578,
#     'lng': -79.73501,
#     'price': '0.41M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLRwv75eZE',
#     'lat': 43.37902,
#     'lng': -79.80261,
#     'price': '0.37M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNxl6ybmwe',
#     'lat': 43.36803,
#     'lng': -79.82602,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vD8q8Y5mGN',
#     'lat': 43.188316,
#     'lng': -79.779993,
#     'price': '0.61M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOM6Lw3d0ZE',
#     'lat': 43.25233,
#     'lng': -79.82657,
#     'price': '0.54M',
#     'house_type': None,
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGJjb7w1Qr',
#     'lat': 43.1825,
#     'lng': -79.79444,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REx2EyqlAp',
#     'lat': 43.4671,
#     'lng': -79.72688,
#     'price': '0.89M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0O8EyvgxV',
#     'lat': 43.38457,
#     'lng': -79.81002,
#     'price': '0.8M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDX0myKabB',
#     'lat': 43.21843,
#     'lng': -79.90217,
#     'price': '0.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZre97J9Bo',
#     'lat': 43.2397,
#     'lng': -79.81631,
#     'price': '0.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vD8n8Y5mGN',
#     'lat': 43.46366,
#     'lng': -79.7072,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8Qpv78m9K',
#     'lat': 43.46408,
#     'lng': -79.66574,
#     'price': '2.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZOQM3QOzg',
#     'lat': 43.07048,
#     'lng': -79.9297,
#     'price': '0.52M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNnR4YJmG2',
#     'lat': 43.12143,
#     'lng': -79.80062,
#     'price': '0.65M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwB4B3XBeq',
#     'lat': 43.126597,
#     'lng': -79.809062,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53De8XVYMnxB',
#     'lat': 43.53029,
#     'lng': -79.86741,
#     'price': '0.8M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kq8m3qdeK',
#     'lat': 43.52869,
#     'lng': -79.69538,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'kbEDRYadr4l31VaB',
#     'lat': 43.47078,
#     'lng': -79.74221,
#     'price': '0.86M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGopVAyW1ZD',
#     'lat': 43.48079,
#     'lng': -79.87246,
#     'price': '0.78M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dOo07wRQr',
#     'lat': 43.24735,
#     'lng': -79.83519,
#     'price': '0.59M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngPXa3EBO9',
#     'lat': 43.51358,
#     'lng': -79.85883,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4WbO3j2q8',
#     'lat': 43.503877,
#     'lng': -79.849924,
#     'price': '0.75M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVJRdYrPo8',
#     'lat': 43.46392,
#     'lng': -79.73621,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZOVz3QOzg',
#     'lat': 43.347762,
#     'lng': -79.80624,
#     'price': '0.62M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDXQ9yKabB',
#     'lat': 43.50573,
#     'lng': -79.85437,
#     'price': '0.94M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzlaRyKRjD',
#     'lat': 43.40401,
#     'lng': -79.82625,
#     'price': '0.92M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZOXd3QOzg',
#     'lat': 43.340652,
#     'lng': -79.877928,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgl9r7x2P0',
#     'lat': 43.53529,
#     'lng': -79.7094,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmVQD3XeLP',
#     'lat': 43.44067,
#     'lng': -79.75444,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOM6RQ3d0ZE',
#     'lat': 43.45734,
#     'lng': -79.70499,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDXa2yKabB',
#     'lat': 43.44662,
#     'lng': -79.7639,
#     'price': '0.77M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZrAZ7J9Bo',
#     'lat': 43.44067,
#     'lng': -79.75444,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53De8pEYMnxB',
#     'lat': 43.45734,
#     'lng': -79.70499,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4W0x3j2q8',
#     'lat': 43.24942,
#     'lng': -79.86471,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngPRM3EBO9',
#     'lat': 43.26244,
#     'lng': -79.93599,
#     'price': '0.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOM6jQ3d0ZE',
#     'lat': 43.44662,
#     'lng': -79.7639,
#     'price': '0.77M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLRrP75eZE',
#     'lat': 43.23127,
#     'lng': -79.68375,
#     'price': '0.56M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzl5OyKRjD',
#     'lat': 43.45002,
#     'lng': -79.73167,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwBag3XBeq',
#     'lat': 43.2561,
#     'lng': -79.84007,
#     'price': '0.45M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZrO17J9Bo',
#     'lat': 43.42657,
#     'lng': -79.76635,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5Yovka23n961',
#     'lat': 43.27045,
#     'lng': -79.9456,
#     'price': '0.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7Nzqdd7eRPJ',
#     'lat': 43.54454,
#     'lng': -79.64674,
#     'price': '5.4M',
#     'house_type': None,
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYradrB354lW',
#     'lat': 43.39867,
#     'lng': -79.71119,
#     'price': '2.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypoK05YLGlV',
#     'lat': 43.53307,
#     'lng': -79.79336,
#     'price': '0.68M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNxodybmwe',
#     'lat': 43.53389,
#     'lng': -79.86125,
#     'price': '0.63M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVJrvYrPo8',
#     'lat': 43.5091,
#     'lng': -79.85453,
#     'price': '0.62M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLRKX75eZE',
#     'lat': 43.48017,
#     'lng': -79.72634,
#     'price': '0.53M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmV9M3XeLP',
#     'lat': 43.37713,
#     'lng': -79.80026,
#     'price': '0.42M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGJxj7w1Qr',
#     'lat': 43.20922,
#     'lng': -79.84317,
#     'price': '0.33M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PXNpyrR18',
#     'lat': 43.52614,
#     'lng': -79.84948,
#     'price': '0.61M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30O2eg7OklN',
#     'lat': 43.518985,
#     'lng': -79.868853,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYrad0P354lW',
#     'lat': 43.543954,
#     'lng': -79.666816,
#     'price': '1.4M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kqpE3qdeK',
#     'lat': 43.35347,
#     'lng': -79.76614,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5Yovk543n961',
#     'lat': 43.318745,
#     'lng': -79.804928,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dO1J7wRQr',
#     'lat': 43.37462,
#     'lng': -79.81651,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9Q8z7GxMb',
#     'lat': 43.47611,
#     'lng': -79.72793,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmV8B3XeLP',
#     'lat': 43.227768,
#     'lng': -79.846856,
#     'price': '0.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVJ60YrPo8',
#     'lat': 43.43609,
#     'lng': -79.68269,
#     'price': '1.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7RExDQyqlAp',
#     'lat': 43.42967,
#     'lng': -79.76313,
#     'price': '0.74M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0w42yZ1MW',
#     'lat': 43.0601,
#     'lng': -79.90189,
#     'price': '0.69M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3Vqk9p7DBNr',
#     'lat': 43.19958,
#     'lng': -79.79181,
#     'price': '0.37M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGJp57w1Qr',
#     'lat': 43.33987,
#     'lng': -79.79558,
#     'price': '0.89M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEglp57x2P0',
#     'lat': 43.42302,
#     'lng': -79.77904,
#     'price': '1.2M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0OR1yvgxV',
#     'lat': 43.35321,
#     'lng': -79.81417,
#     'price': '0.65M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kqZw3qdeK',
#     'lat': 43.48242,
#     'lng': -79.73658,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'kbEDRYadrOP31VaB',
#     'lat': 43.33841,
#     'lng': -79.84026,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGopNvyW1ZD',
#     'lat': 43.44104,
#     'lng': -79.7145,
#     'price': '0.79M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wzlQ6yKRjD',
#     'lat': 43.486912,
#     'lng': -79.86388,
#     'price': '0.67M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVkXMYrPo8',
#     'lat': 43.26074,
#     'lng': -79.94189,
#     'price': '0.4M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDR2eyKabB',
#     'lat': 43.47976,
#     'lng': -79.72747,
#     'price': '0.51M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kRAj3qdeK',
#     'lat': 43.39805,
#     'lng': -79.70949,
#     'price': '1.1M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVklMYrPo8',
#     'lat': 43.181023,
#     'lng': -79.771894,
#     'price': '1.1M',
#     'house_type': None,
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZ6Km3QOzg',
#     'lat': 43.25263,
#     'lng': -79.92425,
#     'price': '0.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMXPB3d0ZE',
#     'lat': 43.43026,
#     'lng': -79.76208,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGK6K7w1Qr',
#     'lat': 43.4961,
#     'lng': -79.87876,
#     'price': '0.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgnRO7x2P0',
#     'lat': 43.38725,
#     'lng': -79.82275,
#     'price': '0.76M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'kbEDRYad1vN31VaB',
#     'lat': 43.21515,
#     'lng': -79.65008,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGo8XJyW1ZD',
#     'lat': 43.21251,
#     'lng': -79.64859,
#     'price': '0.71M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqpO3XeLP',
#     'lat': 43.34134,
#     'lng': -79.8872,
#     'price': '0.79M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgnPO7x2P0',
#     'lat': 43.22922,
#     'lng': -79.68143,
#     'price': '0.55M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meWk23GKjm',
#     'lat': 43.25883,
#     'lng': -79.84902,
#     'price': '0.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovPJ03n961',
#     'lat': 43.12656,
#     'lng': -79.81118,
#     'price': '0.45M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1XV5YjEvL',
#     'lat': 43.32722,
#     'lng': -79.919133,
#     'price': '0.65M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzQlO7eRPJ',
#     'lat': 43.25726,
#     'lng': -79.82334,
#     'price': '0.29M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6PZo78Jg0',
#     'lat': 43.49104,
#     'lng': -79.86374,
#     'price': '0.7M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KQ063ZajD',
#     'lat': 43.36406,
#     'lng': -79.84218,
#     'price': '0.88M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0K9nyZ1MW',
#     'lat': 43.5294,
#     'lng': -79.83552,
#     'price': '0.76M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KQ0a3ZajD',
#     'lat': 43.2258,
#     'lng': -79.73242,
#     'price': '0.5M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'b1DBW7REVZ1yqlAp',
#     'lat': 43.50586,
#     'lng': -79.84315,
#     'price': '0.64M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBJZkyKemj',
#     'lat': 43.48545,
#     'lng': -79.86932,
#     'price': '0.89M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wz8d8yKRjD',
#     'lat': 43.43079,
#     'lng': -79.76627,
#     'price': '0.75M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwpMG3XBeq',
#     'lat': 43.37781,
#     'lng': -79.80285,
#     'price': '0.32M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDLd8Y5mGN',
#     'lat': 43.47849,
#     'lng': -79.72787,
#     'price': '0.51M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wz8wxyKRjD',
#     'lat': 43.2709,
#     'lng': -79.97193,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLEMk75eZE',
#     'lat': 43.45184,
#     'lng': -79.6848,
#     'price': '0.36M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwpgB3XBeq',
#     'lat': 43.24994,
#     'lng': -79.81506,
#     'price': '0.37M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wz89QyKRjD',
#     'lat': 43.22323,
#     'lng': -79.70624,
#     'price': '0.58M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGKee7w1Qr',
#     'lat': 43.38147,
#     'lng': -79.73636,
#     'price': '0.96M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNJk4YJmG2',
#     'lat': 43.34548,
#     'lng': -79.89505,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PEoByrR18',
#     'lat': 43.49951,
#     'lng': -79.69902,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzQ0r7eRPJ',
#     'lat': 43.53775,
#     'lng': -79.6611,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wz8RQyKRjD',
#     'lat': 43.24032,
#     'lng': -79.72559,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqOp3XeLP',
#     'lat': 43.49309,
#     'lng': -79.70544,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0Kr9yZ1MW',
#     'lat': 43.42998,
#     'lng': -79.74851,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMXVb3d0ZE',
#     'lat': 43.42473,
#     'lng': -79.69121,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDRz9yKabB',
#     'lat': 43.53059,
#     'lng': -79.71087,
#     'price': '0.99M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39w62kyDrK8',
#     'lat': 43.487889,
#     'lng': -79.731719,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDLmrY5mGN',
#     'lat': 43.42302,
#     'lng': -79.77904,
#     'price': '1.2M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1XmGYjEvL',
#     'lat': 43.34114,
#     'lng': -79.79851,
#     'price': '0.94M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzQoz7eRPJ',
#     'lat': 43.39898,
#     'lng': -79.82651,
#     'price': '0.88M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7Pmqov3XeLP',
#     'lat': 43.40686,
#     'lng': -79.80041,
#     'price': '0.82M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMXoG3d0ZE',
#     'lat': 43.50005,
#     'lng': -79.88569,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9EvO7GxMb',
#     'lat': 43.52586,
#     'lng': -79.84883,
#     'price': '0.5M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'r56k97wz8EOyKRjD',
#     'lat': 43.25393,
#     'lng': -79.85414,
#     'price': '0.5M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNJn5YJmG2',
#     'lat': 43.324,
#     'lng': -79.90014,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwpBg3XBeq',
#     'lat': 43.18072,
#     'lng': -79.809708,
#     'price': '0.56M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meWAz3GKjm',
#     'lat': 43.21361,
#     'lng': -80.01308,
#     'price': '0.65M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OZ2J7OklN',
#     'lat': 43.20658,
#     'lng': -79.98943,
#     'price': '0.66M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KQQK3ZajD',
#     'lat': 43.48556,
#     'lng': -79.70004,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBJJbyKemj',
#     'lat': 43.42035,
#     'lng': -79.9325,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNOvdybmwe',
#     'lat': 43.51193,
#     'lng': -79.83486,
#     'price': '0.82M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovPb23n961',
#     'lat': 43.55006,
#     'lng': -79.72084,
#     'price': '0.73M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqwB3XeLP',
#     'lat': 43.37688,
#     'lng': -79.808237,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meWMJ3GKjm',
#     'lat': 43.52567,
#     'lng': -79.7056,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNO6Oybmwe',
#     'lat': 43.25388,
#     'lng': -79.80505,
#     'price': '0.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqLB3XeLP',
#     'lat': 43.46557,
#     'lng': -79.73968,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMXng3d0ZE',
#     'lat': 43.25944,
#     'lng': -79.83779,
#     'price': '0.45M',
#     'house_type': None,
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqLX3XeLP',
#     'lat': 43.45711,
#     'lng': -79.67161,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2rg47VPW4',
#     'lat': 43.49748,
#     'lng': -79.70506,
#     'price': '1M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDLgpY5mGN',
#     'lat': 43.47182,
#     'lng': -79.69363,
#     'price': '0.59M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOMXL13d0ZE',
#     'lat': 43.45164,
#     'lng': -79.75248,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KQrM3ZajD',
#     'lat': 43.41867,
#     'lng': -79.70771,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0VgmyvgxV',
#     'lat': 43.39398,
#     'lng': -79.71304,
#     'price': '1.2M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dq9k7wRQr',
#     'lat': 43.21867,
#     'lng': -79.95583,
#     'price': '0.82M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgnxd7x2P0',
#     'lat': 43.36061,
#     'lng': -79.98386,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqA0e7DBNr',
#     'lat': 43.212157,
#     'lng': -79.893932,
#     'price': '0.48M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KQx63ZajD',
#     'lat': 43.22579,
#     'lng': -79.76464,
#     'price': '0.55M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVk0GYrPo8',
#     'lat': 43.25167,
#     'lng': -79.77883,
#     'price': '0.57M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DewB6YMnxB',
#     'lat': 43.48233,
#     'lng': -79.85224,
#     'price': '0.56M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqAOe7DBNr',
#     'lat': 43.48598,
#     'lng': -79.83788,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwp483XBeq',
#     'lat': 43.45495,
#     'lng': -79.70453,
#     'price': '0.83M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDRkkyKabB',
#     'lat': 43.48745,
#     'lng': -79.88499,
#     'price': '0.66M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraJNK354lW',
#     'lat': 43.23785,
#     'lng': -79.71506,
#     'price': '1.3M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dq2z7wRQr',
#     'lat': 43.32443,
#     'lng': -79.79746,
#     'price': '1.1M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVkxGYrPo8',
#     'lat': 43.54848,
#     'lng': -79.71699,
#     'price': '0.61M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqAVO7DBNr',
#     'lat': 43.47164,
#     'lng': -79.68381,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVkxEYrPo8',
#     'lat': 43.31814,
#     'lng': -79.8384,
#     'price': '0.55M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kRLd3qdeK',
#     'lat': 43.22397,
#     'lng': -79.66272,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1XwXYjEvL',
#     'lat': 43.19506,
#     'lng': -79.84556,
#     'price': '0.58M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8R1v78m9K',
#     'lat': 43.26598,
#     'lng': -79.8776,
#     'price': '0.52M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraJ8Z354lW',
#     'lat': 43.24226,
#     'lng': -79.81165,
#     'price': '0.29M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqQ13XeLP',
#     'lat': 43.54456,
#     'lng': -79.73598,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMladYkWVP',
#     'lat': 43.52261,
#     'lng': -79.69558,
#     'price': '0.72M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgn1R7x2P0',
#     'lat': 43.38436,
#     'lng': -79.80947,
#     'price': '0.99M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZpA97J9Bo',
#     'lat': 43.46367,
#     'lng': -79.74072,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39w6odyDrK8',
#     'lat': 43.34914,
#     'lng': -79.76976,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WZd5YDar0',
#     'lat': 43.37551,
#     'lng': -79.75165,
#     'price': '0.84M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1X0XYjEvL',
#     'lat': 43.32391,
#     'lng': -79.91283,
#     'price': '0.9M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8R0v78m9K',
#     'lat': 43.4948,
#     'lng': -79.65769,
#     'price': '0.85M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypokX2YLGlV',
#     'lat': 43.49566,
#     'lng': -79.85678,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DewaVYMnxB',
#     'lat': 43.28678,
#     'lng': -80.084774,
#     'price': '0.61M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1XeNYjEvL',
#     'lat': 43.4481,
#     'lng': -79.7068,
#     'price': '0.83M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0Kl9yZ1MW',
#     'lat': 43.52445,
#     'lng': -79.85392,
#     'price': '0.84M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMlqgYkWVP',
#     'lat': 43.374361,
#     'lng': -79.87692,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGKLe7w1Qr',
#     'lat': 43.531372,
#     'lng': -79.845627,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BXeEn7XVkOdYrPo8',
#     'lat': 43.494815,
#     'lng': -79.853915,
#     'price': '0.83M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WZwwYDar0',
#     'lat': 43.21724,
#     'lng': -79.94894,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8REo78m9K',
#     'lat': 43.34966,
#     'lng': -79.82962,
#     'price': '0.4M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'dXawjy4PEOWyrR18',
#     'lat': 43.54554,
#     'lng': -79.68537,
#     'price': '0.42M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLEKP75eZE',
#     'lat': 43.232644,
#     'lng': -79.859678,
#     'price': '0.45M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5pJx7d4V6',
#     'lat': 43.39681,
#     'lng': -79.96262,
#     'price': '2.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0KxEyZ1MW',
#     'lat': 43.23402,
#     'lng': -79.69179,
#     'price': '1.2M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMl8WYkWVP',
#     'lat': 43.4217,
#     'lng': -79.6965,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqA1x7DBNr',
#     'lat': 43.53233,
#     'lng': -79.66883,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176KQzd3ZajD',
#     'lat': 43.497141,
#     'lng': -79.850647,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BGMnKYqGKxR7w1Qr',
#     'lat': 43.43279,
#     'lng': -79.72955,
#     'price': '0.76M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0V6LyvgxV',
#     'lat': 43.41756,
#     'lng': -80.00852,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDRV2yKabB',
#     'lat': 43.19448,
#     'lng': -79.86815,
#     'price': '0.54M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZpVZ7J9Bo',
#     'lat': 43.24425,
#     'lng': -79.83273,
#     'price': '0.45M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WZ1lYDar0',
#     'lat': 43.21885,
#     'lng': -79.82539,
#     'price': '0.59M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDLK9Y5mGN',
#     'lat': 43.18593,
#     'lng': -79.88426,
#     'price': '0.85M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OZeG7OklN',
#     'lat': 43.22687,
#     'lng': -79.72682,
#     'price': '0.95M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngA2M3EBO9',
#     'lat': 43.33977,
#     'lng': -79.77262,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNOVgybmwe',
#     'lat': 43.53011,
#     'lng': -79.71303,
#     'price': '0.88M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMlx6YkWVP',
#     'lat': 43.24053,
#     'lng': -79.79987,
#     'price': '0.42M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqA9R7DBNr',
#     'lat': 43.40643,
#     'lng': -79.82147,
#     'price': '0.73M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'JjAXw7QZ6wb3QOzg',
#     'lat': 43.1779,
#     'lng': -79.77788,
#     'price': '0.51M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgnpK7x2P0',
#     'lat': 43.50944,
#     'lng': -79.84522,
#     'price': '0.75M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNJV5YJmG2',
#     'lat': 43.44615,
#     'lng': -79.71676,
#     'price': '1.6M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meW5z3GKjm',
#     'lat': 43.45435,
#     'lng': -79.67789,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53DewD5YMnxB',
#     'lat': 43.48724,
#     'lng': -79.8401,
#     'price': '0.84M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39w6EnyDrK8',
#     'lat': 43.45215,
#     'lng': -79.73644,
#     'price': '0.6M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4xXN3j2q8',
#     'lat': 43.4971,
#     'lng': -79.89433,
#     'price': '1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9E8b7GxMb',
#     'lat': 43.51874,
#     'lng': -79.85894,
#     'price': '0.99M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLEG175eZE',
#     'lat': 43.36138,
#     'lng': -79.74347,
#     'price': '2.3M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wOJPyDrK8',
#     'lat': 43.40189,
#     'lng': -79.70558,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510Qqypove5YLGlV',
#     'lat': 43.218842,
#     'lng': -79.783686,
#     'price': '0.32M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngvgg3EBO9',
#     'lat': 43.32269,
#     'lng': -79.80669,
#     'price': '0.37M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
# ...
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OZjg7OklN',
#     'lat': 43.67972,
#     'lng': -79.78629,
#     'price': '0.72M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqwB3XeLP',
#     'lat': 43.37688,
#     'lng': -79.808237,
#     'price': '0.53M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0KBLyZ1MW',
#     'lat': 43.62136,
#     'lng': -79.58902,
#     'price': '0.43M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwpjd3XBeq',
#     'lat': 43.6092,
#     'lng': -79.55829,
#     'price': '0.49M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meWMJ3GKjm',
#     'lat': 43.52567,
#     'lng': -79.7056,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510QqypokADYLGlV',
#     'lat': 43.6639,
#     'lng': -79.84898,
#     'price': '0.4M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'knbq6y1xZgBYo9DA',
#     'lat': 43.60325,
#     'lng': -79.64997,
#     'price': '0.66M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L5VXv3l4xVp3j2q8',
#     'lat': 43.6009,
#     'lng': -79.64789,
#     'price': '0.45M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLEbV75eZE',
#     'lat': 43.66803,
#     'lng': -79.79511,
#     'price': '1.2M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5pke7d4V6',
#     'lat': 43.6773,
#     'lng': -79.86615,
#     'price': '1.9M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqLB3XeLP',
#     'lat': 43.46557,
#     'lng': -79.73968,
#     'price': '1.4M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0KXLyZ1MW',
#     'lat': 43.60659,
#     'lng': -79.66866,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6Pbj78Jg0',
#     'lat': 43.71724,
#     'lng': -79.77034,
#     'price': '0.68M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xMlLLYkWVP',
#     'lat': 43.5431,
#     'lng': -79.59634,
#     'price': '0.93M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgnOV7x2P0',
#     'lat': 43.76004,
#     'lng': -79.7831,
#     'price': '0.71M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmqLX3XeLP',
#     'lat': 43.45711,
#     'lng': -79.67161,
#     'price': '1.7M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0KX2yZ1MW',
#     'lat': 43.70405,
#     'lng': -79.8544,
#     'price': '0.64M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGo8jvyW1ZD',
#     'lat': 43.70092,
#     'lng': -79.85963,
#     'price': '0.76M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovPZm3n961',
#     'lat': 43.71016,
#     'lng': -79.77047,
#     'price': '0.67M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'L4KAX7NzQgq7eRPJ',
#     'lat': 43.66533,
#     'lng': -79.80762,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'xmZRW7ngAZ13EBO9',
#     'lat': 43.56174,
#     'lng': -79.73697,
#     'price': '0.74M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2rg47VPW4',
#     'lat': 43.49748,
#     'lng': -79.70506,
#     'price': '1M',
#     'house_type': 'S',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNOLbybmwe',
#     'lat': 43.78298,
#     'lng': -79.6992,
#     'price': '0.69M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0Va1yvgxV',
#     'lat': 43.60955,
#     'lng': -79.5892,
#     'price': '0.34M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39w6W0yDrK8',
#     'lat': 43.61537,
#     'lng': -79.59516,
#     'price': '0.73M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '6VLaGyGo86vyW1ZD',
#     'lat': 43.721258,
#     'lng': -79.545392,
#     'price': '0.32M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0Zaw5YovPpm3n961',
#     'lat': 43.58511,
#     'lng': -79.64616,
#     'price': '0.48M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'zVwod7vDLgpY5mGN',
#     'lat': 43.47182,
#     'lng': -79.69363,
#     'price': '0.59M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'PXRla7g1Xl6YjEvL',
#     'lat': 43.72058,
#     'lng': -79.60336,
#     'price': '0.41M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'RdXze3e8RnO78m9K',
#     'lat': 43.680583,
#     'lng': -79.730347,
#     'price': '0.43M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZEXrx30OZEZ7OklN',
#     'lat': 43.73589,
#     'lng': -79.74434,
#     'price': '0.47M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'jJKdOYraJej354lW',
#     'lat': 43.68012,
#     'lng': -79.8433,
#     'price': '0.49M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '510Qqypok21YLGlV',
#     'lat': 43.51169,
#     'lng': -79.63645,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VaD6p78dqx67wRQr',
#     'lat': 43.70955,
#     'lng': -79.72505,
#     'price': '0.39M',
#     'house_type': 'C',
#     'flg_idx': 1,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEgldK7x2P0',
#     'lat': 43.50987,
#     'lng': -79.6413,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0OlDyvgxV',
#     'lat': 43.4474,
#     'lng': -79.68681,
#     'price': '0.42M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wxXnyDrK8',
#     'lat': 43.47599,
#     'lng': -79.68764,
#     'price': '0.68M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5ElN7d4V6',
#     'lat': 43.70411,
#     'lng': -79.81765,
#     'price': '0.77M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'obqB176K6kK3ZajD',
#     'lat': 43.69384,
#     'lng': -79.84149,
#     'price': '0.74M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'oK8OgYBNn05YJmG2',
#     'lat': 43.68016,
#     'lng': -79.8123,
#     'price': '0.7M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwBNg3XBeq',
#     'lat': 43.53379,
#     'lng': -79.85404,
#     'price': '0.8M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDXqzyKabB',
#     'lat': 43.74542,
#     'lng': -79.75397,
#     'price': '0.74M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53De845YMnxB',
#     'lat': 43.73657,
#     'lng': -79.79931,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'VgAaOyL9QXb7GxMb',
#     'lat': 43.72424,
#     'lng': -79.61619,
#     'price': '0.51M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'a6zqW7dLRe175eZE',
#     'lat': 43.74953,
#     'lng': -79.58079,
#     'price': '0.41M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'weQp5yOM6zv3d0ZE',
#     'lat': 43.47998,
#     'lng': -79.71286,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '5xLkv3VqkzR7DBNr',
#     'lat': 43.47976,
#     'lng': -79.72747,
#     'price': '0.5M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'EeVbOYEglzK7x2P0',
#     'lat': 43.66111,
#     'lng': -79.72875,
#     'price': '0.58M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'owJKR7PmVjM3XeLP',
#     'lat': 43.60397,
#     'lng': -79.64981,
#     'price': '0.57M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0w5myZ1MW',
#     'lat': 43.58355,
#     'lng': -79.64277,
#     'price': '0.54M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'BDO1w3W6Kzn78Jg0',
#     'lat': 43.69544,
#     'lng': -79.74954,
#     'price': '0.34M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'MB5bO3xM1mQYkWVP',
#     'lat': 43.6639,
#     'lng': -79.84898,
#     'price': '0.44M',
#     'house_type': 'C',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'N0A9X3j0OmdyvgxV',
#     'lat': 43.47998,
#     'lng': -79.71286,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0MWBVyZBwzbyKemj',
#     'lat': 43.482696,
#     'lng': -79.689924,
#     'price': '0.66M',
#     'house_type': None,
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wx2PyDrK8',
#     'lat': 43.79828,
#     'lng': -79.58321,
#     'price': '0.61M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WR5DYDar0',
#     'lat': 43.798694,
#     'lng': -79.583115,
#     'price': '0.57M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'ZNkKJ3J5EbZ7d4V6',
#     'lat': 43.63225,
#     'lng': -80.02366,
#     'price': '0.69M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gJRv53K2R5x7VPW4',
#     'lat': 43.756144,
#     'lng': -79.838863,
#     'price': '1.3M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'DnM697kNxWdybmwe',
#     'lat': 43.87973,
#     'lng': -79.86229,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'damgL7A0wGmyZ1MW',
#     'lat': 43.75321,
#     'lng': -79.84156,
#     'price': '1.1M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0J6Em7bwBEd3XBeq',
#     'lat': 43.761004,
#     'lng': -79.764291,
#     'price': '0.55M',
#     'house_type': 'T',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'x9w8o3meAPJ3GKjm',
#     'lat': 43.63211,
#     'lng': -80.03288,
#     'price': '0.5M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '0ZxwR7MDX5ByKabB',
#     'lat': 43.54752,
#     'lng': -79.62582,
#     'price': '2M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'gaQmD7zZr0O7J9Bo',
#     'lat': 43.73061,
#     'lng': -79.75855,
#     'price': '0.86M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'NAKv53De85jYMnxB',
#     'lat': 43.62272,
#     'lng': -80.04189,
#     'price': '0.6M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '02Zpj39wxGqyDrK8',
#     'lat': 43.5103,
#     'lng': -79.83702,
#     'price': '0.76M',
#     'house_type': 'D',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': '2Z5BX32WRm1YDar0',
#     'lat': 43.78561,
#     'lng': -79.66492,
#     'price': '0.75M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    {'id_listing': 'mLzQ1y5kqaE3qdeK',
#     'lat': 43.54401,
#     'lng': -79.59804,
#     'price': '1.5M',
#     'house_type': 'S',
#     'flg_idx': 0,
#     'flg_disp_addr': 1,
#     'marker': 'active'},
#    ...],
#   'list_feature': [{'id_listing': 'BDO1w3W6PDn78Jg0',
#     'ml_num': 'C4521274',
#     'price': '0.4M',
#     'lat': 43.66022,
#     'lng': -79.36493,
#     'flg_feature': 2,
#     'house_type': 'C.',
#     'marker': 'feature'},
#    {'id_listing': 'BGMnKYqGKvd7w1Qr',
#     'ml_num': 'E4521269',
#     'price': '0.65M',
#     'lat': 43.87691,
#     'lng': -78.95212,
#     'flg_feature': 2,
#     'house_type': 'D.',
#     'marker': 'feature'},
#    {'id_listing': '0J6Em7bwvJj3XBeq',
#     'ml_num': 'E4518963',
#     'price': '0.7M',
#     'lat': 43.7139,
#     'lng': -79.25033,
#     'flg_feature': 2,
#     'house_type': 'D.',
#     'marker': 'feature'}],
#   'days_filter': [{'id': 1, 'name': 'Last 1 days', 'abbr': '1d'},
#    {'id': 7, 'name': 'Last 7 days', 'abbr': '7d'},
#    {'id': 30, 'name': 'Last 30 days', 'abbr': '30d'},
#    {'id': 90, 'name': 'Last 90 days', 'abbr': '90d'},
#    {'id': 0, 'name': 'Listing date - All', 'abbr': 'All'},
#    {'id': -30, 'name': 'More than 30 days', 'abbr': 'dom30'},
#    {'id': -60, 'name': 'More than 60 days', 'abbr': 'dom60'},
#    {'id': -90, 'name': 'More than 90 days', 'abbr': 'dom90'}],
#   'housetype_filter': [{'id': 'all', 'name': 'All property types'},
#    {'id': 'all', 'name': 'All property types'},
#    {'id': 'D.', 'name': '\u200bDetached', 'default': True},
#    {'id': 'S.', 'name': '\u200bSemi-Detached'},
#    {'id': 'A.', 'name': '\u200bFreehold Townhouse'},
#    {'id': 'T.', 'name': '\u200bCondo Townhouse'},
#    {'id': 'C.', 'name': '\u200bCondo Apt'},
#    {'id': 'L.', 'name': '\u200bLink'},
#    {'id': 'J.', 'name': '\u200bMultiplex'},
#    {'id': 'V.', 'name': '\u200bVacant Land'}],
#   'filter_active': {'house_type': 'all',
#    'house_type_name': 'all',
#    'lat1': 43.55153408323952,
#    'lat2': 42.99359899401497,
#    'lon1': -79.64401245117189,
#    'lon2': -80.15899658203126,
#    'days': 0,
#    'price_min': 100000,
#    'price_max': 0,
#    'bedroom_range': [0],
#    'bathroom_min': 0,
#    'garage_min': 0,
#    'basement': [],
#    'square_ft_min': 0,
#    'square_ft_max': 4000}},
#  'error': {'code': 0, 'message': ''},
#  'debug': {'0': 'API V2',
#   '1': '/api/search/mapsearch/listing',
#   'lang': 'en_US',
#   'lang_test': 'Language Test English',
#   '$_REQUEST': {'_url': '/api/search/mapsearch/listing',
#    'baseUri': '/bkv2/',
#    'staticUri': '/bkv2/',
#    'lang': 'en_US',
#    'house_type': 'all',
#    'days': 0,
#    'bedroom_range': [0],
#    'price_min': 100000,
#    'price_max': 0,
#    'bathroom_min': 0,
#    'garage_min': 0,
#    'basement': [],
#    'square_ft_min': 0,
#    'square_ft_max': 4000,
#    'lat1': 43.55153408323952,
#    'lon1': -79.64401245117189,
#    'lat2': 42.99359899401497,
#    'lon2': -80.15899658203126},
#   'environment': 'production',
#   'bounds': {'lat1': 42.99359899401497,
#    'lat2': 43.55153408323952,
#    'lon1': -80.15899658203126,
#    'lon2': -79.64401245117189},
#   'rowCount': 500}}

# %%
# data["data"]["house"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-4d78ea7ce2ef> in <module>
# ----> 1 data["data"]["house"]
#
# KeyError: 'house'

# %%
data
# Out:
# {'status': True, 'data': {'message': '', 'list': [{'id_listing': 'xmZRW7ng8r13EBO9', 'lat': 43.44757, 'lng': -79.68754, 'price': '0.73M', 'house_type': 'C', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'VaD6p78dWm67wRQr', 'lat': 43.4577, 'lng': -79.69413, 'price': '2.5M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'MB5bO3xMOdkYkWVP', 'lat': 43.53884, 'lng': -79.67404, 'price': '0.64M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': '6VLaGyGoQPjyW1ZD', 'lat': 43.430661, 'lng': -79.74829, 'price': '0.7M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': '6VLaGyGoQkJyW1ZD', 'lat': 43.47901, 'lng': -79.73638, 'price': '1.2M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'jJKdOYraRGK354lW', 'lat': 43.44629, 'lng': -79.76425, 'price': '0.8M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'VaD6p78dW1z7wRQr', 'lat': 43.43847, 'lng': -79.68056, 'price': '1.2M', 'house_type': 'D', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'VgAaOyL9O8Z7GxMb', 'lat': 43.51203, 'lng': -79.65332, 'price': '0.76M', 'house_type': 'S', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'b1DBW7REKDLyqlAp', 'lat': 43.46292, 'lng': -79.66456, 'price': '2.8M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'BDO1w3W6Lqd78Jg0', 'lat': 43.5458, 'lng': -79.73195, 'price': '1.5M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': '5xLkv3Vqn9O7DBNr', 'lat': 43.51929, 'lng': -79.67545, 'price': '0.93M', 'house_type': 'D', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'JjAXw7QZkwX3QOzg', 'lat': 43.45277, 'lng': -79.73692, 'price': '0.85M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'gaQmD7zZMz97J9Bo', 'lat': 43.46015, 'lng': -79.67024, 'price': '1.3M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'BDO1w3W6jBV78Jg0', 'lat': 43.55473, 'lng': -79.67685, 'price': '2.7M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'x9w8o3meMeV3GKjm', 'lat': 43.44389, 'lng': -79.72874, 'price': '0.73M', 'house_type': 'C', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': '0Zaw5YovMvL3n961', 'lat': 43.43578, 'lng': -79.73501, 'price': '0.45M', 'house_type': 'C', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'obqB176Kj4n3ZajD', 'lat': 43.54436, 'lng': -79.67833, 'price': '0.65M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'jJKdOYraMnb354lW', 'lat': 43.47337, 'lng': -79.73888, 'price': '0.66M', 'house_type': 'T', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'gaQmD7zZMwA7J9Bo', 'lat': 43.55141, 'lng': -79.68138, 'price': '1.3M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': '0ZxwR7MDKA9yKabB', 'lat': 43.55307, 'lng': -79.64953, 'price': '0.92M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'RdXze3e8jWo78m9K', 'lat': 43.54412, 'lng': -79.74292, 'price': '0.7M', 'house_type': 'S', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'ZEXrx30Ojgl7OklN', 'lat': 43.47442, 'lng': -79.73339, 'price': '0.89M', 'house_type': 'D', 'flg_idx': 0, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'L5VXv3l4Mww3j2q8', 'lat': 43.43315, 'lng': -79.68355, 'price': '1.1M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'r56k97wzMeRyKRjD', 'lat': 43.49161, 'lng': -79.69518, 'price': '2M', 'house_type': 'D', 'flg_idx': 1, 'flg_disp_addr': 1, 'marker': 'active'}, {'id_listing': 'BDO1w3W6jGO78Jg0', 'lat': 43.555, 'lng': -79.75489, 'price': ' ...

# %%
data.keys()
# Out:
# dict_keys(['status', 'data', 'error', 'debug'])

# %%
clean = data["data"]

# %%
clean.keys()
# Out:
# dict_keys(['message', 'list', 'list_feature', 'days_filter', 'housetype_filter', 'filter_active'])

# %%
clean["housetype_filter"]
# Out:
# [{'id': 'all', 'name': 'All property types'},
#  {'id': 'all', 'name': 'All property types'},
#  {'id': 'D.', 'name': '\u200bDetached', 'default': True},
#  {'id': 'S.', 'name': '\u200bSemi-Detached'},
#  {'id': 'A.', 'name': '\u200bFreehold Townhouse'},
#  {'id': 'T.', 'name': '\u200bCondo Townhouse'},
#  {'id': 'C.', 'name': '\u200bCondo Apt'},
#  {'id': 'L.', 'name': '\u200bLink'},
#  {'id': 'J.', 'name': '\u200bMultiplex'},
#  {'id': 'V.', 'name': '\u200bVacant Land'}]

# %%
clean["filter_active"]
# Out:
# {'house_type': 'all',
#  'house_type_name': 'all',
#  'lat1': 43.55153408323952,
#  'lat2': 42.99359899401497,
#  'lon1': -79.64401245117189,
#  'lon2': -80.15899658203126,
#  'days': 0,
#  'price_min': 100000,
#  'price_max': 0,
#  'bedroom_range': [0],
#  'bathroom_min': 0,
#  'garage_min': 0,
#  'basement': [],
#  'square_ft_min': 0,
#  'square_ft_max': 4000}

# %%
usable = clean["list"]

# %%
len(usable)
# Out:
# 13940

# %%
usable

# %%
geojson = {
    "type": "FeatureCollection",
    "features": [
    {
        "type": "Feature",
        "geometry" : {
            "type": "Point",
            "coordinates": [d["lng"], d["lat"]],
            },
            "properties" : {"price": float(d["price"].replace("M","")),"id_listing": d["id_listing"],"house_type": d["house_type"]}
    }    for d in usable]
}

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'price': 0.42,
#     'id_listing': 'N0A9X3j0OlDyvgxV',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.809363, 43.377062]},
#    'properties': {'price': 0.39,
#     'id_listing': '0J6Em7bwBkg3XBeq',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68764, 43.47599]},
#    'properties': {'price': 0.68,
#     'id_listing': '02Zpj39wxXnyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79985, 43.24459]},
#    'properties': {'price': 0.35,
#     'id_listing': '5xLkv3VqkKR7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85404, 43.53379]},
#    'properties': {'price': 0.8,
#     'id_listing': '0J6Em7bwBNg3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75671, 43.36588]},
#    'properties': {'price': 0.93,
#     'id_listing': '0MWBVyZBwnqyKemj',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.97164, 43.27235]},
#    'properties': {'price': 1.3,
#     'id_listing': 'BDO1w3W6KJq78Jg0',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'weQp5yOM6zv3d0ZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72747, 43.47976]},
#    'properties': {'price': 0.5,
#     'id_listing': '5xLkv3VqkzR7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73485, 43.36526]},
#    'properties': {'price': 0.7,
#     'id_listing': 'BXeEn7XVJzvYrPo8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'N0A9X3j0OmdyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.689924, 43.482696]},
#    'properties': {'price': 0.66,
#     'id_listing': '0MWBVyZBwzbyKemj',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.99203, 43.2739]},
#    'properties': {'price': 0.93,
#     'id_listing': 'weQp5yOM65g3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.13745, 43.28862]},
#    'properties': {'price': 0.87,
#     'id_listing': '5xLkv3Vqk5Q7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77823, 43.1821]},
#    'properties': {'price': 0.66,
#     'id_listing': 'oK8OgYBNnGjYJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82134, 43.37113]},
#    'properties': {'price': 1.1,
#     'id_listing': 'N0A9X3j0OxwyvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83702, 43.5103]},
#    'properties': {'price': 0.76,
#     'id_listing': '02Zpj39wxGqyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78066, 43.3905]},
#    'properties': {'price': 0.62,
#     'id_listing': '6VLaGyGopGKyW1ZD',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86242, 43.49255]},
#    'properties': {'price': 0.93,
#     'id_listing': 'knbq6y1xEWBYo9DA',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70822, 43.5263]},
#    'properties': {'price': 0.85,
#     'id_listing': 'DnM697kNxKOybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79202, 43.408]},
#    'properties': {'price': 0.63,
#     'id_listing': 'BDO1w3W6K2j78Jg0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69987, 43.41322]},
#    'properties': {'price': 1.4,
#     'id_listing': 'MB5bO3xM14LYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72774, 43.48328]},
#    'properties': {'price': 0.88,
#     'id_listing': 'oK8OgYBNn4jYJmG2',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69245, 43.46221]},
#    'properties': {'price': 1.1,
#     'id_listing': 'zVwod7vD8NDY5mGN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72787, 43.47849]},
#    'properties': {'price': 0.51,
#     'id_listing': 'L5VXv3l4WWV3j2q8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85467, 43.31159]},
#    'properties': {'price': 0.93,
#     'id_listing': 'VaD6p78dOO67wRQr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80351, 43.39677]},
#    'properties': {'price': 0.97,
#     'id_listing': 'BDO1w3W6KKw78Jg0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78841, 43.39316]},
#    'properties': {'price': 0.34,
#     'id_listing': 'BGMnKYqGJJ57w1Qr',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.89911, 43.22153]},
#    'properties': {'price': 0.45,
#     'id_listing': '0MWBVyZBwG5yKemj',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77122, 43.20268]},
#    'properties': {'price': 0.72,
#     'id_listing': '0ZxwR7MDXGeyKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90379, 43.23302]},
#    'properties': {'price': 0.54,
#     'id_listing': 'gaQmD7zZrBr7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66444, 43.53769]},
#    'properties': {'price': 1.1,
#     'id_listing': 'NAKv53De8LwYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73186, 43.37034]},
#    'properties': {'price': 1.1,
#     'id_listing': 'mLzQ1y5kqXj3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72199, 43.44219]},
#    'properties': {'price': 1.7,
#     'id_listing': 'kbEDRYadr9b31VaB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76725, 43.34319]},
#    'properties': {'price': 1.2,
#     'id_listing': 'ZNkKJ3J5Ej17d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71704, 43.40169]},
#    'properties': {'price': 1.0,
#     'id_listing': 'owJKR7PmVPG3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.93874, 43.24976]},
#    'properties': {'price': 0.72,
#     'id_listing': 'PXRla7g1qkgYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.723435, 43.223106]},
#    'properties': {'price': 0.65,
#     'id_listing': '510QqypoK1aYLGlV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74678, 43.42835]},
#    'properties': {'price': 1.4,
#     'id_listing': 'r56k97wzlVGyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73034, 43.55005]},
#    'properties': {'price': 1.3,
#     'id_listing': 'a6zqW7dLRWK75eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79708, 43.12604]},
#    'properties': {'price': 0.96,
#     'id_listing': 'owJKR7PmVwG3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82243, 43.32108]},
#    'properties': {'price': 0.75,
#     'id_listing': 'MB5bO3xM1bkYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6787, 43.47912]},
#    'properties': {'price': 1.0,
#     'id_listing': '5xLkv3VqkjZ7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.96404, 43.23201]},
#    'properties': {'price': 1.4,
#     'id_listing': 'EeVbOYEgl6d7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9318, 43.07191]},
#    'properties': {'price': 0.5,
#     'id_listing': 'damgL7A0wB5yZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69301, 43.43834]},
#    'properties': {'price': 1.5,
#     'id_listing': 'BGMnKYqGJMK7w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86374, 43.49104]},
#    'properties': {'price': 0.7,
#     'id_listing': 'VaD6p78dOZz7wRQr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7144, 43.3842]},
#    'properties': {'price': 2.0,
#     'id_listing': 'VgAaOyL9QJZ7GxMb',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87049, 43.206551]},
#    'properties': {'price': 0.43,
#     'id_listing': 'BXeEn7XVJgGYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.899968, 43.327507]},
#    'properties': {'price': 0.61,
#     'id_listing': 'EeVbOYEglLO7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88244, 43.50472]},
#    'properties': {'price': 0.54,
#     'id_listing': '0MWBVyZBwRkyKemj',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73501, 43.43578]},
#    'properties': {'price': 0.41,
#     'id_listing': '2Z5BX32WRQOYDar0',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80261, 43.37902]},
#    'properties': {'price': 0.37,
#     'id_listing': 'a6zqW7dLRwv75eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82602, 43.36803]},
#    'properties': {'price': 0.6,
#     'id_listing': 'DnM697kNxl6ybmwe',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.779993, 43.188316]},
#    'properties': {'price': 0.61,
#     'id_listing': 'zVwod7vD8q8Y5mGN',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82657, 43.25233]},
#    'properties': {'price': 0.54,
#     'id_listing': 'weQp5yOM6Lw3d0ZE',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79444, 43.1825]},
#    'properties': {'price': 0.53,
#     'id_listing': 'BGMnKYqGJjb7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72688, 43.4671]},
#    'properties': {'price': 0.89,
#     'id_listing': 'b1DBW7REx2EyqlAp',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81002, 43.38457]},
#    'properties': {'price': 0.8,
#     'id_listing': 'N0A9X3j0O8EyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90217, 43.21843]},
#    'properties': {'price': 0.6,
#     'id_listing': '0ZxwR7MDX0myKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81631, 43.2397]},
#    'properties': {'price': 0.4,
#     'id_listing': 'gaQmD7zZre97J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7072, 43.46366]},
#    'properties': {'price': 1.1,
#     'id_listing': 'zVwod7vD8n8Y5mGN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66574, 43.46408]},
#    'properties': {'price': 2.4,
#     'id_listing': 'RdXze3e8Qpv78m9K',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9297, 43.07048]},
#    'properties': {'price': 0.52,
#     'id_listing': 'JjAXw7QZOQM3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80062, 43.12143]},
#    'properties': {'price': 0.65,
#     'id_listing': 'oK8OgYBNnR4YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.809062, 43.126597]},
#    'properties': {'price': 0.53,
#     'id_listing': '0J6Em7bwB4B3XBeq',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86741, 43.53029]},
#    'properties': {'price': 0.8,
#     'id_listing': 'NAKv53De8XVYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69538, 43.52869]},
#    'properties': {'price': 1.2,
#     'id_listing': 'mLzQ1y5kq8m3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74221, 43.47078]},
#    'properties': {'price': 0.86,
#     'id_listing': 'kbEDRYadr4l31VaB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87246, 43.48079]},
#    'properties': {'price': 0.78,
#     'id_listing': '6VLaGyGopVAyW1ZD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83519, 43.24735]},
#    'properties': {'price': 0.59,
#     'id_listing': 'VaD6p78dOo07wRQr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85883, 43.51358]},
#    'properties': {'price': 0.85,
#     'id_listing': 'xmZRW7ngPXa3EBO9',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.849924, 43.503877]},
#    'properties': {'price': 0.75,
#     'id_listing': 'L5VXv3l4WbO3j2q8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73621, 43.46392]},
#    'properties': {'price': 1.2,
#     'id_listing': 'BXeEn7XVJRdYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80624, 43.347762]},
#    'properties': {'price': 0.62,
#     'id_listing': 'JjAXw7QZOVz3QOzg',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85437, 43.50573]},
#    'properties': {'price': 0.94,
#     'id_listing': '0ZxwR7MDXQ9yKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82625, 43.40401]},
#    'properties': {'price': 0.92,
#     'id_listing': 'r56k97wzlaRyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.877928, 43.340652]},
#    'properties': {'price': 1.0,
#     'id_listing': 'JjAXw7QZOXd3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7094, 43.53529]},
#    'properties': {'price': 0.95,
#     'id_listing': 'EeVbOYEgl9r7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75444, 43.44067]},
#    'properties': {'price': 0.9,
#     'id_listing': 'owJKR7PmVQD3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70499, 43.45734]},
#    'properties': {'price': 1.1,
#     'id_listing': 'weQp5yOM6RQ3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7639, 43.44662]},
#    'properties': {'price': 0.77,
#     'id_listing': '0ZxwR7MDXa2yKabB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75444, 43.44067]},
#    'properties': {'price': 0.9,
#     'id_listing': 'gaQmD7zZrAZ7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70499, 43.45734]},
#    'properties': {'price': 1.1,
#     'id_listing': 'NAKv53De8pEYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86471, 43.24942]},
#    'properties': {'price': 0.5,
#     'id_listing': 'L5VXv3l4W0x3j2q8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.93599, 43.26244]},
#    'properties': {'price': 0.6,
#     'id_listing': 'xmZRW7ngPRM3EBO9',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7639, 43.44662]},
#    'properties': {'price': 0.77,
#     'id_listing': 'weQp5yOM6jQ3d0ZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68375, 43.23127]},
#    'properties': {'price': 0.56,
#     'id_listing': 'a6zqW7dLRrP75eZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73167, 43.45002]},
#    'properties': {'price': 0.95,
#     'id_listing': 'r56k97wzl5OyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84007, 43.2561]},
#    'properties': {'price': 0.45,
#     'id_listing': '0J6Em7bwBag3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76635, 43.42657]},
#    'properties': {'price': 0.85,
#     'id_listing': 'gaQmD7zZrO17J9Bo',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9456, 43.27045]},
#    'properties': {'price': 0.5,
#     'id_listing': '0Zaw5Yovka23n961',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64674, 43.54454]},
#    'properties': {'price': 5.4,
#     'id_listing': 'L4KAX7Nzqdd7eRPJ',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71119, 43.39867]},
#    'properties': {'price': 2.2,
#     'id_listing': 'jJKdOYradrB354lW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79336, 43.53307]},
#    'properties': {'price': 0.68,
#     'id_listing': '510QqypoK05YLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86125, 43.53389]},
#    'properties': {'price': 0.63,
#     'id_listing': 'DnM697kNxodybmwe',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85453, 43.5091]},
#    'properties': {'price': 0.62,
#     'id_listing': 'BXeEn7XVJrvYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72634, 43.48017]},
#    'properties': {'price': 0.53,
#     'id_listing': 'a6zqW7dLRKX75eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80026, 43.37713]},
#    'properties': {'price': 0.42,
#     'id_listing': 'owJKR7PmV9M3XeLP',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84317, 43.20922]},
#    'properties': {'price': 0.33,
#     'id_listing': 'BGMnKYqGJxj7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84948, 43.52614]},
#    'properties': {'price': 0.61,
#     'id_listing': 'dXawjy4PXNpyrR18',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.868853, 43.518985]},
#    'properties': {'price': 0.5,
#     'id_listing': 'ZEXrx30O2eg7OklN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.666816, 43.543954]},
#    'properties': {'price': 1.4,
#     'id_listing': 'jJKdOYrad0P354lW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76614, 43.35347]},
#    'properties': {'price': 0.9,
#     'id_listing': 'mLzQ1y5kqpE3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.804928, 43.318745]},
#    'properties': {'price': 1.6,
#     'id_listing': '0Zaw5Yovk543n961',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81651, 43.37462]},
#    'properties': {'price': 0.95,
#     'id_listing': 'VaD6p78dO1J7wRQr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72793, 43.47611]},
#    'properties': {'price': 1.2,
#     'id_listing': 'VgAaOyL9Q8z7GxMb',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.846856, 43.227768]},
#    'properties': {'price': 0.4,
#     'id_listing': 'owJKR7PmV8B3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68269, 43.43609]},
#    'properties': {'price': 1.7,
#     'id_listing': 'BXeEn7XVJ60YrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76313, 43.42967]},
#    'properties': {'price': 0.74,
#     'id_listing': 'b1DBW7RExDQyqlAp',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90189, 43.0601]},
#    'properties': {'price': 0.69,
#     'id_listing': 'damgL7A0w42yZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79181, 43.19958]},
#    'properties': {'price': 0.37,
#     'id_listing': '5xLkv3Vqk9p7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79558, 43.33987]},
#    'properties': {'price': 0.89,
#     'id_listing': 'BGMnKYqGJp57w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77904, 43.42302]},
#    'properties': {'price': 1.2,
#     'id_listing': 'EeVbOYEglp57x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81417, 43.35321]},
#    'properties': {'price': 0.65,
#     'id_listing': 'N0A9X3j0OR1yvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73658, 43.48242]},
#    'properties': {'price': 1.7,
#     'id_listing': 'mLzQ1y5kqZw3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84026, 43.33841]},
#    'properties': {'price': 1.1,
#     'id_listing': 'kbEDRYadrOP31VaB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7145, 43.44104]},
#    'properties': {'price': 0.79,
#     'id_listing': '6VLaGyGopNvyW1ZD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86388, 43.486912]},
#    'properties': {'price': 0.67,
#     'id_listing': 'r56k97wzlQ6yKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.94189, 43.26074]},
#    'properties': {'price': 0.4,
#     'id_listing': 'BXeEn7XVkXMYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72747, 43.47976]},
#    'properties': {'price': 0.51,
#     'id_listing': '0ZxwR7MDR2eyKabB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70949, 43.39805]},
#    'properties': {'price': 1.1,
#     'id_listing': 'mLzQ1y5kRAj3qdeK',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.771894, 43.181023]},
#    'properties': {'price': 1.1,
#     'id_listing': 'BXeEn7XVklMYrPo8',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.92425, 43.25263]},
#    'properties': {'price': 0.6,
#     'id_listing': 'JjAXw7QZ6Km3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76208, 43.43026]},
#    'properties': {'price': 1.2,
#     'id_listing': 'weQp5yOMXPB3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87876, 43.4961]},
#    'properties': {'price': 0.7,
#     'id_listing': 'BGMnKYqGK6K7w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82275, 43.38725]},
#    'properties': {'price': 0.76,
#     'id_listing': 'EeVbOYEgnRO7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65008, 43.21515]},
#    'properties': {'price': 0.57,
#     'id_listing': 'kbEDRYad1vN31VaB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64859, 43.21251]},
#    'properties': {'price': 0.71,
#     'id_listing': '6VLaGyGo8XJyW1ZD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8872, 43.34134]},
#    'properties': {'price': 0.79,
#     'id_listing': 'owJKR7PmqpO3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68143, 43.22922]},
#    'properties': {'price': 0.55,
#     'id_listing': 'EeVbOYEgnPO7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84902, 43.25883]},
#    'properties': {'price': 0.3,
#     'id_listing': 'x9w8o3meWk23GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81118, 43.12656]},
#    'properties': {'price': 0.45,
#     'id_listing': '0Zaw5YovPJ03n961',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.919133, 43.32722]},
#    'properties': {'price': 0.65,
#     'id_listing': 'PXRla7g1XV5YjEvL',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82334, 43.25726]},
#    'properties': {'price': 0.29,
#     'id_listing': 'L4KAX7NzQlO7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86374, 43.49104]},
#    'properties': {'price': 0.7,
#     'id_listing': 'BDO1w3W6PZo78Jg0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84218, 43.36406]},
#    'properties': {'price': 0.88,
#     'id_listing': 'obqB176KQ063ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83552, 43.5294]},
#    'properties': {'price': 0.76,
#     'id_listing': 'damgL7A0K9nyZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73242, 43.2258]},
#    'properties': {'price': 0.5,
#     'id_listing': 'obqB176KQ0a3ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84315, 43.50586]},
#    'properties': {'price': 0.64,
#     'id_listing': 'b1DBW7REVZ1yqlAp',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86932, 43.48545]},
#    'properties': {'price': 0.89,
#     'id_listing': '0MWBVyZBJZkyKemj',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76627, 43.43079]},
#    'properties': {'price': 0.75,
#     'id_listing': 'r56k97wz8d8yKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80285, 43.37781]},
#    'properties': {'price': 0.32,
#     'id_listing': '0J6Em7bwpMG3XBeq',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72787, 43.47849]},
#    'properties': {'price': 0.51,
#     'id_listing': 'zVwod7vDLd8Y5mGN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.97193, 43.2709]},
#    'properties': {'price': 0.5,
#     'id_listing': 'r56k97wz8wxyKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6848, 43.45184]},
#    'properties': {'price': 0.36,
#     'id_listing': 'a6zqW7dLEMk75eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81506, 43.24994]},
#    'properties': {'price': 0.37,
#     'id_listing': '0J6Em7bwpgB3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70624, 43.22323]},
#    'properties': {'price': 0.58,
#     'id_listing': 'r56k97wz89QyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73636, 43.38147]},
#    'properties': {'price': 0.96,
#     'id_listing': 'BGMnKYqGKee7w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.89505, 43.34548]},
#    'properties': {'price': 1.2,
#     'id_listing': 'oK8OgYBNJk4YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69902, 43.49951]},
#    'properties': {'price': 1.4,
#     'id_listing': 'dXawjy4PEoByrR18',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6611, 43.53775]},
#    'properties': {'price': 1.3,
#     'id_listing': 'L4KAX7NzQ0r7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72559, 43.24032]},
#    'properties': {'price': 0.5,
#     'id_listing': 'r56k97wz8RQyKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70544, 43.49309]},
#    'properties': {'price': 1.2,
#     'id_listing': 'owJKR7PmqOp3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74851, 43.42998]},
#    'properties': {'price': 0.85,
#     'id_listing': 'damgL7A0Kr9yZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69121, 43.42473]},
#    'properties': {'price': 1.4,
#     'id_listing': 'weQp5yOMXVb3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71087, 43.53059]},
#    'properties': {'price': 0.99,
#     'id_listing': '0ZxwR7MDRz9yKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.731719, 43.487889]},
#    'properties': {'price': 1.3,
#     'id_listing': '02Zpj39w62kyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77904, 43.42302]},
#    'properties': {'price': 1.2,
#     'id_listing': 'zVwod7vDLmrY5mGN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79851, 43.34114]},
#    'properties': {'price': 0.94,
#     'id_listing': 'PXRla7g1XmGYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82651, 43.39898]},
#    'properties': {'price': 0.88,
#     'id_listing': 'L4KAX7NzQoz7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80041, 43.40686]},
#    'properties': {'price': 0.82,
#     'id_listing': 'owJKR7Pmqov3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88569, 43.50005]},
#    'properties': {'price': 0.9,
#     'id_listing': 'weQp5yOMXoG3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84883, 43.52586]},
#    'properties': {'price': 0.5,
#     'id_listing': 'VgAaOyL9EvO7GxMb',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85414, 43.25393]},
#    'properties': {'price': 0.5,
#     'id_listing': 'r56k97wz8EOyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90014, 43.324]},
#    'properties': {'price': 1.0,
#     'id_listing': 'oK8OgYBNJn5YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.809708, 43.18072]},
#    'properties': {'price': 0.56,
#     'id_listing': '0J6Em7bwpBg3XBeq',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.01308, 43.21361]},
#    'properties': {'price': 0.65,
#     'id_listing': 'x9w8o3meWAz3GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.98943, 43.20658]},
#    'properties': {'price': 0.66,
#     'id_listing': 'ZEXrx30OZ2J7OklN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70004, 43.48556]},
#    'properties': {'price': 1.2,
#     'id_listing': 'obqB176KQQK3ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9325, 43.42035]},
#    'properties': {'price': 1.2,
#     'id_listing': '0MWBVyZBJJbyKemj',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83486, 43.51193]},
#    'properties': {'price': 0.82,
#     'id_listing': 'DnM697kNOvdybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72084, 43.55006]},
#    'properties': {'price': 0.73,
#     'id_listing': '0Zaw5YovPb23n961',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.808237, 43.37688]},
#    'properties': {'price': 0.53,
#     'id_listing': 'owJKR7PmqwB3XeLP',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7056, 43.52567]},
#    'properties': {'price': 0.57,
#     'id_listing': 'x9w8o3meWMJ3GKjm',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80505, 43.25388]},
#    'properties': {'price': 0.3,
#     'id_listing': 'DnM697kNO6Oybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73968, 43.46557]},
#    'properties': {'price': 1.4,
#     'id_listing': 'owJKR7PmqLB3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83779, 43.25944]},
#    'properties': {'price': 0.45,
#     'id_listing': 'weQp5yOMXng3d0ZE',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67161, 43.45711]},
#    'properties': {'price': 1.7,
#     'id_listing': 'owJKR7PmqLX3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70506, 43.49748]},
#    'properties': {'price': 1.0,
#     'id_listing': 'gJRv53K2rg47VPW4',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69363, 43.47182]},
#    'properties': {'price': 0.59,
#     'id_listing': 'zVwod7vDLgpY5mGN',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75248, 43.45164]},
#    'properties': {'price': 1.1,
#     'id_listing': 'weQp5yOMXL13d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70771, 43.41867]},
#    'properties': {'price': 1.2,
#     'id_listing': 'obqB176KQrM3ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71304, 43.39398]},
#    'properties': {'price': 1.2,
#     'id_listing': 'N0A9X3j0VgmyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.95583, 43.21867]},
#    'properties': {'price': 0.82,
#     'id_listing': 'VaD6p78dq9k7wRQr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.98386, 43.36061]},
#    'properties': {'price': 0.95,
#     'id_listing': 'EeVbOYEgnxd7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.893932, 43.212157]},
#    'properties': {'price': 0.48,
#     'id_listing': '5xLkv3VqA0e7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76464, 43.22579]},
#    'properties': {'price': 0.55,
#     'id_listing': 'obqB176KQx63ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77883, 43.25167]},
#    'properties': {'price': 0.57,
#     'id_listing': 'BXeEn7XVk0GYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85224, 43.48233]},
#    'properties': {'price': 0.56,
#     'id_listing': 'NAKv53DewB6YMnxB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83788, 43.48598]},
#    'properties': {'price': 0.85,
#     'id_listing': '5xLkv3VqAOe7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70453, 43.45495]},
#    'properties': {'price': 0.83,
#     'id_listing': '0J6Em7bwp483XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88499, 43.48745]},
#    'properties': {'price': 0.66,
#     'id_listing': '0ZxwR7MDRkkyKabB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71506, 43.23785]},
#    'properties': {'price': 1.3,
#     'id_listing': 'jJKdOYraJNK354lW',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79746, 43.32443]},
#    'properties': {'price': 1.1,
#     'id_listing': 'VaD6p78dq2z7wRQr',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71699, 43.54848]},
#    'properties': {'price': 0.61,
#     'id_listing': 'BXeEn7XVkxGYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68381, 43.47164]},
#    'properties': {'price': 0.5,
#     'id_listing': '5xLkv3VqAVO7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8384, 43.31814]},
#    'properties': {'price': 0.55,
#     'id_listing': 'BXeEn7XVkxEYrPo8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66272, 43.22397]},
#    'properties': {'price': 1.6,
#     'id_listing': 'mLzQ1y5kRLd3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84556, 43.19506]},
#    'properties': {'price': 0.58,
#     'id_listing': 'PXRla7g1XwXYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8776, 43.26598]},
#    'properties': {'price': 0.52,
#     'id_listing': 'RdXze3e8R1v78m9K',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81165, 43.24226]},
#    'properties': {'price': 0.29,
#     'id_listing': 'jJKdOYraJ8Z354lW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73598, 43.54456]},
#    'properties': {'price': 1.2,
#     'id_listing': 'owJKR7PmqQ13XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69558, 43.52261]},
#    'properties': {'price': 0.72,
#     'id_listing': 'MB5bO3xMladYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80947, 43.38436]},
#    'properties': {'price': 0.99,
#     'id_listing': 'EeVbOYEgn1R7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74072, 43.46367]},
#    'properties': {'price': 1.2,
#     'id_listing': 'gaQmD7zZpA97J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76976, 43.34914]},
#    'properties': {'price': 1.2,
#     'id_listing': '02Zpj39w6odyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75165, 43.37551]},
#    'properties': {'price': 0.84,
#     'id_listing': '2Z5BX32WZd5YDar0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.91283, 43.32391]},
#    'properties': {'price': 0.9,
#     'id_listing': 'PXRla7g1X0XYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65769, 43.4948]},
#    'properties': {'price': 0.85,
#     'id_listing': 'RdXze3e8R0v78m9K',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85678, 43.49566]},
#    'properties': {'price': 1.3,
#     'id_listing': '510QqypokX2YLGlV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.084774, 43.28678]},
#    'properties': {'price': 0.61,
#     'id_listing': 'NAKv53DewaVYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7068, 43.4481]},
#    'properties': {'price': 0.83,
#     'id_listing': 'PXRla7g1XeNYjEvL',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85392, 43.52445]},
#    'properties': {'price': 0.84,
#     'id_listing': 'damgL7A0Kl9yZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87692, 43.374361]},
#    'properties': {'price': 1.9,
#     'id_listing': 'MB5bO3xMlqgYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.845627, 43.531372]},
#    'properties': {'price': 0.6,
#     'id_listing': 'BGMnKYqGKLe7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.853915, 43.494815]},
#    'properties': {'price': 0.83,
#     'id_listing': 'BXeEn7XVkOdYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.94894, 43.21724]},
#    'properties': {'price': 0.5,
#     'id_listing': '2Z5BX32WZwwYDar0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82962, 43.34966]},
#    'properties': {'price': 0.4,
#     'id_listing': 'RdXze3e8REo78m9K',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68537, 43.54554]},
#    'properties': {'price': 0.42,
#     'id_listing': 'dXawjy4PEOWyrR18',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.859678, 43.232644]},
#    'properties': {'price': 0.45,
#     'id_listing': 'a6zqW7dLEKP75eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.96262, 43.39681]},
#    'properties': {'price': 2.7,
#     'id_listing': 'ZNkKJ3J5pJx7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69179, 43.23402]},
#    'properties': {'price': 1.2,
#     'id_listing': 'damgL7A0KxEyZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6965, 43.4217]},
#    'properties': {'price': 1.2,
#     'id_listing': 'MB5bO3xMl8WYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66883, 43.53233]},
#    'properties': {'price': 1.4,
#     'id_listing': '5xLkv3VqA1x7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.850647, 43.497141]},
#    'properties': {'price': 0.58,
#     'id_listing': 'obqB176KQzd3ZajD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72955, 43.43279]},
#    'properties': {'price': 0.76,
#     'id_listing': 'BGMnKYqGKxR7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.00852, 43.41756]},
#    'properties': {'price': 1.6,
#     'id_listing': 'N0A9X3j0V6LyvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86815, 43.19448]},
#    'properties': {'price': 0.54,
#     'id_listing': '0ZxwR7MDRV2yKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83273, 43.24425]},
#    'properties': {'price': 0.45,
#     'id_listing': 'gaQmD7zZpVZ7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82539, 43.21885]},
#    'properties': {'price': 0.59,
#     'id_listing': '2Z5BX32WZ1lYDar0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88426, 43.18593]},
#    'properties': {'price': 0.85,
#     'id_listing': 'zVwod7vDLK9Y5mGN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72682, 43.22687]},
#    'properties': {'price': 0.95,
#     'id_listing': 'ZEXrx30OZeG7OklN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77262, 43.33977]},
#    'properties': {'price': 1.3,
#     'id_listing': 'xmZRW7ngA2M3EBO9',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71303, 43.53011]},
#    'properties': {'price': 0.88,
#     'id_listing': 'DnM697kNOVgybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79987, 43.24053]},
#    'properties': {'price': 0.42,
#     'id_listing': 'MB5bO3xMlx6YkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82147, 43.40643]},
#    'properties': {'price': 0.73,
#     'id_listing': '5xLkv3VqA9R7DBNr',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77788, 43.1779]},
#    'properties': {'price': 0.51,
#     'id_listing': 'JjAXw7QZ6wb3QOzg',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84522, 43.50944]},
#    'properties': {'price': 0.75,
#     'id_listing': 'EeVbOYEgnpK7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71676, 43.44615]},
#    'properties': {'price': 1.6,
#     'id_listing': 'oK8OgYBNJV5YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67789, 43.45435]},
#    'properties': {'price': 1.2,
#     'id_listing': 'x9w8o3meW5z3GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8401, 43.48724]},
#    'properties': {'price': 0.84,
#     'id_listing': 'NAKv53DewD5YMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73644, 43.45215]},
#    'properties': {'price': 0.6,
#     'id_listing': '02Zpj39w6EnyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.89433, 43.4971]},
#    'properties': {'price': 1.0,
#     'id_listing': 'L5VXv3l4xXN3j2q8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85894, 43.51874]},
#    'properties': {'price': 0.99,
#     'id_listing': 'VgAaOyL9E8b7GxMb',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74347, 43.36138]},
#    'properties': {'price': 2.3,
#     'id_listing': 'a6zqW7dLEG175eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70558, 43.40189]},
#    'properties': {'price': 1.9,
#     'id_listing': '02Zpj39wOJPyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.783686, 43.218842]},
#    'properties': {'price': 0.32,
#     'id_listing': '510Qqypove5YLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80669, 43.32269]},
#    'properties': {'price': 0.37,
#     'id_listing': 'xmZRW7ngvgg3EBO9',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78723, 43.33721]},
#    'properties': {'price': 0.2,
#     'id_listing': 'DnM697kNvNdybmwe',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85203, 43.5098]},
#    'properties': {'price': 0.55,
#     'id_listing': 'oK8OgYBNwNjYJmG2',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85046, 43.22068]},
#    'properties': {'price': 0.39,
#     'id_listing': '0ZxwR7MDGDByKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85184, 43.35123]},
#    'properties': {'price': 2.0,
#     'id_listing': 'r56k97wz4P1yKRjD',
# ...
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.840207, 43.681013]},
#    'properties': {'price': 0.56,
#     'id_listing': 'ZNkKJ3J5pjZ7d4V6',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83486, 43.51193]},
#    'properties': {'price': 0.82,
#     'id_listing': 'DnM697kNOvdybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.03262, 43.63538]},
#    'properties': {'price': 0.54,
#     'id_listing': 'BXeEn7XVkGvYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82132, 43.68374]},
#    'properties': {'price': 0.86,
#     'id_listing': 'JjAXw7QZ6Ga3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67862, 43.77098]},
#    'properties': {'price': 1.6,
#     'id_listing': 'N0A9X3j0VvdyvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.56275, 43.74614]},
#    'properties': {'price': 0.35,
#     'id_listing': 'x9w8o3meWvZ3GKjm',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72084, 43.55006]},
#    'properties': {'price': 0.73,
#     'id_listing': '0Zaw5YovPb23n961',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6888, 43.58424]},
#    'properties': {'price': 1.3,
#     'id_listing': 'JjAXw7QZ6ka3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79273, 43.72467]},
#    'properties': {'price': 0.61,
#     'id_listing': 'damgL7A0KLLyZ1MW',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79873, 43.68066]},
#    'properties': {'price': 0.77,
#     'id_listing': 'BDO1w3W6PLj78Jg0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.63578, 43.73381]},
#    'properties': {'price': 0.68,
#     'id_listing': 'weQp5yOMXAg3d0ZE',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73473, 43.75928]},
#    'properties': {'price': 0.7,
#     'id_listing': '5xLkv3VqAnQ7DBNr',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.5712, 43.83101]},
#    'properties': {'price': 1.2,
#     'id_listing': 'EeVbOYEgnEV7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81702, 43.71196]},
#    'properties': {'price': 0.83,
#     'id_listing': 'RdXze3e8Rjq78m9K',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77388, 43.73329]},
#    'properties': {'price': 0.75,
#     'id_listing': 'dXawjy4PEjpyrR18',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79148, 43.58665]},
#    'properties': {'price': 1.1,
#     'id_listing': 'L4KAX7NzQJP7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78629, 43.67972]},
#    'properties': {'price': 0.72,
#     'id_listing': 'ZEXrx30OZjg7OklN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.808237, 43.37688]},
#    'properties': {'price': 0.53,
#     'id_listing': 'owJKR7PmqwB3XeLP',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.58902, 43.62136]},
#    'properties': {'price': 0.43,
#     'id_listing': 'damgL7A0KBLyZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.55829, 43.6092]},
#    'properties': {'price': 0.49,
#     'id_listing': '0J6Em7bwpjd3XBeq',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7056, 43.52567]},
#    'properties': {'price': 0.57,
#     'id_listing': 'x9w8o3meWMJ3GKjm',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84898, 43.6639]},
#    'properties': {'price': 0.4,
#     'id_listing': '510QqypokADYLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64997, 43.60325]},
#    'properties': {'price': 0.66,
#     'id_listing': 'knbq6y1xZgBYo9DA',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64789, 43.6009]},
#    'properties': {'price': 0.45,
#     'id_listing': 'L5VXv3l4xVp3j2q8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79511, 43.66803]},
#    'properties': {'price': 1.2,
#     'id_listing': 'a6zqW7dLEbV75eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86615, 43.6773]},
#    'properties': {'price': 1.9,
#     'id_listing': 'ZNkKJ3J5pke7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73968, 43.46557]},
#    'properties': {'price': 1.4,
#     'id_listing': 'owJKR7PmqLB3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66866, 43.60659]},
#    'properties': {'price': 1.1,
#     'id_listing': 'damgL7A0KXLyZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77034, 43.71724]},
#    'properties': {'price': 0.68,
#     'id_listing': 'BDO1w3W6Pbj78Jg0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.59634, 43.5431]},
#    'properties': {'price': 0.93,
#     'id_listing': 'MB5bO3xMlLLYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7831, 43.76004]},
#    'properties': {'price': 0.71,
#     'id_listing': 'EeVbOYEgnOV7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67161, 43.45711]},
#    'properties': {'price': 1.7,
#     'id_listing': 'owJKR7PmqLX3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8544, 43.70405]},
#    'properties': {'price': 0.64,
#     'id_listing': 'damgL7A0KX2yZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85963, 43.70092]},
#    'properties': {'price': 0.76,
#     'id_listing': '6VLaGyGo8jvyW1ZD',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77047, 43.71016]},
#    'properties': {'price': 0.67,
#     'id_listing': '0Zaw5YovPZm3n961',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80762, 43.66533]},
#    'properties': {'price': 1.1,
#     'id_listing': 'L4KAX7NzQgq7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73697, 43.56174]},
#    'properties': {'price': 0.74,
#     'id_listing': 'xmZRW7ngAZ13EBO9',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70506, 43.49748]},
#    'properties': {'price': 1.0,
#     'id_listing': 'gJRv53K2rg47VPW4',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6992, 43.78298]},
#    'properties': {'price': 0.69,
#     'id_listing': 'DnM697kNOLbybmwe',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.5892, 43.60955]},
#    'properties': {'price': 0.34,
#     'id_listing': 'N0A9X3j0Va1yvgxV',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.59516, 43.61537]},
#    'properties': {'price': 0.73,
#     'id_listing': '02Zpj39w6W0yDrK8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.545392, 43.721258]},
#    'properties': {'price': 0.32,
#     'id_listing': '6VLaGyGo86vyW1ZD',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64616, 43.58511]},
#    'properties': {'price': 0.48,
#     'id_listing': '0Zaw5YovPpm3n961',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69363, 43.47182]},
#    'properties': {'price': 0.59,
#     'id_listing': 'zVwod7vDLgpY5mGN',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.60336, 43.72058]},
#    'properties': {'price': 0.41,
#     'id_listing': 'PXRla7g1Xl6YjEvL',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.730347, 43.680583]},
#    'properties': {'price': 0.43,
#     'id_listing': 'RdXze3e8RnO78m9K',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74434, 43.73589]},
#    'properties': {'price': 0.47,
#     'id_listing': 'ZEXrx30OZEZ7OklN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8433, 43.68012]},
#    'properties': {'price': 0.49,
#     'id_listing': 'jJKdOYraJej354lW',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.63645, 43.51169]},
#    'properties': {'price': 0.5,
#     'id_listing': '510Qqypok21YLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72505, 43.70955]},
#    'properties': {'price': 0.39,
#     'id_listing': 'VaD6p78dqx67wRQr',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6413, 43.50987]},
#    'properties': {'price': 0.58,
#     'id_listing': 'EeVbOYEgldK7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'price': 0.42,
#     'id_listing': 'N0A9X3j0OlDyvgxV',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68764, 43.47599]},
#    'properties': {'price': 0.68,
#     'id_listing': '02Zpj39wxXnyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81765, 43.70411]},
#    'properties': {'price': 0.77,
#     'id_listing': 'ZNkKJ3J5ElN7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84149, 43.69384]},
#    'properties': {'price': 0.74,
#     'id_listing': 'obqB176K6kK3ZajD',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8123, 43.68016]},
#    'properties': {'price': 0.7,
#     'id_listing': 'oK8OgYBNn05YJmG2',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85404, 43.53379]},
#    'properties': {'price': 0.8,
#     'id_listing': '0J6Em7bwBNg3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75397, 43.74542]},
#    'properties': {'price': 0.74,
#     'id_listing': '0ZxwR7MDXqzyKabB',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79931, 43.73657]},
#    'properties': {'price': 1.1,
#     'id_listing': 'NAKv53De845YMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.61619, 43.72424]},
#    'properties': {'price': 0.51,
#     'id_listing': 'VgAaOyL9QXb7GxMb',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.58079, 43.74953]},
#    'properties': {'price': 0.41,
#     'id_listing': 'a6zqW7dLRe175eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'weQp5yOM6zv3d0ZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72747, 43.47976]},
#    'properties': {'price': 0.5,
#     'id_listing': '5xLkv3VqkzR7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72875, 43.66111]},
#    'properties': {'price': 0.58,
#     'id_listing': 'EeVbOYEglzK7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64981, 43.60397]},
#    'properties': {'price': 0.57,
#     'id_listing': 'owJKR7PmVjM3XeLP',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64277, 43.58355]},
#    'properties': {'price': 0.54,
#     'id_listing': 'damgL7A0w5myZ1MW',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74954, 43.69544]},
#    'properties': {'price': 0.34,
#     'id_listing': 'BDO1w3W6Kzn78Jg0',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84898, 43.6639]},
#    'properties': {'price': 0.44,
#     'id_listing': 'MB5bO3xM1mQYkWVP',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'N0A9X3j0OmdyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.689924, 43.482696]},
#    'properties': {'price': 0.66,
#     'id_listing': '0MWBVyZBwzbyKemj',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.58321, 43.79828]},
#    'properties': {'price': 0.61,
#     'id_listing': '02Zpj39wx2PyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.583115, 43.798694]},
#    'properties': {'price': 0.57,
#     'id_listing': '2Z5BX32WR5DYDar0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.02366, 43.63225]},
#    'properties': {'price': 0.69,
#     'id_listing': 'ZNkKJ3J5EbZ7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.838863, 43.756144]},
#    'properties': {'price': 1.3,
#     'id_listing': 'gJRv53K2R5x7VPW4',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86229, 43.87973]},
#    'properties': {'price': 1.1,
#     'id_listing': 'DnM697kNxWdybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84156, 43.75321]},
#    'properties': {'price': 1.1,
#     'id_listing': 'damgL7A0wGmyZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.764291, 43.761004]},
#    'properties': {'price': 0.55,
#     'id_listing': '0J6Em7bwBEd3XBeq',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.03288, 43.63211]},
#    'properties': {'price': 0.5,
#     'id_listing': 'x9w8o3meAPJ3GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.62582, 43.54752]},
#    'properties': {'price': 2.0,
#     'id_listing': '0ZxwR7MDX5ByKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75855, 43.73061]},
#    'properties': {'price': 0.86,
#     'id_listing': 'gaQmD7zZr0O7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.04189, 43.62272]},
#    'properties': {'price': 0.6,
#     'id_listing': 'NAKv53De85jYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83702, 43.5103]},
#    'properties': {'price': 0.76,
#     'id_listing': '02Zpj39wxGqyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66492, 43.78561]},
#    'properties': {'price': 0.75,
#     'id_listing': '2Z5BX32WRm1YDar0',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.59804, 43.54401]},
#    'properties': {'price': 1.5,
#     'id_listing': 'mLzQ1y5kqaE3qdeK',
#     'house_type': 'S'}},
#   ...]}

# %%
output = open(out_file, 'w')
json.dump(geojson, output)

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'price': 0.42,
#     'id_listing': 'N0A9X3j0OlDyvgxV',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.809363, 43.377062]},
#    'properties': {'price': 0.39,
#     'id_listing': '0J6Em7bwBkg3XBeq',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68764, 43.47599]},
#    'properties': {'price': 0.68,
#     'id_listing': '02Zpj39wxXnyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79985, 43.24459]},
#    'properties': {'price': 0.35,
#     'id_listing': '5xLkv3VqkKR7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85404, 43.53379]},
#    'properties': {'price': 0.8,
#     'id_listing': '0J6Em7bwBNg3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75671, 43.36588]},
#    'properties': {'price': 0.93,
#     'id_listing': '0MWBVyZBwnqyKemj',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.97164, 43.27235]},
#    'properties': {'price': 1.3,
#     'id_listing': 'BDO1w3W6KJq78Jg0',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'weQp5yOM6zv3d0ZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72747, 43.47976]},
#    'properties': {'price': 0.5,
#     'id_listing': '5xLkv3VqkzR7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73485, 43.36526]},
#    'properties': {'price': 0.7,
#     'id_listing': 'BXeEn7XVJzvYrPo8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'N0A9X3j0OmdyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.689924, 43.482696]},
#    'properties': {'price': 0.66,
#     'id_listing': '0MWBVyZBwzbyKemj',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.99203, 43.2739]},
#    'properties': {'price': 0.93,
#     'id_listing': 'weQp5yOM65g3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.13745, 43.28862]},
#    'properties': {'price': 0.87,
#     'id_listing': '5xLkv3Vqk5Q7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77823, 43.1821]},
#    'properties': {'price': 0.66,
#     'id_listing': 'oK8OgYBNnGjYJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82134, 43.37113]},
#    'properties': {'price': 1.1,
#     'id_listing': 'N0A9X3j0OxwyvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83702, 43.5103]},
#    'properties': {'price': 0.76,
#     'id_listing': '02Zpj39wxGqyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78066, 43.3905]},
#    'properties': {'price': 0.62,
#     'id_listing': '6VLaGyGopGKyW1ZD',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86242, 43.49255]},
#    'properties': {'price': 0.93,
#     'id_listing': 'knbq6y1xEWBYo9DA',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70822, 43.5263]},
#    'properties': {'price': 0.85,
#     'id_listing': 'DnM697kNxKOybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79202, 43.408]},
#    'properties': {'price': 0.63,
#     'id_listing': 'BDO1w3W6K2j78Jg0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69987, 43.41322]},
#    'properties': {'price': 1.4,
#     'id_listing': 'MB5bO3xM14LYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72774, 43.48328]},
#    'properties': {'price': 0.88,
#     'id_listing': 'oK8OgYBNn4jYJmG2',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69245, 43.46221]},
#    'properties': {'price': 1.1,
#     'id_listing': 'zVwod7vD8NDY5mGN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72787, 43.47849]},
#    'properties': {'price': 0.51,
#     'id_listing': 'L5VXv3l4WWV3j2q8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85467, 43.31159]},
#    'properties': {'price': 0.93,
#     'id_listing': 'VaD6p78dOO67wRQr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80351, 43.39677]},
#    'properties': {'price': 0.97,
#     'id_listing': 'BDO1w3W6KKw78Jg0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78841, 43.39316]},
#    'properties': {'price': 0.34,
#     'id_listing': 'BGMnKYqGJJ57w1Qr',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.89911, 43.22153]},
#    'properties': {'price': 0.45,
#     'id_listing': '0MWBVyZBwG5yKemj',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77122, 43.20268]},
#    'properties': {'price': 0.72,
#     'id_listing': '0ZxwR7MDXGeyKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90379, 43.23302]},
#    'properties': {'price': 0.54,
#     'id_listing': 'gaQmD7zZrBr7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66444, 43.53769]},
#    'properties': {'price': 1.1,
#     'id_listing': 'NAKv53De8LwYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73186, 43.37034]},
#    'properties': {'price': 1.1,
#     'id_listing': 'mLzQ1y5kqXj3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72199, 43.44219]},
#    'properties': {'price': 1.7,
#     'id_listing': 'kbEDRYadr9b31VaB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76725, 43.34319]},
#    'properties': {'price': 1.2,
#     'id_listing': 'ZNkKJ3J5Ej17d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71704, 43.40169]},
#    'properties': {'price': 1.0,
#     'id_listing': 'owJKR7PmVPG3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.93874, 43.24976]},
#    'properties': {'price': 0.72,
#     'id_listing': 'PXRla7g1qkgYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.723435, 43.223106]},
#    'properties': {'price': 0.65,
#     'id_listing': '510QqypoK1aYLGlV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74678, 43.42835]},
#    'properties': {'price': 1.4,
#     'id_listing': 'r56k97wzlVGyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73034, 43.55005]},
#    'properties': {'price': 1.3,
#     'id_listing': 'a6zqW7dLRWK75eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79708, 43.12604]},
#    'properties': {'price': 0.96,
#     'id_listing': 'owJKR7PmVwG3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82243, 43.32108]},
#    'properties': {'price': 0.75,
#     'id_listing': 'MB5bO3xM1bkYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6787, 43.47912]},
#    'properties': {'price': 1.0,
#     'id_listing': '5xLkv3VqkjZ7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.96404, 43.23201]},
#    'properties': {'price': 1.4,
#     'id_listing': 'EeVbOYEgl6d7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9318, 43.07191]},
#    'properties': {'price': 0.5,
#     'id_listing': 'damgL7A0wB5yZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69301, 43.43834]},
#    'properties': {'price': 1.5,
#     'id_listing': 'BGMnKYqGJMK7w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86374, 43.49104]},
#    'properties': {'price': 0.7,
#     'id_listing': 'VaD6p78dOZz7wRQr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7144, 43.3842]},
#    'properties': {'price': 2.0,
#     'id_listing': 'VgAaOyL9QJZ7GxMb',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87049, 43.206551]},
#    'properties': {'price': 0.43,
#     'id_listing': 'BXeEn7XVJgGYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.899968, 43.327507]},
#    'properties': {'price': 0.61,
#     'id_listing': 'EeVbOYEglLO7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88244, 43.50472]},
#    'properties': {'price': 0.54,
#     'id_listing': '0MWBVyZBwRkyKemj',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73501, 43.43578]},
#    'properties': {'price': 0.41,
#     'id_listing': '2Z5BX32WRQOYDar0',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80261, 43.37902]},
#    'properties': {'price': 0.37,
#     'id_listing': 'a6zqW7dLRwv75eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82602, 43.36803]},
#    'properties': {'price': 0.6,
#     'id_listing': 'DnM697kNxl6ybmwe',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.779993, 43.188316]},
#    'properties': {'price': 0.61,
#     'id_listing': 'zVwod7vD8q8Y5mGN',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82657, 43.25233]},
#    'properties': {'price': 0.54,
#     'id_listing': 'weQp5yOM6Lw3d0ZE',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79444, 43.1825]},
#    'properties': {'price': 0.53,
#     'id_listing': 'BGMnKYqGJjb7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72688, 43.4671]},
#    'properties': {'price': 0.89,
#     'id_listing': 'b1DBW7REx2EyqlAp',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81002, 43.38457]},
#    'properties': {'price': 0.8,
#     'id_listing': 'N0A9X3j0O8EyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90217, 43.21843]},
#    'properties': {'price': 0.6,
#     'id_listing': '0ZxwR7MDX0myKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81631, 43.2397]},
#    'properties': {'price': 0.4,
#     'id_listing': 'gaQmD7zZre97J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7072, 43.46366]},
#    'properties': {'price': 1.1,
#     'id_listing': 'zVwod7vD8n8Y5mGN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66574, 43.46408]},
#    'properties': {'price': 2.4,
#     'id_listing': 'RdXze3e8Qpv78m9K',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9297, 43.07048]},
#    'properties': {'price': 0.52,
#     'id_listing': 'JjAXw7QZOQM3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80062, 43.12143]},
#    'properties': {'price': 0.65,
#     'id_listing': 'oK8OgYBNnR4YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.809062, 43.126597]},
#    'properties': {'price': 0.53,
#     'id_listing': '0J6Em7bwB4B3XBeq',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86741, 43.53029]},
#    'properties': {'price': 0.8,
#     'id_listing': 'NAKv53De8XVYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69538, 43.52869]},
#    'properties': {'price': 1.2,
#     'id_listing': 'mLzQ1y5kq8m3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74221, 43.47078]},
#    'properties': {'price': 0.86,
#     'id_listing': 'kbEDRYadr4l31VaB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87246, 43.48079]},
#    'properties': {'price': 0.78,
#     'id_listing': '6VLaGyGopVAyW1ZD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83519, 43.24735]},
#    'properties': {'price': 0.59,
#     'id_listing': 'VaD6p78dOo07wRQr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85883, 43.51358]},
#    'properties': {'price': 0.85,
#     'id_listing': 'xmZRW7ngPXa3EBO9',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.849924, 43.503877]},
#    'properties': {'price': 0.75,
#     'id_listing': 'L5VXv3l4WbO3j2q8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73621, 43.46392]},
#    'properties': {'price': 1.2,
#     'id_listing': 'BXeEn7XVJRdYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80624, 43.347762]},
#    'properties': {'price': 0.62,
#     'id_listing': 'JjAXw7QZOVz3QOzg',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85437, 43.50573]},
#    'properties': {'price': 0.94,
#     'id_listing': '0ZxwR7MDXQ9yKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82625, 43.40401]},
#    'properties': {'price': 0.92,
#     'id_listing': 'r56k97wzlaRyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.877928, 43.340652]},
#    'properties': {'price': 1.0,
#     'id_listing': 'JjAXw7QZOXd3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7094, 43.53529]},
#    'properties': {'price': 0.95,
#     'id_listing': 'EeVbOYEgl9r7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75444, 43.44067]},
#    'properties': {'price': 0.9,
#     'id_listing': 'owJKR7PmVQD3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70499, 43.45734]},
#    'properties': {'price': 1.1,
#     'id_listing': 'weQp5yOM6RQ3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7639, 43.44662]},
#    'properties': {'price': 0.77,
#     'id_listing': '0ZxwR7MDXa2yKabB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75444, 43.44067]},
#    'properties': {'price': 0.9,
#     'id_listing': 'gaQmD7zZrAZ7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70499, 43.45734]},
#    'properties': {'price': 1.1,
#     'id_listing': 'NAKv53De8pEYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86471, 43.24942]},
#    'properties': {'price': 0.5,
#     'id_listing': 'L5VXv3l4W0x3j2q8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.93599, 43.26244]},
#    'properties': {'price': 0.6,
#     'id_listing': 'xmZRW7ngPRM3EBO9',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7639, 43.44662]},
#    'properties': {'price': 0.77,
#     'id_listing': 'weQp5yOM6jQ3d0ZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68375, 43.23127]},
#    'properties': {'price': 0.56,
#     'id_listing': 'a6zqW7dLRrP75eZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73167, 43.45002]},
#    'properties': {'price': 0.95,
#     'id_listing': 'r56k97wzl5OyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84007, 43.2561]},
#    'properties': {'price': 0.45,
#     'id_listing': '0J6Em7bwBag3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76635, 43.42657]},
#    'properties': {'price': 0.85,
#     'id_listing': 'gaQmD7zZrO17J9Bo',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9456, 43.27045]},
#    'properties': {'price': 0.5,
#     'id_listing': '0Zaw5Yovka23n961',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64674, 43.54454]},
#    'properties': {'price': 5.4,
#     'id_listing': 'L4KAX7Nzqdd7eRPJ',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71119, 43.39867]},
#    'properties': {'price': 2.2,
#     'id_listing': 'jJKdOYradrB354lW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79336, 43.53307]},
#    'properties': {'price': 0.68,
#     'id_listing': '510QqypoK05YLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86125, 43.53389]},
#    'properties': {'price': 0.63,
#     'id_listing': 'DnM697kNxodybmwe',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85453, 43.5091]},
#    'properties': {'price': 0.62,
#     'id_listing': 'BXeEn7XVJrvYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72634, 43.48017]},
#    'properties': {'price': 0.53,
#     'id_listing': 'a6zqW7dLRKX75eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80026, 43.37713]},
#    'properties': {'price': 0.42,
#     'id_listing': 'owJKR7PmV9M3XeLP',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84317, 43.20922]},
#    'properties': {'price': 0.33,
#     'id_listing': 'BGMnKYqGJxj7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84948, 43.52614]},
#    'properties': {'price': 0.61,
#     'id_listing': 'dXawjy4PXNpyrR18',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.868853, 43.518985]},
#    'properties': {'price': 0.5,
#     'id_listing': 'ZEXrx30O2eg7OklN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.666816, 43.543954]},
#    'properties': {'price': 1.4,
#     'id_listing': 'jJKdOYrad0P354lW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76614, 43.35347]},
#    'properties': {'price': 0.9,
#     'id_listing': 'mLzQ1y5kqpE3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.804928, 43.318745]},
#    'properties': {'price': 1.6,
#     'id_listing': '0Zaw5Yovk543n961',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81651, 43.37462]},
#    'properties': {'price': 0.95,
#     'id_listing': 'VaD6p78dO1J7wRQr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72793, 43.47611]},
#    'properties': {'price': 1.2,
#     'id_listing': 'VgAaOyL9Q8z7GxMb',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.846856, 43.227768]},
#    'properties': {'price': 0.4,
#     'id_listing': 'owJKR7PmV8B3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68269, 43.43609]},
#    'properties': {'price': 1.7,
#     'id_listing': 'BXeEn7XVJ60YrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76313, 43.42967]},
#    'properties': {'price': 0.74,
#     'id_listing': 'b1DBW7RExDQyqlAp',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90189, 43.0601]},
#    'properties': {'price': 0.69,
#     'id_listing': 'damgL7A0w42yZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79181, 43.19958]},
#    'properties': {'price': 0.37,
#     'id_listing': '5xLkv3Vqk9p7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79558, 43.33987]},
#    'properties': {'price': 0.89,
#     'id_listing': 'BGMnKYqGJp57w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77904, 43.42302]},
#    'properties': {'price': 1.2,
#     'id_listing': 'EeVbOYEglp57x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81417, 43.35321]},
#    'properties': {'price': 0.65,
#     'id_listing': 'N0A9X3j0OR1yvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73658, 43.48242]},
#    'properties': {'price': 1.7,
#     'id_listing': 'mLzQ1y5kqZw3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84026, 43.33841]},
#    'properties': {'price': 1.1,
#     'id_listing': 'kbEDRYadrOP31VaB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7145, 43.44104]},
#    'properties': {'price': 0.79,
#     'id_listing': '6VLaGyGopNvyW1ZD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86388, 43.486912]},
#    'properties': {'price': 0.67,
#     'id_listing': 'r56k97wzlQ6yKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.94189, 43.26074]},
#    'properties': {'price': 0.4,
#     'id_listing': 'BXeEn7XVkXMYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72747, 43.47976]},
#    'properties': {'price': 0.51,
#     'id_listing': '0ZxwR7MDR2eyKabB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70949, 43.39805]},
#    'properties': {'price': 1.1,
#     'id_listing': 'mLzQ1y5kRAj3qdeK',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.771894, 43.181023]},
#    'properties': {'price': 1.1,
#     'id_listing': 'BXeEn7XVklMYrPo8',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.92425, 43.25263]},
#    'properties': {'price': 0.6,
#     'id_listing': 'JjAXw7QZ6Km3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76208, 43.43026]},
#    'properties': {'price': 1.2,
#     'id_listing': 'weQp5yOMXPB3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87876, 43.4961]},
#    'properties': {'price': 0.7,
#     'id_listing': 'BGMnKYqGK6K7w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82275, 43.38725]},
#    'properties': {'price': 0.76,
#     'id_listing': 'EeVbOYEgnRO7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65008, 43.21515]},
#    'properties': {'price': 0.57,
#     'id_listing': 'kbEDRYad1vN31VaB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64859, 43.21251]},
#    'properties': {'price': 0.71,
#     'id_listing': '6VLaGyGo8XJyW1ZD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8872, 43.34134]},
#    'properties': {'price': 0.79,
#     'id_listing': 'owJKR7PmqpO3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68143, 43.22922]},
#    'properties': {'price': 0.55,
#     'id_listing': 'EeVbOYEgnPO7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84902, 43.25883]},
#    'properties': {'price': 0.3,
#     'id_listing': 'x9w8o3meWk23GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81118, 43.12656]},
#    'properties': {'price': 0.45,
#     'id_listing': '0Zaw5YovPJ03n961',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.919133, 43.32722]},
#    'properties': {'price': 0.65,
#     'id_listing': 'PXRla7g1XV5YjEvL',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82334, 43.25726]},
#    'properties': {'price': 0.29,
#     'id_listing': 'L4KAX7NzQlO7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86374, 43.49104]},
#    'properties': {'price': 0.7,
#     'id_listing': 'BDO1w3W6PZo78Jg0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84218, 43.36406]},
#    'properties': {'price': 0.88,
#     'id_listing': 'obqB176KQ063ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83552, 43.5294]},
#    'properties': {'price': 0.76,
#     'id_listing': 'damgL7A0K9nyZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73242, 43.2258]},
#    'properties': {'price': 0.5,
#     'id_listing': 'obqB176KQ0a3ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84315, 43.50586]},
#    'properties': {'price': 0.64,
#     'id_listing': 'b1DBW7REVZ1yqlAp',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86932, 43.48545]},
#    'properties': {'price': 0.89,
#     'id_listing': '0MWBVyZBJZkyKemj',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76627, 43.43079]},
#    'properties': {'price': 0.75,
#     'id_listing': 'r56k97wz8d8yKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80285, 43.37781]},
#    'properties': {'price': 0.32,
#     'id_listing': '0J6Em7bwpMG3XBeq',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72787, 43.47849]},
#    'properties': {'price': 0.51,
#     'id_listing': 'zVwod7vDLd8Y5mGN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.97193, 43.2709]},
#    'properties': {'price': 0.5,
#     'id_listing': 'r56k97wz8wxyKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6848, 43.45184]},
#    'properties': {'price': 0.36,
#     'id_listing': 'a6zqW7dLEMk75eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81506, 43.24994]},
#    'properties': {'price': 0.37,
#     'id_listing': '0J6Em7bwpgB3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70624, 43.22323]},
#    'properties': {'price': 0.58,
#     'id_listing': 'r56k97wz89QyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73636, 43.38147]},
#    'properties': {'price': 0.96,
#     'id_listing': 'BGMnKYqGKee7w1Qr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.89505, 43.34548]},
#    'properties': {'price': 1.2,
#     'id_listing': 'oK8OgYBNJk4YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69902, 43.49951]},
#    'properties': {'price': 1.4,
#     'id_listing': 'dXawjy4PEoByrR18',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6611, 43.53775]},
#    'properties': {'price': 1.3,
#     'id_listing': 'L4KAX7NzQ0r7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72559, 43.24032]},
#    'properties': {'price': 0.5,
#     'id_listing': 'r56k97wz8RQyKRjD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70544, 43.49309]},
#    'properties': {'price': 1.2,
#     'id_listing': 'owJKR7PmqOp3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74851, 43.42998]},
#    'properties': {'price': 0.85,
#     'id_listing': 'damgL7A0Kr9yZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69121, 43.42473]},
#    'properties': {'price': 1.4,
#     'id_listing': 'weQp5yOMXVb3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71087, 43.53059]},
#    'properties': {'price': 0.99,
#     'id_listing': '0ZxwR7MDRz9yKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.731719, 43.487889]},
#    'properties': {'price': 1.3,
#     'id_listing': '02Zpj39w62kyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77904, 43.42302]},
#    'properties': {'price': 1.2,
#     'id_listing': 'zVwod7vDLmrY5mGN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79851, 43.34114]},
#    'properties': {'price': 0.94,
#     'id_listing': 'PXRla7g1XmGYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82651, 43.39898]},
#    'properties': {'price': 0.88,
#     'id_listing': 'L4KAX7NzQoz7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80041, 43.40686]},
#    'properties': {'price': 0.82,
#     'id_listing': 'owJKR7Pmqov3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88569, 43.50005]},
#    'properties': {'price': 0.9,
#     'id_listing': 'weQp5yOMXoG3d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84883, 43.52586]},
#    'properties': {'price': 0.5,
#     'id_listing': 'VgAaOyL9EvO7GxMb',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85414, 43.25393]},
#    'properties': {'price': 0.5,
#     'id_listing': 'r56k97wz8EOyKRjD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.90014, 43.324]},
#    'properties': {'price': 1.0,
#     'id_listing': 'oK8OgYBNJn5YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.809708, 43.18072]},
#    'properties': {'price': 0.56,
#     'id_listing': '0J6Em7bwpBg3XBeq',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.01308, 43.21361]},
#    'properties': {'price': 0.65,
#     'id_listing': 'x9w8o3meWAz3GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.98943, 43.20658]},
#    'properties': {'price': 0.66,
#     'id_listing': 'ZEXrx30OZ2J7OklN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70004, 43.48556]},
#    'properties': {'price': 1.2,
#     'id_listing': 'obqB176KQQK3ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.9325, 43.42035]},
#    'properties': {'price': 1.2,
#     'id_listing': '0MWBVyZBJJbyKemj',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83486, 43.51193]},
#    'properties': {'price': 0.82,
#     'id_listing': 'DnM697kNOvdybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72084, 43.55006]},
#    'properties': {'price': 0.73,
#     'id_listing': '0Zaw5YovPb23n961',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.808237, 43.37688]},
#    'properties': {'price': 0.53,
#     'id_listing': 'owJKR7PmqwB3XeLP',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7056, 43.52567]},
#    'properties': {'price': 0.57,
#     'id_listing': 'x9w8o3meWMJ3GKjm',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80505, 43.25388]},
#    'properties': {'price': 0.3,
#     'id_listing': 'DnM697kNO6Oybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73968, 43.46557]},
#    'properties': {'price': 1.4,
#     'id_listing': 'owJKR7PmqLB3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83779, 43.25944]},
#    'properties': {'price': 0.45,
#     'id_listing': 'weQp5yOMXng3d0ZE',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67161, 43.45711]},
#    'properties': {'price': 1.7,
#     'id_listing': 'owJKR7PmqLX3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70506, 43.49748]},
#    'properties': {'price': 1.0,
#     'id_listing': 'gJRv53K2rg47VPW4',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69363, 43.47182]},
#    'properties': {'price': 0.59,
#     'id_listing': 'zVwod7vDLgpY5mGN',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75248, 43.45164]},
#    'properties': {'price': 1.1,
#     'id_listing': 'weQp5yOMXL13d0ZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70771, 43.41867]},
#    'properties': {'price': 1.2,
#     'id_listing': 'obqB176KQrM3ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71304, 43.39398]},
#    'properties': {'price': 1.2,
#     'id_listing': 'N0A9X3j0VgmyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.95583, 43.21867]},
#    'properties': {'price': 0.82,
#     'id_listing': 'VaD6p78dq9k7wRQr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.98386, 43.36061]},
#    'properties': {'price': 0.95,
#     'id_listing': 'EeVbOYEgnxd7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.893932, 43.212157]},
#    'properties': {'price': 0.48,
#     'id_listing': '5xLkv3VqA0e7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76464, 43.22579]},
#    'properties': {'price': 0.55,
#     'id_listing': 'obqB176KQx63ZajD',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77883, 43.25167]},
#    'properties': {'price': 0.57,
#     'id_listing': 'BXeEn7XVk0GYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85224, 43.48233]},
#    'properties': {'price': 0.56,
#     'id_listing': 'NAKv53DewB6YMnxB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83788, 43.48598]},
#    'properties': {'price': 0.85,
#     'id_listing': '5xLkv3VqAOe7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70453, 43.45495]},
#    'properties': {'price': 0.83,
#     'id_listing': '0J6Em7bwp483XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88499, 43.48745]},
#    'properties': {'price': 0.66,
#     'id_listing': '0ZxwR7MDRkkyKabB',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71506, 43.23785]},
#    'properties': {'price': 1.3,
#     'id_listing': 'jJKdOYraJNK354lW',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79746, 43.32443]},
#    'properties': {'price': 1.1,
#     'id_listing': 'VaD6p78dq2z7wRQr',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71699, 43.54848]},
#    'properties': {'price': 0.61,
#     'id_listing': 'BXeEn7XVkxGYrPo8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68381, 43.47164]},
#    'properties': {'price': 0.5,
#     'id_listing': '5xLkv3VqAVO7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8384, 43.31814]},
#    'properties': {'price': 0.55,
#     'id_listing': 'BXeEn7XVkxEYrPo8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66272, 43.22397]},
#    'properties': {'price': 1.6,
#     'id_listing': 'mLzQ1y5kRLd3qdeK',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84556, 43.19506]},
#    'properties': {'price': 0.58,
#     'id_listing': 'PXRla7g1XwXYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8776, 43.26598]},
#    'properties': {'price': 0.52,
#     'id_listing': 'RdXze3e8R1v78m9K',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81165, 43.24226]},
#    'properties': {'price': 0.29,
#     'id_listing': 'jJKdOYraJ8Z354lW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73598, 43.54456]},
#    'properties': {'price': 1.2,
#     'id_listing': 'owJKR7PmqQ13XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69558, 43.52261]},
#    'properties': {'price': 0.72,
#     'id_listing': 'MB5bO3xMladYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80947, 43.38436]},
#    'properties': {'price': 0.99,
#     'id_listing': 'EeVbOYEgn1R7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74072, 43.46367]},
#    'properties': {'price': 1.2,
#     'id_listing': 'gaQmD7zZpA97J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.76976, 43.34914]},
#    'properties': {'price': 1.2,
#     'id_listing': '02Zpj39w6odyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75165, 43.37551]},
#    'properties': {'price': 0.84,
#     'id_listing': '2Z5BX32WZd5YDar0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.91283, 43.32391]},
#    'properties': {'price': 0.9,
#     'id_listing': 'PXRla7g1X0XYjEvL',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.65769, 43.4948]},
#    'properties': {'price': 0.85,
#     'id_listing': 'RdXze3e8R0v78m9K',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85678, 43.49566]},
#    'properties': {'price': 1.3,
#     'id_listing': '510QqypokX2YLGlV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.084774, 43.28678]},
#    'properties': {'price': 0.61,
#     'id_listing': 'NAKv53DewaVYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7068, 43.4481]},
#    'properties': {'price': 0.83,
#     'id_listing': 'PXRla7g1XeNYjEvL',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85392, 43.52445]},
#    'properties': {'price': 0.84,
#     'id_listing': 'damgL7A0Kl9yZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.87692, 43.374361]},
#    'properties': {'price': 1.9,
#     'id_listing': 'MB5bO3xMlqgYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.845627, 43.531372]},
#    'properties': {'price': 0.6,
#     'id_listing': 'BGMnKYqGKLe7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.853915, 43.494815]},
#    'properties': {'price': 0.83,
#     'id_listing': 'BXeEn7XVkOdYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.94894, 43.21724]},
#    'properties': {'price': 0.5,
#     'id_listing': '2Z5BX32WZwwYDar0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82962, 43.34966]},
#    'properties': {'price': 0.4,
#     'id_listing': 'RdXze3e8REo78m9K',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68537, 43.54554]},
#    'properties': {'price': 0.42,
#     'id_listing': 'dXawjy4PEOWyrR18',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.859678, 43.232644]},
#    'properties': {'price': 0.45,
#     'id_listing': 'a6zqW7dLEKP75eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.96262, 43.39681]},
#    'properties': {'price': 2.7,
#     'id_listing': 'ZNkKJ3J5pJx7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69179, 43.23402]},
#    'properties': {'price': 1.2,
#     'id_listing': 'damgL7A0KxEyZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6965, 43.4217]},
#    'properties': {'price': 1.2,
#     'id_listing': 'MB5bO3xMl8WYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66883, 43.53233]},
#    'properties': {'price': 1.4,
#     'id_listing': '5xLkv3VqA1x7DBNr',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.850647, 43.497141]},
#    'properties': {'price': 0.58,
#     'id_listing': 'obqB176KQzd3ZajD',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72955, 43.43279]},
#    'properties': {'price': 0.76,
#     'id_listing': 'BGMnKYqGKxR7w1Qr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.00852, 43.41756]},
#    'properties': {'price': 1.6,
#     'id_listing': 'N0A9X3j0V6LyvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86815, 43.19448]},
#    'properties': {'price': 0.54,
#     'id_listing': '0ZxwR7MDRV2yKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83273, 43.24425]},
#    'properties': {'price': 0.45,
#     'id_listing': 'gaQmD7zZpVZ7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82539, 43.21885]},
#    'properties': {'price': 0.59,
#     'id_listing': '2Z5BX32WZ1lYDar0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.88426, 43.18593]},
#    'properties': {'price': 0.85,
#     'id_listing': 'zVwod7vDLK9Y5mGN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72682, 43.22687]},
#    'properties': {'price': 0.95,
#     'id_listing': 'ZEXrx30OZeG7OklN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77262, 43.33977]},
#    'properties': {'price': 1.3,
#     'id_listing': 'xmZRW7ngA2M3EBO9',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71303, 43.53011]},
#    'properties': {'price': 0.88,
#     'id_listing': 'DnM697kNOVgybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79987, 43.24053]},
#    'properties': {'price': 0.42,
#     'id_listing': 'MB5bO3xMlx6YkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82147, 43.40643]},
#    'properties': {'price': 0.73,
#     'id_listing': '5xLkv3VqA9R7DBNr',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77788, 43.1779]},
#    'properties': {'price': 0.51,
#     'id_listing': 'JjAXw7QZ6wb3QOzg',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84522, 43.50944]},
#    'properties': {'price': 0.75,
#     'id_listing': 'EeVbOYEgnpK7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71676, 43.44615]},
#    'properties': {'price': 1.6,
#     'id_listing': 'oK8OgYBNJV5YJmG2',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67789, 43.45435]},
#    'properties': {'price': 1.2,
#     'id_listing': 'x9w8o3meW5z3GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8401, 43.48724]},
#    'properties': {'price': 0.84,
#     'id_listing': 'NAKv53DewD5YMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73644, 43.45215]},
#    'properties': {'price': 0.6,
#     'id_listing': '02Zpj39w6EnyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.89433, 43.4971]},
#    'properties': {'price': 1.0,
#     'id_listing': 'L5VXv3l4xXN3j2q8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85894, 43.51874]},
#    'properties': {'price': 0.99,
#     'id_listing': 'VgAaOyL9E8b7GxMb',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74347, 43.36138]},
#    'properties': {'price': 2.3,
#     'id_listing': 'a6zqW7dLEG175eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70558, 43.40189]},
#    'properties': {'price': 1.9,
#     'id_listing': '02Zpj39wOJPyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.783686, 43.218842]},
#    'properties': {'price': 0.32,
#     'id_listing': '510Qqypove5YLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80669, 43.32269]},
#    'properties': {'price': 0.37,
#     'id_listing': 'xmZRW7ngvgg3EBO9',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78723, 43.33721]},
#    'properties': {'price': 0.2,
#     'id_listing': 'DnM697kNvNdybmwe',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85203, 43.5098]},
#    'properties': {'price': 0.55,
#     'id_listing': 'oK8OgYBNwNjYJmG2',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85046, 43.22068]},
#    'properties': {'price': 0.39,
#     'id_listing': '0ZxwR7MDGDByKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85184, 43.35123]},
#    'properties': {'price': 2.0,
#     'id_listing': 'r56k97wz4P1yKRjD',
# ...
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.840207, 43.681013]},
#    'properties': {'price': 0.56,
#     'id_listing': 'ZNkKJ3J5pjZ7d4V6',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83486, 43.51193]},
#    'properties': {'price': 0.82,
#     'id_listing': 'DnM697kNOvdybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.03262, 43.63538]},
#    'properties': {'price': 0.54,
#     'id_listing': 'BXeEn7XVkGvYrPo8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.82132, 43.68374]},
#    'properties': {'price': 0.86,
#     'id_listing': 'JjAXw7QZ6Ga3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67862, 43.77098]},
#    'properties': {'price': 1.6,
#     'id_listing': 'N0A9X3j0VvdyvgxV',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.56275, 43.74614]},
#    'properties': {'price': 0.35,
#     'id_listing': 'x9w8o3meWvZ3GKjm',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72084, 43.55006]},
#    'properties': {'price': 0.73,
#     'id_listing': '0Zaw5YovPb23n961',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6888, 43.58424]},
#    'properties': {'price': 1.3,
#     'id_listing': 'JjAXw7QZ6ka3QOzg',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79273, 43.72467]},
#    'properties': {'price': 0.61,
#     'id_listing': 'damgL7A0KLLyZ1MW',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79873, 43.68066]},
#    'properties': {'price': 0.77,
#     'id_listing': 'BDO1w3W6PLj78Jg0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.63578, 43.73381]},
#    'properties': {'price': 0.68,
#     'id_listing': 'weQp5yOMXAg3d0ZE',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73473, 43.75928]},
#    'properties': {'price': 0.7,
#     'id_listing': '5xLkv3VqAnQ7DBNr',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.5712, 43.83101]},
#    'properties': {'price': 1.2,
#     'id_listing': 'EeVbOYEgnEV7x2P0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81702, 43.71196]},
#    'properties': {'price': 0.83,
#     'id_listing': 'RdXze3e8Rjq78m9K',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77388, 43.73329]},
#    'properties': {'price': 0.75,
#     'id_listing': 'dXawjy4PEjpyrR18',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79148, 43.58665]},
#    'properties': {'price': 1.1,
#     'id_listing': 'L4KAX7NzQJP7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.78629, 43.67972]},
#    'properties': {'price': 0.72,
#     'id_listing': 'ZEXrx30OZjg7OklN',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.808237, 43.37688]},
#    'properties': {'price': 0.53,
#     'id_listing': 'owJKR7PmqwB3XeLP',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.58902, 43.62136]},
#    'properties': {'price': 0.43,
#     'id_listing': 'damgL7A0KBLyZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.55829, 43.6092]},
#    'properties': {'price': 0.49,
#     'id_listing': '0J6Em7bwpjd3XBeq',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7056, 43.52567]},
#    'properties': {'price': 0.57,
#     'id_listing': 'x9w8o3meWMJ3GKjm',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84898, 43.6639]},
#    'properties': {'price': 0.4,
#     'id_listing': '510QqypokADYLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64997, 43.60325]},
#    'properties': {'price': 0.66,
#     'id_listing': 'knbq6y1xZgBYo9DA',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64789, 43.6009]},
#    'properties': {'price': 0.45,
#     'id_listing': 'L5VXv3l4xVp3j2q8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79511, 43.66803]},
#    'properties': {'price': 1.2,
#     'id_listing': 'a6zqW7dLEbV75eZE',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86615, 43.6773]},
#    'properties': {'price': 1.9,
#     'id_listing': 'ZNkKJ3J5pke7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73968, 43.46557]},
#    'properties': {'price': 1.4,
#     'id_listing': 'owJKR7PmqLB3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66866, 43.60659]},
#    'properties': {'price': 1.1,
#     'id_listing': 'damgL7A0KXLyZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77034, 43.71724]},
#    'properties': {'price': 0.68,
#     'id_listing': 'BDO1w3W6Pbj78Jg0',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.59634, 43.5431]},
#    'properties': {'price': 0.93,
#     'id_listing': 'MB5bO3xMlLLYkWVP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.7831, 43.76004]},
#    'properties': {'price': 0.71,
#     'id_listing': 'EeVbOYEgnOV7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.67161, 43.45711]},
#    'properties': {'price': 1.7,
#     'id_listing': 'owJKR7PmqLX3XeLP',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8544, 43.70405]},
#    'properties': {'price': 0.64,
#     'id_listing': 'damgL7A0KX2yZ1MW',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85963, 43.70092]},
#    'properties': {'price': 0.76,
#     'id_listing': '6VLaGyGo8jvyW1ZD',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.77047, 43.71016]},
#    'properties': {'price': 0.67,
#     'id_listing': '0Zaw5YovPZm3n961',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.80762, 43.66533]},
#    'properties': {'price': 1.1,
#     'id_listing': 'L4KAX7NzQgq7eRPJ',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.73697, 43.56174]},
#    'properties': {'price': 0.74,
#     'id_listing': 'xmZRW7ngAZ13EBO9',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.70506, 43.49748]},
#    'properties': {'price': 1.0,
#     'id_listing': 'gJRv53K2rg47VPW4',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6992, 43.78298]},
#    'properties': {'price': 0.69,
#     'id_listing': 'DnM697kNOLbybmwe',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.5892, 43.60955]},
#    'properties': {'price': 0.34,
#     'id_listing': 'N0A9X3j0Va1yvgxV',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.59516, 43.61537]},
#    'properties': {'price': 0.73,
#     'id_listing': '02Zpj39w6W0yDrK8',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.545392, 43.721258]},
#    'properties': {'price': 0.32,
#     'id_listing': '6VLaGyGo86vyW1ZD',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64616, 43.58511]},
#    'properties': {'price': 0.48,
#     'id_listing': '0Zaw5YovPpm3n961',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.69363, 43.47182]},
#    'properties': {'price': 0.59,
#     'id_listing': 'zVwod7vDLgpY5mGN',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.60336, 43.72058]},
#    'properties': {'price': 0.41,
#     'id_listing': 'PXRla7g1Xl6YjEvL',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.730347, 43.680583]},
#    'properties': {'price': 0.43,
#     'id_listing': 'RdXze3e8RnO78m9K',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74434, 43.73589]},
#    'properties': {'price': 0.47,
#     'id_listing': 'ZEXrx30OZEZ7OklN',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8433, 43.68012]},
#    'properties': {'price': 0.49,
#     'id_listing': 'jJKdOYraJej354lW',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.63645, 43.51169]},
#    'properties': {'price': 0.5,
#     'id_listing': '510Qqypok21YLGlV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72505, 43.70955]},
#    'properties': {'price': 0.39,
#     'id_listing': 'VaD6p78dqx67wRQr',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.6413, 43.50987]},
#    'properties': {'price': 0.58,
#     'id_listing': 'EeVbOYEgldK7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68681, 43.4474]},
#    'properties': {'price': 0.42,
#     'id_listing': 'N0A9X3j0OlDyvgxV',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.68764, 43.47599]},
#    'properties': {'price': 0.68,
#     'id_listing': '02Zpj39wxXnyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.81765, 43.70411]},
#    'properties': {'price': 0.77,
#     'id_listing': 'ZNkKJ3J5ElN7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84149, 43.69384]},
#    'properties': {'price': 0.74,
#     'id_listing': 'obqB176K6kK3ZajD',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.8123, 43.68016]},
#    'properties': {'price': 0.7,
#     'id_listing': 'oK8OgYBNn05YJmG2',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.85404, 43.53379]},
#    'properties': {'price': 0.8,
#     'id_listing': '0J6Em7bwBNg3XBeq',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75397, 43.74542]},
#    'properties': {'price': 0.74,
#     'id_listing': '0ZxwR7MDXqzyKabB',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.79931, 43.73657]},
#    'properties': {'price': 1.1,
#     'id_listing': 'NAKv53De845YMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.61619, 43.72424]},
#    'properties': {'price': 0.51,
#     'id_listing': 'VgAaOyL9QXb7GxMb',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.58079, 43.74953]},
#    'properties': {'price': 0.41,
#     'id_listing': 'a6zqW7dLRe175eZE',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'weQp5yOM6zv3d0ZE',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72747, 43.47976]},
#    'properties': {'price': 0.5,
#     'id_listing': '5xLkv3VqkzR7DBNr',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.72875, 43.66111]},
#    'properties': {'price': 0.58,
#     'id_listing': 'EeVbOYEglzK7x2P0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64981, 43.60397]},
#    'properties': {'price': 0.57,
#     'id_listing': 'owJKR7PmVjM3XeLP',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.64277, 43.58355]},
#    'properties': {'price': 0.54,
#     'id_listing': 'damgL7A0w5myZ1MW',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.74954, 43.69544]},
#    'properties': {'price': 0.34,
#     'id_listing': 'BDO1w3W6Kzn78Jg0',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84898, 43.6639]},
#    'properties': {'price': 0.44,
#     'id_listing': 'MB5bO3xM1mQYkWVP',
#     'house_type': 'C'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.71286, 43.47998]},
#    'properties': {'price': 0.57,
#     'id_listing': 'N0A9X3j0OmdyvgxV',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.689924, 43.482696]},
#    'properties': {'price': 0.66,
#     'id_listing': '0MWBVyZBwzbyKemj',
#     'house_type': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.58321, 43.79828]},
#    'properties': {'price': 0.61,
#     'id_listing': '02Zpj39wx2PyDrK8',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.583115, 43.798694]},
#    'properties': {'price': 0.57,
#     'id_listing': '2Z5BX32WR5DYDar0',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.02366, 43.63225]},
#    'properties': {'price': 0.69,
#     'id_listing': 'ZNkKJ3J5EbZ7d4V6',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.838863, 43.756144]},
#    'properties': {'price': 1.3,
#     'id_listing': 'gJRv53K2R5x7VPW4',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.86229, 43.87973]},
#    'properties': {'price': 1.1,
#     'id_listing': 'DnM697kNxWdybmwe',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.84156, 43.75321]},
#    'properties': {'price': 1.1,
#     'id_listing': 'damgL7A0wGmyZ1MW',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.764291, 43.761004]},
#    'properties': {'price': 0.55,
#     'id_listing': '0J6Em7bwBEd3XBeq',
#     'house_type': 'T'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.03288, 43.63211]},
#    'properties': {'price': 0.5,
#     'id_listing': 'x9w8o3meAPJ3GKjm',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.62582, 43.54752]},
#    'properties': {'price': 2.0,
#     'id_listing': '0ZxwR7MDX5ByKabB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.75855, 43.73061]},
#    'properties': {'price': 0.86,
#     'id_listing': 'gaQmD7zZr0O7J9Bo',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.04189, 43.62272]},
#    'properties': {'price': 0.6,
#     'id_listing': 'NAKv53De85jYMnxB',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.83702, 43.5103]},
#    'properties': {'price': 0.76,
#     'id_listing': '02Zpj39wxGqyDrK8',
#     'house_type': 'D'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.66492, 43.78561]},
#    'properties': {'price': 0.75,
#     'id_listing': '2Z5BX32WRm1YDar0',
#     'house_type': 'S'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-79.59804, 43.54401]},
#    'properties': {'price': 1.5,
#     'id_listing': 'mLzQ1y5kqaE3qdeK',
#     'house_type': 'S'}},
#   ...]}
